# %%
import numpy as np
from ase.io import read
from ase.db import connect
from collections import Counter
from catkit.pawprint import Fingerprinter
import sys
from ase.build import bulk
from catkit.gen.surface import SlabGenerator
from ase import Atoms
import pkg_resources
import json
from ase.data import atomic_numbers

# %% [markdown]
# # A1 nearest neighbor list for $Pt$ surface
#
# ## Top Pt NN list:
# $$N_0 = Pt$$
# $$N_1 = 6 Pt$$
# $$N_2 = 12 Pt$$
#
# ## Bridge Pt NN list:
# $$N_0 = 2 Pt$$
# $$N_1 = 8 Pt$$
# $$N_2 = 14 Pt$$
#
# ## Hollow Pt NN list:
# $$N_0 = 3 Pt$$
# $$N_1 = 9 Pt$$
# $$N_2 = 15 Pt$$
#
# # L12 nearest neighbor list for $Ag3Au$ surface
#
# ## Top Ag NN list:
# $$N_0 = Ag$$
# $$N_1 = 4 Ag, 2 Au (Au, 2 Ag)$$
# $$N_2 = 10 Ag, 2 Au (2 Au, 7 Ag)$$
#
# ## Top Au NN list:
# $$N_0 = Au$$
# $$N_1 = 6 Ag (3 Ag)$$
# $$N_2 = 6 Ag, 6 Au (3 Au, 6 Ag)$$
#
# ## Bridge Ag_Ag|Au NN list:
# $$N_0 = 2 Ag$$
# $$N_1 = 5 Ag, 3 Au (1 Au)$$
# $$N_2 = 12 Ag, 2 Au (6 Ag)$$
#
# ## Bridge Ag_Ag|Ag NN list:
# $$N_0 = 2 Ag$$
# $$N_1 = 5 Ag, 3 Au (1 Ag)$$
# $$N_2 = 12 Ag, 2 Au (4 Ag 2 Au)$$
#
# ## Bridge Ag_Au NN list:
# $$N_0 = Ag, Au$$
# $$N_1 = 7 Ag, 1 Au (1 Ag)$$
# $$N_2 = 9 Ag, 5 Au (4 Ag 2 Au)$$
#
# ## Hollow Ag_Ag_Au|HCP NN list:
# $$N_0 = 2 Ag, Au$$
# $$N_1 = 7 Ag, 2 Au (1 Ag)$$
# $$N_2 = 11 Ag, 4 Au (4 Ag 2 Au)$$
#
# ## Hollow Ag_Ag_Au|FCC NN list:
# $$N_0 = 2 Ag, Au$$
# $$N_1 = 7 Ag, 2 Au$$
# $$N_2 = 11 Ag, 4 Au (2 Ag 1 Au)$$
#
# ## Hollow Ag_Ag_Ag|HCP NN list:
# $$N_0 = 3 Ag$$
# $$N_1 = 6 Ag, 3 Au (1 Au)$$
# $$N_2 = 12 Ag, 3 Au (6 Ag)$$
#
# ## Hollow Ag_Ag_Ag|FCC NN list:
# $$N_0 = 3 Ag$$
# $$N_1 = 6 Ag, 3 Au$$
# $$N_2 = 12 Ag, 3 Au (3 Ag)$$
#
# # L10 nearest neighbor list for $Hf2Sn2$ surface
#
# ## Top Hf NN list:
# $$N_0 = Hf$$
# $$N_1 = 4 Sn, 2 Hf (Hf, 2 Sn)$$
# $$N_2 = 8 Hf, 4 Sn (5 Hf, 3 Sn)$$
#
# ## Top Sn NN list:
# $$N_0 = Sn$$
# $$N_1 = 4 Hf, 2 Sn (Sn, 2 Hf)$$
# $$N_2 = 8 Sn, 4 Hf (5 Sn, 3 Hf)$$
#
# ## Bridge Hf-Hf NN list:
# $$N_0 = 2 Hf$$
# $$N_1 = 6 Sn, 2 Hf (1 Sn)$$
# $$N_2 = 10 Hf, 4 Sn (4 Hf, 2 Sn)$$
#
# ## Bridge Sn_Sn NN list:
# $$N_0 = 2 Sn$$
# $$N_1 = 6 Hf, 2 Sn (1 Hf)$$
# $$N_2 = 10 Sn, 4 Hf (4 Sn, 2 Hf)$$
#
# ## Bridge Hf_Sn|Hf NN list:
# $$N_0 = Hf, Sn$$
# $$N_1 = 4 Hf, 4 Sn (1 Hf)$$
# $$N_2 = 7 Sn, 7 Hf (2 Hf, 4 Sn)$$
#
# ## Bridge Hf_Sn|Sn NN list:
# $$N_0 = Hf, Sn$$
# $$N_1 = 4 Hf, 4 Sn (1 Sn)$$
# $$N_2 = 7 Hf, 7 Sn (2 Sn, 4 Hf)$$
#
# ## Hollow Hf_Hf_Sn|FCC NN list:
# $$N_0 = 2 Hf, Sn$$
# $$N_1 = 5 Sn, 4 Hf$$
# $$N_2 = 7 Sn, 8 Hf (2 Hf 1 Sn)$$
#
# ## Hollow Hf_Hf_Sn|HCP NN list:
# $$N_0 = 2 Hf 1 Sn$$
# $$N_1 = 5 Sn, 4 Hf (1 Sn)$$
# $$N_2 = 8 Hf, 7 Sn (4 Hf 2 Sn)$$
#
# ## Hollow Sn_Sn_Hf|FCC NN list:
# $$N_0 = 2 Sn, Hf$$
# $$N_1 = 5 Hf, 4 Sn$$
# $$N_2 = 7 Hf, 8 Sn (2 Sn 1 Hf)$$
#
# ## Hollow Sn_Sn_Hf|HCP NN list:
# $$N_0 = 2 Sn 1 Hf$$
# $$N_1 = 5 Hf, 4 Sn (1 Hf)$$
# $$N_2 = 8 Sn, 7 Hf (4 Sn 2 Hf)$$

# %%
parameters_list_nonlocal = []

parameters_list_nonlocal += [['atomic_number',
                              'atomic_radius',
                              'dband_center_slab',
                              'dband_width_slab',
                              'dband_skewness_slab',
                              'dband_kurtosis_slab',
                              'dipole_polarizability',
                              'electron_affinity',
                              'heat_of_formation',
                              'specific_heat']]
parameters_list_nonlocal += [parameters_list_nonlocal[-1]]

parameters_list_nonlocal += [['atomic_number',
                              'atomic_radius',
                              'dband_center_slab',
                              'dband_width_slab',
                              'dipole_polarizability',
                              'electron_affinity',
                              'heat_of_formation',
                              'specific_heat',
                              'en_allen']]

# %%
def get_slab(symbol):
    data = np.load('bulk_data.npy')[()]

    try:
        a = data[symbol]['a']
        c = data[symbol]['c']
    except KeyError:
        if '2' in symbol:
            m1, m2, _ = symbol.split('2')
            try:
                a = data[m1 + '2' + m2 + '2']['a']
                c = data[m1 + '2' + m2 + '2']['c']
            except KeyError:
                a = data[m2 + '2' + m1 + '2']['a']
                c = data[m2 + '2' + m1 + '2']['c']

    if '2' in symbol:
        m1, m2, _ = symbol.split('2')
        name = m1 + '2' + m2 + '2'
        b=Atoms(name,
                scaled_positions=[(0, 0, 0),
                                  (0.5, 0.5, 0),
                                  (0.5, 0, 0.5),
                                  (0, 0.5, 0.5)],
                cell=[a, a, c],
                pbc=True)
        b.set_pbc((1,1,1))
    elif '3' in symbol:
        m1, m2 = symbol.split('3')
        b = bulk(m1, cubic=True, crystalstructure='fcc', a=a, c=c)
        b[3].symbol = m2
    else:
        b = bulk(symbol, cubic=True, crystalstructure='fcc', a=a, c=c)

    gen = SlabGenerator(b,
            miller_index=(1, 1, 1),
            vacuum=10,
            layers=3,
            fixed=2,
            layer_type='trim',
            standardize_bulk=False,
            primitive=False)


    return gen.get_slab(size=(1, 1), iterm=-1)

# %%
path = pkg_resources.resource_filename('catkit', 'data/properties.json')
with open(path, 'r') as f:
    properties_data = json.load(f)

# %%
def get_ads_fp(A):
    parameters = ['atomic_number',
                  'atomic_radius',
                  'dband_center_slab',
                  'dband_width_slab',
                  'dband_skewness_slab',
                  'dband_kurtosis_slab',
                  'dipole_polarizability',
                  'electron_affinity',
                  'heat_of_formation',
                  'specific_heat']
    if A[3] == "A1":
        num = [atomic_numbers[A[0]]]
    if A[3] == "L12":
        a, b = A[0].split('3')
        num = [atomic_numbers[a], atomic_numbers[b]]
    if A[3] == "L10":  
        a, b, _ = A[0].split('2')
        num = [atomic_numbers[a], atomic_numbers[b]]
    atoms_parameters = np.zeros((len(parameters), len(num)))
    for i, k in enumerate(parameters):
        atoms_parameters[i] = np.asarray(properties_data[k])[num]
    
    if A[3] == 'A1':
        if A[1] == 'top':
            AD0U = atoms_parameters.reshape(-1)
            AD0S = atoms_parameters.reshape(-1)
            AD1U = 6 * atoms_parameters.reshape(-1)
            AD1S = atoms_parameters.reshape(-1)
            AD2U = 12 * atoms_parameters.reshape(-1)
            AD2S = atoms_parameters.reshape(-1)
            SSU = 3 * atoms_parameters.reshape(-1)
            SSS = atoms_parameters.reshape(-1)
        if A[1] == 'bridge':
            AD0U = 2 * atoms_parameters.reshape(-1)
            AD0S = atoms_parameters.reshape(-1)
            AD1U = 8 * atoms_parameters.reshape(-1)
            AD1S = atoms_parameters.reshape(-1)
            AD2U = 14 * atoms_parameters.reshape(-1)
            AD2S = atoms_parameters.reshape(-1)
            SSU = atoms_parameters.reshape(-1)
            SSS = atoms_parameters.reshape(-1)
        if A[1] == 'hollow':
            AD0U = 3 * atoms_parameters.reshape(-1)
            AD0S = atoms_parameters.reshape(-1)
            AD1U = 9 * atoms_parameters.reshape(-1)
            AD1S = atoms_parameters.reshape(-1)
            AD2U = 15 * atoms_parameters.reshape(-1)
            AD2S = atoms_parameters.reshape(-1)
            if 'FCC' in A[2]:
                SSU = 3 * atoms_parameters.reshape(-1)
            else:
                SSU = atoms_parameters.reshape(-1)
            SSS = atoms_parameters.reshape(-1)
    if A[3] == 'L12':
        if A[1] == 'top':
            if A[2] == a:
                AD0U = atoms_parameters[:, 0].reshape(-1)
                AD0S = atoms_parameters[:, 0].reshape(-1)
                AD1U = 4 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/6
                AD2U = 10 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/12
                SSU = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                SSS = SSU/3
            if A[2] == b:
                AD0U = atoms_parameters[:, 1].reshape(-1)
                AD0S = atoms_parameters[:, 1].reshape(-1)
                AD1U = 6 * atoms_parameters[:, 0].reshape(-1) 
                AD1S = AD1U/6
                AD2U = 6 * atoms_parameters[:, 0].reshape(-1) + 6 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/12
                SSU = 3 * atoms_parameters[:, 0].reshape(-1) 
                SSS = atoms_parameters[:, 0].reshape(-1)
        if A[1] == 'bridge':
            m, o = A[2].split('|')
            m, n = m.split('_')
            if m == n:
                AD0U = 2 * atoms_parameters[:, 0].reshape(-1)
                AD0S = AD0U/2
                AD1U = 5 * atoms_parameters[:, 0].reshape(-1) + 3 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/8
                AD2U = 12 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/14
                if o == a:
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
                else:
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = atoms_parameters[:, 1].reshape(-1)
            else:
                AD0U = atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/2
                AD1U = 7 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/8
                AD2U = 9 * atoms_parameters[:, 0].reshape(-1) + 5 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/14
                SSU = atoms_parameters[:, 0].reshape(-1)
                SSS = SSU
        if A[1] == 'hollow':
            if Counter(A[2].split('|')[0].split('_'))[a] == 3:
                AD0U = 3 * atoms_parameters[:, 0].reshape(-1)
                AD0S = AD0U/3
                AD1U = 6 * atoms_parameters[:, 0].reshape(-1) + 3 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/9
                AD2U = 12 * atoms_parameters[:, 0].reshape(-1) + 3 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/15
                if 'FCC' in A[2]:
                    SSU = 3 * atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU/3
                else:
                    SSU =  atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU
            else:
                AD0U = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/3
                AD1U = 7 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/9
                AD2U = 11 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/15  
                if 'FCC' in A[2]:
                    SSU = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU/3
                else:
                    SSU =  atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
    if A[3] == 'L10':
        if A[1] == 'top':
            if A[2] == a:
                AD0U = atoms_parameters[:, 0].reshape(-1) 
                AD0S = AD0U
                AD1U = 2 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/6
                AD2U = 8 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/12
                SSU = atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                SSS = SSU/3
            else:
                AD0U = atoms_parameters[:, 1].reshape(-1) 
                AD0S = AD0U
                AD1U = 2 * atoms_parameters[:, 1].reshape(-1) + 4 * atoms_parameters[:, 0].reshape(-1)
                AD1S = AD1U/6
                AD2U = 8 * atoms_parameters[:, 1].reshape(-1) + 4 * atoms_parameters[:, 0].reshape(-1)
                AD2S = AD2U/12
                SSU = atoms_parameters[:, 1].reshape(-1) + 2 * atoms_parameters[:, 0].reshape(-1)
                SSS = SSU/3
        if A[1] == 'bridge':
            m, o = A[2].split('|')
            m, n = m.split('_')
            if m == n:
                if m == a:
                    AD0U = 2 * atoms_parameters[:, 0].reshape(-1) 
                    AD0S = AD0U/2
                    AD1U = 2 * atoms_parameters[:, 0].reshape(-1) + 6 * atoms_parameters[:, 1].reshape(-1)
                    AD1S = AD1U/8
                    AD2U = 10 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                    AD2S = AD2U/14
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU
                else:
                    AD0U = 2 * atoms_parameters[:, 1].reshape(-1) 
                    AD0S = AD0U/2
                    AD1U = 2 * atoms_parameters[:, 1].reshape(-1) + 6 * atoms_parameters[:, 0].reshape(-1)
                    AD1S = AD1U/8
                    AD2U = 10 * atoms_parameters[:, 1].reshape(-1) + 4 * atoms_parameters[:, 0].reshape(-1)
                    AD2S = AD2U/14
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
            else:
                AD0U = atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/2
                AD1U = 4 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/8
                AD2U = 7 * atoms_parameters[:, 0].reshape(-1) + 7 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/14
                if o == a:
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
                else:
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU
        if A[1] == 'hollow':
            if A[2].split('|')[0].split('_').count(a) == 2:
                AD0U = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/3
                AD1U = 4 * atoms_parameters[:, 0].reshape(-1) + 5 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/9
                AD2U = 8 * atoms_parameters[:, 0].reshape(-1) + 7 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/15
                if 'FCC' in A[2]:
                    SSU = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU/3
                else:
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
                    
            else:
                AD0U = 2 * atoms_parameters[:, 1].reshape(-1) + atoms_parameters[:, 0].reshape(-1)
                AD0S = AD0U/3
                AD1U = 4 * atoms_parameters[:, 1].reshape(-1) + 5 * atoms_parameters[:, 0].reshape(-1)
                AD1S = AD1U/9
                AD2U = 8 * atoms_parameters[:, 1].reshape(-1) + 7 * atoms_parameters[:, 0].reshape(-1)
                AD2S = AD2U/15
                if 'FCC' in A[2]:
                    SSU = 2 * atoms_parameters[:, 1].reshape(-1) + atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU/3
                else:
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU                  
    
    return AD0U, AD1U, AD2U, SSU, AD0S, AD1S, AD2S, SSS

# %%
#'CH', and 'CH2' done
adsorbates = ['CH3', 'OH', 'NH', 'SH']
'''data_format = [metadata, slab_d0, slab_d1, bimetal_fp, 
                  ads_d0_unscaled, ads_d1_unscaled, ads_d2_unscaled, SS_unscaled,
                  ads_d0_scaled, ads_d1_scaled, ads_d2_scaled, SS_scaled,
                  energy, energy_A]'''
for ads in adsorbates:
    print('Working on adsorbates: {}'.format(ads))
    data = []
    db =connect('{}_atoms.db'.format(ads))
    db_A = connect('{}_atoms.db'.format(ads[0]))
    cnt = 0
    for i in db.select():
        if len(i.toatoms()) != 12:
            continue
        cnt += 1
        slab = get_slab(i.symbol)
        metadata = tuple([i.symbol, i.site, i.site_type, i.sb_symbol])
        print('{}: {}'.format(cnt, metadata))
        energy = i.reaction_energy
        #energy_A part is wrong
        energy_A = None
        for j in db_A.select():
            cond1 = Counter(i.symbol) == Counter(j.symbol) 
            cond2 = Counter(i.site) == Counter(j.site)
            cond3 = Counter(i.site_type) == Counter(j.site_type)
            if cond1 and cond2 and cond3:
                energy_A = j.reaction_energy
                break
        fp_slab = Fingerprinter(slab)
        slab_d0 = fp_slab.get_fp(parameters_list_nonlocal[0],
                                 ['periodic_convolution'])
        slab_d1 = fp_slab.get_fp(parameters_list_nonlocal[1],
                                 [['periodic_convolution', {'d': 1}]])
        bimetal_fp = fp_slab.get_fp(parameters_list_nonlocal[2],
                                 ['bimetal_fp'])
        
        ads_d0_unscaled, ads_d1_unscaled, ads_d2_unscaled, subsurface_unscaled,\
        ads_d0_scaled, ads_d1_scaled, ads_d2_scaled, subsurface_scaled = get_ads_fp(metadata)
        

        temp = [metadata, slab_d0, slab_d1, bimetal_fp, ads_d0_unscaled, 
                ads_d1_unscaled, ads_d2_unscaled, subsurface_unscaled, ads_d0_scaled, 
                ads_d1_scaled, ads_d2_scaled, subsurface_scaled, energy, energy_A]

        data +=[temp]                
    np.save('{}_data.npy'.format(ads), data)
# Out:
# Working on adsorbates: CH3
# 1: ('Ag', 'bridge', 'Ag_Ag|Ag', 'A1')
# /Users/osmanmamun/Suncat_Code_Base/CatKit/catkit/gen/surface.py:106: UserWarning: Not using a standardized bulk will result in an arbitrary Miller index. To get ensure you are using the correct miller index, use standardize_bulk=True
#   ("Not using a standardized bulk will result in an arbitrary "
# 2: ('Ag', 'hollow', 'Ag_Ag_Ag|FCC', 'A1')
# 3: ('Ag', 'hollow', 'Ag_Ag_Ag|HCP', 'A1')
# 4: ('Ag', 'top', 'Ag', 'A1')
# 5: ('Ru3Pt', 'bridge', 'Ru_Ru|Pt', 'L12')
# 6: ('Ru3Pt', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 7: ('Ru3Pt', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 8: ('Ru3Pt', 'hollow', 'Ru_Ru_Pt|FCC', 'L12')
# 9: ('Ru3Pt', 'top', 'Ru', 'L12')
# 10: ('Ru3Pt', 'top', 'Pt', 'L12')
# /Users/osmanmamun/Suncat_Code_Base/CatKit/catkit/gratoms.py:325: UserWarning: Edge conservation not currently supported with pbc. Remove pbc or edges first.
#   ("Edge conservation not currently supported with "
# 11: ('Ru2Pt2', 'bridge', 'Ru_Ru|Pt', 'L10')
# 12: ('Ru2Pt2', 'hollow', 'Pt_Ru_Ru|FCC', 'L10')
# 13: ('Ru2Pt2', 'top', 'Pt', 'L10')
# 14: ('Ru2Pt2', 'top', 'Ru', 'L10')
# 15: ('Ru3Pd', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 16: ('Ru3Pd', 'top', 'Ru', 'L12')
# 17: ('Ru3Pd', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 18: ('Ru3Pd', 'top', 'Pd', 'L12')
# 19: ('Au', 'top', 'Au', 'A1')
# 20: ('Ru2Pd2', 'bridge', 'Pd_Pd|Ru', 'L10')
# 21: ('Ru2Pd2', 'top', 'Pd', 'L10')
# 22: ('Ru3Au', 'bridge', 'Ru_Ru|Au', 'L12')
# 23: ('Ru3Au', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 24: ('Ru3Au', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 25: ('Ru3Au', 'top', 'Ru', 'L12')
# 26: ('Ru3Au', 'top', 'Au', 'L12')
# 27: ('Ru2Cu2', 'top', 'Ru', 'L10')
# 28: ('Ru2Au2', 'bridge', 'Ru_Ru|Au', 'L10')
# 29: ('Ru2Au2', 'bridge', 'Ru_Ru|Ru', 'L10')
# 30: ('Ru2Au2', 'top', 'Ru', 'L10')
# 31: ('Ru2Ag2', 'bridge', 'Ag_Ag|Ag', 'L10')
# 32: ('Ru3Ag', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 33: ('Ru2Ag2', 'bridge', 'Ru_Ru|Ag', 'L10')
# 34: ('Ru2Ag2', 'top', 'Ag', 'L10')
# 35: ('Ru2Ag2', 'top', 'Ru', 'L10')
# 36: ('Ru3Ga', 'top', 'Ru', 'L12')
# 37: ('Ru3Ga', 'bridge', 'Ru_Ru|Ru', 'L12')
# 38: ('Ru3Ga', 'top', 'Ga', 'L12')
# 39: ('Ru3Ga', 'bridge', 'Ru_Ru|Ga', 'L12')
# 40: ('Ru3Ga', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 41: ('Ru3Ga', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 42: ('Ru3Sn', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 43: ('Ru3Sn', 'bridge', 'Ru_Ru|Sn', 'L12')
# 44: ('Ru3Sn', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 45: ('Ru3Sn', 'top', 'Ru', 'L12')
# 46: ('Ru3Sn', 'top', 'Sn', 'L12')
# 47: ('Ru2Sn2', 'top', 'Ru', 'L10')
# 48: ('Ru3Cu', 'bridge', 'Cu_Cu|Ru', 'L12')
# 49: ('Ru2Sn2', 'top', 'Sn', 'L10')
# 50: ('Ru2Cu2', 'bridge', 'Cu_Cu|Ru', 'L10')
# 51: ('Ru2Cu2', 'bridge', 'Ru_Ru|Cu', 'L10')
# 52: ('Ru2Cu2', 'hollow', 'Cu_Ru_Ru|FCC', 'L10')
# 53: ('Ru3Al', 'bridge', 'Ru_Ru|Ru', 'L12')
# 54: ('Ru2Cu2', 'top', 'Cu', 'L10')
# 55: ('Ru3Al', 'bridge', 'Ru_Ru|Al', 'L12')
# 56: ('Ru3Cu', 'bridge', 'Ru_Ru|Ru', 'L12')
# 57: ('Ru3Al', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 58: ('Ru3Cu', 'bridge', 'Ru_Ru|Cu', 'L12')
# 59: ('Ru3Cu', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 60: ('Ru3Al', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 61: ('Ru3Cu', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 62: ('Ru3Cu', 'top', 'Ru', 'L12')
# 63: ('Ru3Cu', 'top', 'Cu', 'L12')
# 64: ('Ru3Al', 'top', 'Ru', 'L12')
# 65: ('Ru3Al', 'top', 'Al', 'L12')
# 66: ('Ru3Bi', 'top', 'Ru', 'L12')
# 67: ('Ir2Rh2', 'top', 'Ir', 'L10')
# 68: ('Ir2Rh2', 'top', 'Rh', 'L10')
# 69: ('Os2Ir2', 'top', 'Os', 'L10')
# 70: ('Os3Ru', 'bridge', 'Os_Os|Os', 'L12')
# 71: ('Os3Ru', 'bridge', 'Os_Os|Ru', 'L12')
# 72: ('Os3Ru', 'bridge', 'Os_Ru|Os', 'L12')
# 73: ('Os3Ir', 'bridge', 'Os_Os|Os', 'L12')
# 74: ('Os2Ni2', 'top', 'Ni', 'L10')
# 75: ('Os3Co', 'bridge', 'Os_Co|Os', 'L12')
# 76: ('Os2Ni2', 'top', 'Os', 'L10')
# 77: ('Os3Co', 'bridge', 'Os_Os|Os', 'L12')
# 78: ('Os3Co', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 79: ('Os2Ir2', 'bridge', 'Ir_Ir|Os', 'L10')
# 80: ('Os2Rh2', 'bridge', 'Rh_Rh|Os', 'L10')
# 81: ('Os3Co', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 82: ('Os3Ru', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 83: ('Os2Rh2', 'top', 'Os', 'L10')
# 84: ('Os3Co', 'hollow', 'Os_Os_Co|FCC', 'L12')
# 85: ('Os3Ir', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 86: ('Os2Co2', 'bridge', 'Os_Os|Co', 'L10')
# 87: ('Os2Co2', 'top', 'Os', 'L10')
# 88: ('Os2Rh2', 'top', 'Rh', 'L10')
# 89: ('Os2Ni2', 'bridge', 'Os_Os|Ni', 'L10')
# 90: ('Os2Co2', 'hollow', 'Co_Co_Os|FCC', 'L10')
# 91: ('Os2Ir2', 'hollow', 'Ir_Ir_Os|FCC', 'L10')
# 92: ('Os2Co2', 'hollow', 'Co_Os_Os|HCP', 'L10')
# 93: ('Os3Co', 'top', 'Os', 'L12')
# 94: ('Os2Co2', 'bridge', 'Co_Co|Os', 'L10')
# 95: ('Os2Co2', 'top', 'Co', 'L10')
# 96: ('Os3Ru', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 97: ('Os2Co2', 'bridge', 'Co_Os|Co', 'L10')
# 98: ('Os3Ir', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 99: ('Os2Ir2', 'top', 'Ir', 'L10')
# 100: ('Os2Ru2', 'bridge', 'Os_Os|Ru', 'L10')
# 101: ('Os3Ru', 'hollow', 'Os_Os_Ru|FCC', 'L12')
# 102: ('Os3Co', 'top', 'Co', 'L12')
# 103: ('Os3Ir', 'top', 'Os', 'L12')
# 104: ('Os2Ru2', 'bridge', 'Os_Ru|Os', 'L10')
# 105: ('Os3Ru', 'hollow', 'Os_Os_Ru|HCP', 'L12')
# 106: ('Os3Ir', 'top', 'Ir', 'L12')
# 107: ('Os2Ru2', 'bridge', 'Os_Ru|Ru', 'L10')
# 108: ('Os3Ru', 'top', 'Os', 'L12')
# 109: ('Os2Ru2', 'bridge', 'Ru_Ru|Os', 'L10')
# 110: ('Os3Ru', 'top', 'Ru', 'L12')
# 111: ('Os2Ru2', 'hollow', 'Os_Os_Ru|FCC', 'L10')
# 112: ('Os2Ru2', 'hollow', 'Os_Os_Ru|HCP', 'L10')
# 113: ('Ir2Ni2', 'bridge', 'Ir_Ni|Ir', 'L10')
# 114: ('Os2Ru2', 'hollow', 'Os_Ru_Ru|FCC', 'L10')
# 115: ('Os3Rh', 'bridge', 'Os_Os|Os', 'L12')
# 116: ('Ir2Ni2', 'top', 'Ir', 'L10')
# 117: ('Ir2Ni2', 'top', 'Ni', 'L10')
# 118: ('Ir2Co2', 'hollow', 'Co_Co_Ir|FCC', 'L10')
# 119: ('Ir2Co2', 'hollow', 'Co_Ir_Ir|HCP', 'L10')
# 120: ('Os2Ru2', 'hollow', 'Os_Ru_Ru|HCP', 'L10')
# 121: ('Os3Rh', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 122: ('Ir2Co2', 'top', 'Co', 'L10')
# 123: ('Os2Ru2', 'top', 'Os', 'L10')
# 124: ('Os3Rh', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 125: ('Ir2Co2', 'bridge', 'Co_Ir|Co', 'L10')
# 126: ('Ir2Co2', 'top', 'Ir', 'L10')
# 127: ('Os2Ru2', 'top', 'Ru', 'L10')
# 128: ('Os3Rh', 'top', 'Os', 'L12')
# 129: ('Os3Rh', 'top', 'Rh', 'L12')
# 130: ('Ir2Fe2', 'hollow', 'Fe_Fe_Ir|FCC', 'L10')
# 131: ('Ir2Fe2', 'top', 'Fe', 'L10')
# 132: ('Os3Ni', 'bridge', 'Os_Os|Os', 'L12')
# 133: ('Ir2Fe2', 'top', 'Ir', 'L10')
# 134: ('Os3Ni', 'bridge', 'Os_Os|Ni', 'L12')
# 135: ('Os3Ni', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 136: ('Os3Ni', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 137: ('Os3Ni', 'top', 'Os', 'L12')
# 138: ('Os3Ni', 'top', 'Ni', 'L12')
# 139: ('Ir3Pt', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 140: ('Ir3Pt', 'top', 'Ir', 'L12')
# 141: ('Ir3Pt', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 142: ('Ir3Pt', 'top', 'Pt', 'L12')
# 143: ('Os3Ag', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 144: ('Os3Ag', 'top', 'Os', 'L12')
# 145: ('Os3Ag', 'bridge', 'Os_Os|Os', 'L12')
# 146: ('Os3Ag', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 147: ('Os3Ag', 'top', 'Ag', 'L12')
# 148: ('Os3Ag', 'bridge', 'Os_Os|Ag', 'L12')
# 149: ('Ir3Fe', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 150: ('Ir3Fe', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 151: ('Ir3Fe', 'top', 'Ir', 'L12')
# 152: ('Ir2Pt2', 'top', 'Ir', 'L10')
# 153: ('Ir3Fe', 'top', 'Fe', 'L12')
# 154: ('Os2Fe2', 'bridge', 'Fe_Os|Os', 'L10')
# 155: ('Os3Cu', 'bridge', 'Os_Os|Os', 'L12')
# 156: ('Os3Cu', 'top', 'Os', 'L12')
# 157: ('Os3Cu', 'bridge', 'Os_Os|Cu', 'L12')
# 158: ('Os3Cu', 'top', 'Cu', 'L12')
# 159: ('Os3Cu', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 160: ('Os2Pd2', 'bridge', 'Pd_Pd|Os', 'L10')
# 161: ('Os3Cu', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 162: ('Os2Pd2', 'top', 'Os', 'L10')
# 163: ('Os2Fe2', 'bridge', 'Os_Os|Fe', 'L10')
# 164: ('Os2Pd2', 'top', 'Pd', 'L10')
# 165: ('Os2Ag2', 'top', 'Os', 'L10')
# 166: ('Os2Fe2', 'hollow', 'Fe_Fe_Os|FCC', 'L10')
# 167: ('Os3Au', 'bridge', 'Os_Os|Os', 'L12')
# 168: ('Os3Au', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 169: ('Os2Fe2', 'hollow', 'Fe_Fe_Os|HCP', 'L10')
# 170: ('Os3Au', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 171: ('Os2Fe2', 'hollow', 'Fe_Os_Os|FCC', 'L10')
# 172: ('Os3Au', 'top', 'Os', 'L12')
# 173: ('Os3Au', 'top', 'Au', 'L12')
# 174: ('Os2Fe2', 'hollow', 'Fe_Os_Os|HCP', 'L10')
# 175: ('Os2Fe2', 'top', 'Fe', 'L10')
# 176: ('Os3Pt', 'bridge', 'Os_Os|Os', 'L12')
# 177: ('Os3Pt', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 178: ('Os3Pt', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 179: ('Os3Pt', 'top', 'Os', 'L12')
# 180: ('Os3Pt', 'top', 'Pt', 'L12')
# 181: ('Ir2Pt2', 'top', 'Pt', 'L10')
# 182: ('Os2Cu2', 'bridge', 'Cu_Cu|Os', 'L10')
# 183: ('Os2Cu2', 'bridge', 'Os_Os|Cu', 'L10')
# 184: ('Os2Pt2', 'bridge', 'Pt_Pt|Os', 'L10')
# 185: ('Os2Al2', 'top', 'Os', 'L10')
# 186: ('Os2Pt2', 'top', 'Os', 'L10')
# 187: ('Os2Pt2', 'top', 'Pt', 'L10')
# 188: ('Ir2Pd2', 'top', 'Ir', 'L10')
# 189: ('Ir2Pd2', 'top', 'Pd', 'L10')
# 190: ('Ir3Os', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 191: ('Ir3Pd', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 192: ('Ir3Pd', 'top', 'Ir', 'L12')
# 193: ('Ir3Pd', 'top', 'Pd', 'L12')
# 194: ('Ir3Os', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 195: ('Ir3Au', 'top', 'Au', 'L12')
# 196: ('Os2Ga2', 'top', 'Os', 'L10')
# 197: ('Ir3Os', 'top', 'Ir', 'L12')
# 198: ('Ir3Au', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 199: ('Ir3Au', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 200: ('Ir3Au', 'top', 'Ir', 'L12')
# 201: ('Ir3Os', 'top', 'Os', 'L12')
# 202: ('Os3Pd', 'bridge', 'Os_Os|Os', 'L12')
# 203: ('Os3Pd', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 204: ('Os3Pd', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 205: ('Os3Pd', 'top', 'Os', 'L12')
# 206: ('Os3Pd', 'top', 'Pd', 'L12')
# 207: ('Ga', 'top', 'Ga', 'A1')
# 208: ('Ir2Au2', 'top', 'Au', 'L10')
# 209: ('Ir2Au2', 'top', 'Ir', 'L10')
# 210: ('Ir3Ag', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 211: ('Ir3Ag', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 212: ('Os3Al', 'bridge', 'Os_Os|Os', 'L12')
# 213: ('Ir3Ag', 'top', 'Ir', 'L12')
# 214: ('Ir3Ag', 'top', 'Ag', 'L12')
# 215: ('Os3Al', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 216: ('Os2Sn2', 'top', 'Os', 'L10')
# 217: ('Ir2Ag2', 'top', 'Ir', 'L10')
# 218: ('Ir2Ag2', 'bridge', 'Ir_Ir|Ag', 'L10')
# 219: ('Os2Sn2', 'top', 'Sn', 'L10')
# 220: ('Ir2Ag2', 'top', 'Ag', 'L10')
# 221: ('Ir2Cu2', 'top', 'Ir', 'L10')
# 222: ('Ir3Al', 'bridge', 'Ir_Ir|Al', 'L12')
# 223: ('Os3Sn', 'bridge', 'Os_Os|Sn', 'L12')
# 224: ('Os3Sn', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 225: ('Ir3Cu', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 226: ('Os3Sn', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 227: ('Ir3Cu', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 228: ('Ir3Cu', 'top', 'Ir', 'L12')
# 229: ('Os3Sn', 'top', 'Os', 'L12')
# 230: ('Ir3Cu', 'top', 'Cu', 'L12')
# 231: ('Ir3Al', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 232: ('Ir3Al', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 233: ('Ir3Al', 'top', 'Ir', 'L12')
# 234: ('Ir3Al', 'top', 'Al', 'L12')
# 235: ('Ru3Os', 'bridge', 'Ru_Ru|Ru', 'L12')
# 236: ('Ru3Os', 'bridge', 'Ru_Ru|Os', 'L12')
# 237: ('Ru3Os', 'bridge', 'Ru_Os|Ru', 'L12')
# 238: ('Ru3Os', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 239: ('Ru3Ir', 'bridge', 'Ru_Ru|Ir', 'L12')
# 240: ('Os3Bi', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 241: ('Ru3Ir', 'bridge', 'Ru_Ir|Ru', 'L12')
# 242: ('Ru3Os', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 243: ('Ir3Ru', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 244: ('Os3Bi', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 245: ('Ru3Ir', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 246: ('Ru2Ir2', 'bridge', 'Ru_Ru|Ir', 'L10')
# 247: ('Ru3Rh', 'bridge', 'Ru_Ru|Ru', 'L12')
# 248: ('Ru3Rh', 'bridge', 'Ru_Ru|Rh', 'L12')
# 249: ('Ru3Os', 'hollow', 'Ru_Ru_Os|FCC', 'L12')
# 250: ('Ru3Ir', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 251: ('Ru2Ir2', 'hollow', 'Ir_Ir_Ru|FCC', 'L10')
# 252: ('Ru3Rh', 'bridge', 'Ru_Rh|Ru', 'L12')
# 253: ('Ru2Rh2', 'bridge', 'Rh_Ru|Rh', 'L10')
# 254: ('Ru3Os', 'hollow', 'Ru_Ru_Os|HCP', 'L12')
# 255: ('Ru3Ir', 'hollow', 'Ru_Ru_Ir|FCC', 'L12')
# 256: ('Ru3Rh', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 257: ('Ir3Ru', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 258: ('Ru3Rh', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 259: ('Ir3Ru', 'hollow', 'Ir_Ir_Ru|FCC', 'L12')
# 260: ('Ru3Rh', 'top', 'Ru', 'L12')
# 261: ('Ir3Ru', 'top', 'Ir', 'L12')
# 262: ('Ru2Ir2', 'hollow', 'Ir_Ir_Ru|HCP', 'L10')
# 263: ('Ru3Rh', 'top', 'Rh', 'L12')
# 264: ('Ir3Ru', 'top', 'Ru', 'L12')
# 265: ('Ru3Ir', 'hollow', 'Ru_Ru_Ir|HCP', 'L12')
# 266: ('Ru2Rh2', 'bridge', 'Rh_Ru|Ru', 'L10')
# 267: ('Ru3Os', 'top', 'Ru', 'L12')
# 268: ('Ru2Ir2', 'hollow', 'Ir_Ru_Ru|FCC', 'L10')
# 269: ('Ru3Os', 'top', 'Os', 'L12')
# 270: ('Ru2Rh2', 'bridge', 'Ru_Ru|Rh', 'L10')
# 271: ('Ru2Ir2', 'top', 'Ir', 'L10')
# 272: ('Ru2Rh2', 'hollow', 'Rh_Rh_Ru|FCC', 'L10')
# 273: ('Ru2Ir2', 'top', 'Ru', 'L10')
# 274: ('Ru2Rh2', 'hollow', 'Rh_Ru_Ru|FCC', 'L10')
# 275: ('Ru2Rh2', 'hollow', 'Rh_Ru_Ru|HCP', 'L10')
# 276: ('Ru3Co', 'bridge', 'Ru_Co|Ru', 'L12')
# 277: ('Ir2Al2', 'top', 'Al', 'L10')
# 278: ('Ru2Rh2', 'top', 'Rh', 'L10')
# 279: ('Ru3Co', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 280: ('Ru3Co', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 281: ('Ru3Co', 'hollow', 'Ru_Ru_Co|FCC', 'L12')
# 282: ('Ru2Rh2', 'top', 'Ru', 'L10')
# 283: ('Ru3Co', 'hollow', 'Ru_Ru_Co|HCP', 'L12')
# 284: ('Ru3Co', 'top', 'Co', 'L12')
# 285: ('Ru3Ni', 'bridge', 'Ru_Ru|Ru', 'L12')
# 286: ('Ru3Ni', 'bridge', 'Ru_Ru|Ni', 'L12')
# 287: ('Ir2Sn2', 'top', 'Sn', 'L10')
# 288: ('Ir3Bi', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 289: ('Ir3Bi', 'top', 'Ir', 'L12')
# 290: ('Ru3Ni', 'bridge', 'Ru_Ni|Ru', 'L12')
# 291: ('Ir3Bi', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 292: ('Ru3Ni', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 293: ('Rh3Os', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 294: ('Ir3Sn', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 295: ('Rh3Os', 'top', 'Rh', 'L12')
# 296: ('Ru3Ni', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 297: ('Ir2Ga2', 'top', 'Ga', 'L10')
# 298: ('Rh3Os', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 299: ('Rh3Os', 'top', 'Os', 'L12')
# 300: ('Ir3Sn', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 301: ('Ir3Sn', 'top', 'Ir', 'L12')
# 302: ('Ru3Ni', 'hollow', 'Ru_Ru_Ni|FCC', 'L12')
# 303: ('Rh3Ru', 'bridge', 'Rh_Ru|Rh', 'L12')
# 304: ('Ir3Ga', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 305: ('Rh3Ru', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 306: ('Rh3Ru', 'hollow', 'Rh_Rh_Ru|FCC', 'L12')
# 307: ('Ir3Ga', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 308: ('Rh3Ru', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 309: ('Rh3Ru', 'top', 'Rh', 'L12')
# 310: ('Ir3Ga', 'top', 'Ir', 'L12')
# 311: ('Rh3Ru', 'top', 'Ru', 'L12')
# 312: ('Ru3Ni', 'top', 'Ru', 'L12')
# 313: ('Rh3Ir', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 314: ('Rh3Ir', 'top', 'Rh', 'L12')
# 315: ('Rh3Ir', 'top', 'Ir', 'L12')
# 316: ('Ru2Fe2', 'bridge', 'Fe_Fe|Ru', 'L10')
# 317: ('Ru2Fe2', 'bridge', 'Fe_Ru|Fe', 'L10')
# 318: ('Ru2Fe2', 'bridge', 'Fe_Ru|Ru', 'L10')
# 319: ('Ru2Co2', 'bridge', 'Co_Co|Ru', 'L10')
# 320: ('Ru2Co2', 'bridge', 'Co_Ru|Co', 'L10')
# 321: ('Ru2Fe2', 'hollow', 'Fe_Fe_Ru|FCC', 'L10')
# 322: ('Ru2Co2', 'bridge', 'Ru_Ru|Co', 'L10')
# 323: ('Ru2Co2', 'hollow', 'Co_Co_Ru|FCC', 'L10')
# 324: ('Ru2Fe2', 'hollow', 'Fe_Fe_Ru|HCP', 'L10')
# 325: ('Ir3Rh', 'bridge', 'Ir_Rh|Ir', 'L12')
# 326: ('Ir3Rh', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 327: ('Ru2Co2', 'hollow', 'Co_Co_Ru|HCP', 'L10')
# 328: ('Ru2Fe2', 'hollow', 'Fe_Ru_Ru|HCP', 'L10')
# 329: ('Ir3Rh', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 330: ('Rh2Ni2', 'hollow', 'Ni_Ni_Rh|HCP', 'L10')
# 331: ('Ru2Co2', 'hollow', 'Co_Ru_Ru|FCC', 'L10')
# 332: ('Ir3Rh', 'top', 'Ir', 'L12')
# 333: ('Ru2Fe2', 'top', 'Fe', 'L10')
# 334: ('Ru2Co2', 'hollow', 'Co_Ru_Ru|HCP', 'L10')
# 335: ('Rh2Co2', 'bridge', 'Co_Co|Rh', 'L10')
# 336: ('Ir3Rh', 'top', 'Rh', 'L12')
# 337: ('Ru2Fe2', 'top', 'Ru', 'L10')
# 338: ('Ru2Co2', 'top', 'Co', 'L10')
# 339: ('Ru3Ir', 'top', 'Ru', 'L12')
# 340: ('Rh2Co2', 'bridge', 'Co_Rh|Co', 'L10')
# 341: ('Ru3Ir', 'top', 'Ir', 'L12')
# 342: ('Ru2Co2', 'top', 'Ru', 'L10')
# 343: ('Rh2Co2', 'bridge', 'Co_Rh|Rh', 'L10')
# 344: ('Rh2Co2', 'bridge', 'Rh_Rh|Co', 'L10')
# 345: ('Rh2Co2', 'hollow', 'Co_Co_Rh|FCC', 'L10')
# 346: ('Rh2Co2', 'hollow', 'Co_Co_Rh|HCP', 'L10')
# 347: ('Ru2Ni2', 'bridge', 'Ni_Ni|Ru', 'L10')
# 348: ('Ru2Ni2', 'bridge', 'Ni_Ru|Ni', 'L10')
# 349: ('Rh2Co2', 'hollow', 'Co_Rh_Rh|FCC', 'L10')
# 350: ('Ru2Ni2', 'bridge', 'Ni_Ru|Ru', 'L10')
# 351: ('Rh2Co2', 'hollow', 'Co_Rh_Rh|HCP', 'L10')
# 352: ('Rh2Pd2', 'top', 'Pd', 'L10')
# 353: ('Rh2Co2', 'top', 'Co', 'L10')
# 354: ('Ru2Ni2', 'bridge', 'Ru_Ru|Ni', 'L10')
# 355: ('Rh3Au', 'top', 'Au', 'L12')
# 356: ('Rh2Co2', 'top', 'Rh', 'L10')
# 357: ('Ru2Ni2', 'hollow', 'Ni_Ni_Ru|FCC', 'L10')
# 358: ('Rh2Au2', 'top', 'Rh', 'L10')
# 359: ('Ru2Ni2', 'hollow', 'Ni_Ru_Ru|FCC', 'L10')
# 360: ('Rh2Au2', 'top', 'Au', 'L10')
# 361: ('Rh2Pd2', 'top', 'Rh', 'L10')
# 362: ('Ru2Ni2', 'hollow', 'Ni_Ru_Ru|HCP', 'L10')
# 363: ('Ru2Ni2', 'top', 'Ni', 'L10')
# 364: ('Rh3Au', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 365: ('Rh3Au', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 366: ('Rh3Au', 'top', 'Rh', 'L12')
# 367: ('Ru2Ni2', 'top', 'Ru', 'L10')
# 368: ('Rh2Pt2', 'top', 'Pt', 'L10')
# 369: ('Rh3Pd', 'bridge', 'Rh_Rh|Rh', 'L12')
# 370: ('Rh3Pd', 'bridge', 'Rh_Pd|Rh', 'L12')
# 371: ('Rh2Pt2', 'top', 'Rh', 'L10')
# 372: ('Rh3Pd', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 373: ('Rh3Sn', 'top', 'Rh', 'L12')
# 374: ('Rh3Pd', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 375: ('Rh3Sn', 'top', 'Sn', 'L12')
# 376: ('Rh3Pd', 'top', 'Rh', 'L12')
# 377: ('Rh3Pd', 'top', 'Pd', 'L12')
# 378: ('Ni3Fe', 'bridge', 'Ni_Fe|Ni', 'L12')
# 379: ('Ni3Fe', 'hollow', 'Ni_Ni_Fe|HCP', 'L12')
# 380: ('Ni3Fe', 'hollow', 'Ni_Ni_Ni|HCP', 'L12')
# 381: ('Ni3Fe', 'top', 'Ni', 'L12')
# 382: ('Ni3Fe', 'top', 'Fe', 'L12')
# 383: ('Ni2Fe2', 'bridge', 'Fe_Ni|Ni', 'L10')
# 384: ('Ni2Fe2', 'hollow', 'Fe_Fe_Ni|FCC', 'L10')
# 385: ('Ni2Fe2', 'top', 'Fe', 'L10')
# 386: ('Ni2Pt2', 'bridge', 'Ni_Ni|Pt', 'L10')
# 387: ('Ni2Pt2', 'top', 'Pt', 'L10')
# 388: ('Ni2Pt2', 'top', 'Ni', 'L10')
# 389: ('Ni3Pd', 'hollow', 'Ni_Ni_Ni|FCC', 'L12')
# 390: ('Rh3Pt', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 391: ('Ni2Pd2', 'top', 'Ni', 'L10')
# 392: ('Ni2Pd2', 'top', 'Pd', 'L10')
# 393: ('Rh3Ag', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 394: ('Rh2Ag2', 'top', 'Rh', 'L10')
# 395: ('Rh2Cu2', 'bridge', 'Rh_Rh|Cu', 'L10')
# 396: ('Ni3Au', 'top', 'Ni', 'L12')
# 397: ('Rh3Ag', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 398: ('Rh2Cu2', 'top', 'Rh', 'L10')
# 399: ('Rh3Ag', 'top', 'Rh', 'L12')
# 400: ('Ni3Au', 'bridge', 'Ni_Ni|Au', 'L12')
# 401: ('Rh3Ag', 'top', 'Ag', 'L12')
# 402: ('Rh2Ag2', 'bridge', 'Rh_Rh|Ag', 'L10')
# 403: ('Ni3Au', 'hollow', 'Ni_Ni_Ni|HCP', 'L12')
# 404: ('Rh2Cu2', 'bridge', 'Cu_Cu|Rh', 'L10')
# 405: ('Rh2Ag2', 'top', 'Ag', 'L10')
# 406: ('Rh2Cu2', 'top', 'Cu', 'L10')
# 407: ('Ni2Au2', 'bridge', 'Au_Au|Ni', 'L10')
# 408: ('Ni3Ag', 'bridge', 'Ni_Ni|Ni', 'L12')
# 409: ('Ni3Ag', 'bridge', 'Ni_Ni|Ag', 'L12')
# 410: ('Ni2Ag2', 'top', 'Ni', 'L10')
# 411: ('Ni2Au2', 'top', 'Au', 'L10')
# 412: ('Ni3Ag', 'hollow', 'Ni_Ni_Ni|FCC', 'L12')
# 413: ('Rh3Pt', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 414: ('Ni2Au2', 'top', 'Ni', 'L10')
# 415: ('Ni2Ag2', 'bridge', 'Ni_Ni|Ag', 'L10')
# 416: ('Rh3Pt', 'top', 'Rh', 'L12')
# 417: ('Rh3Pt', 'top', 'Pt', 'L12')
# 418: ('Rh2Sn2', 'top', 'Rh', 'L10')
# 419: ('Rh2Sn2', 'top', 'Sn', 'L10')
# 420: ('Ni3Sn', 'top', 'Ni', 'L12')
# 421: ('Ni3Sn', 'hollow', 'Ni_Ni_Ni|FCC', 'L12')
# 422: ('Ni3Sn', 'top', 'Sn', 'L12')
# 423: ('Rh3Cu', 'bridge', 'Rh_Rh|Rh', 'L12')
# 424: ('Ni3Sn', 'hollow', 'Ni_Ni_Ni|HCP', 'L12')
# 425: ('Ni2Sn2', 'top', 'Ni', 'L10')
# 426: ('Ni2Sn2', 'top', 'Sn', 'L10')
# 427: ('Rh2Bi2', 'top', 'Bi', 'L10')
# 428: ('Rh2Bi2', 'top', 'Rh', 'L10')
# 429: ('Rh3Bi', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 430: ('Rh3Cu', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 431: ('Ni3Ga', 'bridge', 'Ni_Ni|Ni', 'L12')
# 432: ('Rh3Bi', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 433: ('Ni2Cu2', 'bridge', 'Cu_Cu|Ni', 'L10')
# 434: ('Rh3Cu', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 435: ('Rh3Cu', 'top', 'Rh', 'L12')
# 436: ('Ni3Ga', 'hollow', 'Ni_Ni_Ni|FCC', 'L12')
# 437: ('Rh3Cu', 'top', 'Cu', 'L12')
# 438: ('Ni3Al', 'bridge', 'Ni_Ni|Ni', 'L12')
# 439: ('Rh3Bi', 'top', 'Rh', 'L12')
# 440: ('Ni2Cu2', 'bridge', 'Cu_Ni|Ni', 'L10')
# 441: ('Ni3Al', 'bridge', 'Ni_Ni|Al', 'L12')
# 442: ('Ni3Ga', 'hollow', 'Ni_Ni_Ni|HCP', 'L12')
# 443: ('Ni3Al', 'hollow', 'Ni_Ni_Ni|FCC', 'L12')
# 444: ('Ni3Ga', 'top', 'Ni', 'L12')
# 445: ('Ni3Al', 'hollow', 'Ni_Ni_Ni|HCP', 'L12')
# 446: ('Ni2Al2', 'bridge', 'Al_Ni|Al', 'L10')
# 447: ('Ni3Ga', 'top', 'Ga', 'L12')
# 448: ('Rh3Bi', 'top', 'Bi', 'L12')
# 449: ('Ni2Cu2', 'bridge', 'Ni_Ni|Cu', 'L10')
# 450: ('Ni3Al', 'hollow', 'Ni_Ni_Al|FCC', 'L12')
# 451: ('Ni2Al2', 'bridge', 'Al_Ni|Ni', 'L10')
# 452: ('Ni2Cu2', 'hollow', 'Cu_Cu_Ni|HCP', 'L10')
# 453: ('Ni3Al', 'hollow', 'Ni_Ni_Al|HCP', 'L12')
# 454: ('Ni2Cu2', 'top', 'Cu', 'L10')
# 455: ('Ni3Al', 'top', 'Al', 'L12')
# 456: ('Ni2Cu2', 'top', 'Ni', 'L10')
# 457: ('Ni2Ga2', 'top', 'Ni', 'L10')
# 458: ('Co2Cu2', 'bridge', 'Co_Co|Cu', 'L10')
# 459: ('Co2Cu2', 'bridge', 'Cu_Cu|Co', 'L10')
# 460: ('Co2Cu2', 'top', 'Co', 'L10')
# 461: ('Co2Cu2', 'hollow', 'Co_Co_Cu|FCC', 'L10')
# 462: ('Co2Cu2', 'top', 'Cu', 'L10')
# 463: ('Ni2Al2', 'top', 'Al', 'L10')
# 464: ('Co2Cu2', 'hollow', 'Co_Cu_Cu|FCC', 'L10')
# 465: ('Co2Cu2', 'hollow', 'Co_Cu_Cu|HCP', 'L10')
# 466: ('Co3Ag', 'bridge', 'Co_Co|Ag', 'L12')
# 467: ('Co3Ag', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 468: ('Co3Ag', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 469: ('Co3Ag', 'top', 'Co', 'L12')
# 470: ('Co3Ag', 'top', 'Ag', 'L12')
# 471: ('Co3Ga', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 472: ('Co3Ga', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 473: ('Co3Ga', 'top', 'Co', 'L12')
# 474: ('Co2Ga2', 'bridge', 'Ga_Ga|Co', 'L10')
# 475: ('Co2Ga2', 'top', 'Ga', 'L10')
# 476: ('Hf', 'hollow', 'Hf_Hf_Hf|FCC', 'A1')
# 477: ('Rh3Ga', 'bridge', 'Rh_Rh|Ga', 'L12')
# 478: ('Rh3Ga', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 479: ('Rh3Ga', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 480: ('Hf', 'hollow', 'Hf_Hf_Hf|HCP', 'A1')
# 481: ('Rh3Ga', 'top', 'Rh', 'L12')
# 482: ('Rh3Ga', 'top', 'Ga', 'L12')
# 483: ('Hf', 'top', 'Hf', 'A1')
# 484: ('Fe2Ag2', 'bridge', 'Fe_Fe|Ag', 'L10')
# 485: ('Fe2Ag2', 'bridge', 'Ag_Ag|Fe', 'L10')
# 486: ('Fe2Ag2', 'top', 'Ag', 'L10')
# 487: ('Fe2Ag2', 'top', 'Fe', 'L10')
# 488: ('Rh2Ga2', 'top', 'Ga', 'L10')
# 489: ('Rh2Ga2', 'top', 'Rh', 'L10')
# 490: ('Rh3Sn', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 491: ('Rh3Sn', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 492: ('Au3Al', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 493: ('La', 'bridge', 'La_La|La', 'A1')
# 494: ('La', 'hollow', 'La_La_La|FCC', 'A1')
# 495: ('La', 'hollow', 'La_La_La|HCP', 'A1')
# 496: ('La', 'top', 'La', 'A1')
# 497: ('Au3Bi', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 498: ('Au3Bi', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 499: ('Au3Bi', 'top', 'Au', 'L12')
# 500: ('Au3Cu', 'bridge', 'Au_Cu|Au', 'L12')
# 501: ('Au3Cu', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 502: ('Au3Cu', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 503: ('Au3Cu', 'top', 'Au', 'L12')
# 504: ('Au3Cu', 'top', 'Cu', 'L12')
# 505: ('Au3Ga', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 506: ('Au3Ga', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 507: ('Au3Ga', 'top', 'Au', 'L12')
# 508: ('Au3Sn', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 509: ('Au3Sn', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 510: ('Au3Sn', 'top', 'Au', 'L12')
# 511: ('Au2Al2', 'top', 'Al', 'L10')
# 512: ('Pt2Au2', 'top', 'Pt', 'L10')
# 513: ('Pt2Au2', 'bridge', 'Au_Au|Pt', 'L10')
# 514: ('Au2Sn2', 'top', 'Au', 'L10')
# 515: ('Pt2Au2', 'top', 'Au', 'L10')
# 516: ('Au2Bi2', 'top', 'Au', 'L10')
# 517: ('Cu2Bi2', 'top', 'Cu', 'L10')
# 518: ('Au2Bi2', 'top', 'Bi', 'L10')
# 519: ('Pd2Bi2', 'top', 'Bi', 'L10')
# 520: ('Pd2Bi2', 'top', 'Pd', 'L10')
# 521: ('Co3Sn', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 522: ('Co3Sn', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 523: ('Co2Sn2', 'top', 'Co', 'L10')
# 524: ('Co2Sn2', 'top', 'Sn', 'L10')
# 525: ('Cu3Bi', 'bridge', 'Cu_Cu|Bi', 'L12')
# 526: ('Cu3Bi', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 527: ('Cu3Bi', 'top', 'Cu', 'L12')
# 528: ('Cu3Bi', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 529: ('Cu3Ga', 'bridge', 'Cu_Cu|Cu', 'L12')
# 530: ('Cu3Ga', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 531: ('Cu3Ga', 'top', 'Cu', 'L12')
# 532: ('Cu3Ga', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 533: ('Cu3Sn', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 534: ('Cu3Sn', 'top', 'Cu', 'L12')
# 535: ('Au2Cu2', 'top', 'Au', 'L10')
# 536: ('Au2Cu2', 'top', 'Cu', 'L10')
# 537: ('Cu3Sn', 'bridge', 'Cu_Cu|Cu', 'L12')
# 538: ('Cu3Sn', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 539: ('Au2Cu2', 'bridge', 'Cu_Cu|Au', 'L10')
# 540: ('Cu2Ga2', 'top', 'Cu', 'L10')
# 541: ('Pt2Cu2', 'top', 'Cu', 'L10')
# 542: ('Pt2Cu2', 'top', 'Pt', 'L10')
# 543: ('Fe3Ag', 'hollow', 'Fe_Fe_Fe|HCP', 'L12')
# 544: ('Fe3Al', 'bridge', 'Fe_Fe|Al', 'L12')
# 545: ('Fe3Al', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 546: ('Fe3Al', 'hollow', 'Fe_Fe_Al|FCC', 'L12')
# 547: ('Fe3Al', 'hollow', 'Fe_Fe_Al|HCP', 'L12')
# 548: ('Fe3Al', 'top', 'Al', 'L12')
# 549: ('Fe3Al', 'hollow', 'Fe_Fe_Fe|HCP', 'L12')
# 550: ('Fe3Al', 'top', 'Fe', 'L12')
# 551: ('Fe3Cu', 'bridge', 'Fe_Cu|Fe', 'L12')
# 552: ('Fe3Cu', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 553: ('Fe3Cu', 'hollow', 'Fe_Fe_Fe|HCP', 'L12')
# 554: ('Fe3Cu', 'hollow', 'Fe_Fe_Cu|FCC', 'L12')
# 555: ('Fe3Cu', 'hollow', 'Fe_Fe_Cu|HCP', 'L12')
# 556: ('Fe3Cu', 'top', 'Fe', 'L12')
# 557: ('Fe3Ga', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 558: ('Fe3Ga', 'hollow', 'Fe_Fe_Fe|HCP', 'L12')
# 559: ('Fe3Ga', 'top', 'Fe', 'L12')
# 560: ('Fe3Ga', 'top', 'Ga', 'L12')
# 561: ('Fe3Sn', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 562: ('Fe3Sn', 'hollow', 'Fe_Fe_Fe|HCP', 'L12')
# 563: ('Fe3Sn', 'top', 'Fe', 'L12')
# 564: ('Fe3Sn', 'top', 'Sn', 'L12')
# 565: ('Fe2Al2', 'bridge', 'Al_Al|Fe', 'L10')
# 566: ('Fe2Al2', 'top', 'Al', 'L10')
# 567: ('Fe', 'bridge', 'Fe_Fe|Fe', 'A1')
# 568: ('Fe2Cu2', 'bridge', 'Cu_Cu|Fe', 'L10')
# 569: ('Fe2Cu2', 'bridge', 'Fe_Fe|Cu', 'L10')
# 570: ('Fe2Cu2', 'hollow', 'Cu_Cu_Fe|HCP', 'L10')
# 571: ('Fe2Cu2', 'top', 'Cu', 'L10')
# 572: ('Fe2Cu2', 'top', 'Fe', 'L10')
# 573: ('Fe2Ga2', 'bridge', 'Fe_Fe|Ga', 'L10')
# 574: ('Fe2Ga2', 'top', 'Fe', 'L10')
# 575: ('Fe2Al2', 'hollow', 'Al_Al_Fe|HCP', 'L10')
# 576: ('Pd', 'hollow', 'Pd_Pd_Pd|FCC', 'A1')
# 577: ('Pd', 'top', 'Pd', 'A1')
# 578: ('Ag3Cu', 'bridge', 'Cu_Cu|Ag', 'L12')
# 579: ('Fe2Ga2', 'bridge', 'Ga_Ga|Fe', 'L10')
# 580: ('Fe2Sn2', 'bridge', 'Sn_Sn|Fe', 'L10')
# 581: ('Fe2Sn2', 'top', 'Sn', 'L10')
# 582: ('Ag3Cu', 'bridge', 'Cu_Cu|Cu', 'L12')
# 583: ('Ga3Au', 'top', 'Ga', 'L12')
# 584: ('Ga3Fe', 'top', 'Ga', 'L12')
# 585: ('Ga3Pd', 'top', 'Ga', 'L12')
# 586: ('Pd2Ga2', 'top', 'Ga', 'L10')
# 587: ('Pd2Ga2', 'top', 'Pd', 'L10')
# 588: ('Pt2Ga2', 'top', 'Pt', 'L10')
# 589: ('Ir3Co', 'top', 'Co', 'L12')
# 590: ('Mn', 'bridge', 'Mn_Mn|Mn', 'A1')
# 591: ('Ni3Au', 'top', 'Au', 'L12')
# 592: ('Os3Fe', 'bridge', 'Os_Fe|Fe', 'L12')
# 593: ('Os3Fe', 'bridge', 'Fe_Fe|Fe', 'L12')
# 594: ('Os3Fe', 'top', 'Os', 'L12')
# 595: ('Os3Fe', 'top', 'Fe', 'L12')
# 596: ('Pd3Ag', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 597: ('Pd3Ag', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 598: ('Pd3Ag', 'top', 'Pd', 'L12')
# 599: ('Ag3Cu', 'top', 'Ag', 'L12')
# 600: ('Pd3Ag', 'top', 'Ag', 'L12')
# 601: ('Pd3Al', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 602: ('Pd3Al', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 603: ('Pd3Al', 'top', 'Pd', 'L12')
# 604: ('Pd3Al', 'top', 'Al', 'L12')
# 605: ('Pd3Bi', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 606: ('Pd3Bi', 'top', 'Pd', 'L12')
# 607: ('Pd3Bi', 'top', 'Bi', 'L12')
# 608: ('Pd3Co', 'top', 'Pd', 'L12')
# 609: ('Pd3Co', 'top', 'Co', 'L12')
# 610: ('Pd3Cu', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 611: ('Pd3Cu', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 612: ('Pd3Cu', 'top', 'Pd', 'L12')
# 613: ('Pd3Fe', 'top', 'Pd', 'L12')
# 614: ('Ag3Cu', 'top', 'Cu', 'L12')
# 615: ('Pd3Bi', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 616: ('Pd3Cu', 'top', 'Cu', 'L12')
# 617: ('Pd3Fe', 'top', 'Fe', 'L12')
# 618: ('Ag3Fe', 'bridge', 'Fe_Fe|Fe', 'L12')
# 619: ('Pd3Ga', 'bridge', 'Pd_Pd|Ga', 'L12')
# 620: ('Pd3Ga', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 621: ('Pd3Ga', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 622: ('Pd3Ga', 'top', 'Pd', 'L12')
# 623: ('Pd3Ga', 'top', 'Ga', 'L12')
# 624: ('Pd3Pt', 'top', 'Pt', 'L12')
# 625: ('Pd3Rh', 'top', 'Pd', 'L12')
# 626: ('Pd3Rh', 'top', 'Rh', 'L12')
# 627: ('Pd3Ru', 'top', 'Pd', 'L12')
# 628: ('Pd3Ru', 'top', 'Ru', 'L12')
# 629: ('Pd3Sn', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 630: ('Pd3Sn', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 631: ('Pd3Sn', 'top', 'Pd', 'L12')
# 632: ('Pd3Sn', 'top', 'Sn', 'L12')
# 633: ('Pt3Ag', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 634: ('Pt3Ag', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 635: ('Pt3Ag', 'top', 'Pt', 'L12')
# 636: ('Pt3Ag', 'top', 'Ag', 'L12')
# 637: ('Pt3Al', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 638: ('Pt3Al', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 639: ('Pt3Al', 'top', 'Pt', 'L12')
# 640: ('Pt3Al', 'top', 'Al', 'L12')
# 641: ('Pt3Bi', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 642: ('Pt3Bi', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 643: ('Pt3Bi', 'top', 'Pt', 'L12')
# 644: ('Pt3Cu', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 645: ('Pt3Cu', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 646: ('Pt3Cu', 'top', 'Pt', 'L12')
# 647: ('Pt3Cu', 'top', 'Cu', 'L12')
# 648: ('Pt3Fe', 'top', 'Fe', 'L12')
# 649: ('Pt3Ga', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 650: ('Pt3Ga', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 651: ('Pt3Ga', 'top', 'Pt', 'L12')
# 652: ('Pt3Sn', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 653: ('Pt3Sn', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 654: ('Pt3Sn', 'top', 'Pt', 'L12')
# 655: ('Ag3Fe', 'top', 'Ag', 'L12')
# 656: ('Ag3Fe', 'top', 'Fe', 'L12')
# 657: ('Rh3Al', 'bridge', 'Al_Al|Rh', 'L12')
# 658: ('Rh3Al', 'top', 'Rh', 'L12')
# 659: ('Rh3Al', 'top', 'Al', 'L12')
# 660: ('Rh3Fe', 'bridge', 'Rh_Fe|Fe', 'L12')
# 661: ('Rh3Fe', 'bridge', 'Fe_Fe|Rh', 'L12')
# 662: ('Rh3Fe', 'bridge', 'Fe_Fe|Fe', 'L12')
# 663: ('Rh3Fe', 'top', 'Rh', 'L12')
# 664: ('Ru3Fe', 'bridge', 'Ru_Fe|Fe', 'L12')
# 665: ('Ru3Fe', 'bridge', 'Fe_Fe|Ru', 'L12')
# 666: ('Ru3Fe', 'bridge', 'Fe_Fe|Fe', 'L12')
# 667: ('Ru3Fe', 'top', 'Ru', 'L12')
# 668: ('Ru3Fe', 'top', 'Fe', 'L12')
# 669: ('Sn3Au', 'top', 'Sn', 'L12')
# 670: ('Ag3Ir', 'top', 'Ag', 'L12')
# 671: ('Rh3Fe', 'top', 'Fe', 'L12')
# 672: ('Ag3Ru', 'top', 'Ag', 'L12')
# 673: ('Ag3Ru', 'top', 'Ru', 'L12')
# 674: ('Pd2Ag2', 'top', 'Ag', 'L10')
# 675: ('Pt2Ag2', 'top', 'Ag', 'L10')
# 676: ('Pt2Ag2', 'top', 'Pt', 'L10')
# 677: ('Al3Co', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 678: ('Al3Co', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 679: ('Al3Co', 'top', 'Co', 'L12')
# 680: ('Pd2Al2', 'top', 'Al', 'L10')
# 681: ('Pd2Al2', 'top', 'Pd', 'L10')
# 682: ('Pt2Al2', 'bridge', 'Al_Pt|Al', 'L10')
# 683: ('Pt2Al2', 'top', 'Al', 'L10')
# 684: ('Au3Co', 'bridge', 'Au_Au|Co', 'L12')
# 685: ('Au3Co', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 686: ('Au3Co', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 687: ('Au3Co', 'top', 'Au', 'L12')
# 688: ('Au3Co', 'top', 'Co', 'L12')
# 689: ('Au3Ga', 'top', 'Ga', 'L12')
# 690: ('Au3Ni', 'top', 'Au', 'L12')
# 691: ('Au3Ni', 'top', 'Ni', 'L12')
# 692: ('Pt2Bi2', 'top', 'Bi', 'L10')
# 693: ('Pt2Bi2', 'top', 'Pt', 'L10')
# 694: ('Co3Al', 'bridge', 'Co_Al|Al', 'L12')
# 695: ('Co3Cu', 'bridge', 'Co_Cu|Cu', 'L12')
# 696: ('Co3Cu', 'bridge', 'Cu_Cu|Cu', 'L12')
# 697: ('Co3Cu', 'top', 'Co', 'L12')
# 698: ('Co3Cu', 'top', 'Cu', 'L12')
# 699: ('Cu3Al', 'bridge', 'Al_Al|Cu', 'L12')
# 700: ('Cu3Al', 'bridge', 'Al_Al|Al', 'L12')
# 701: ('Cu3Al', 'top', 'Cu', 'L12')
# 702: ('Cu3Al', 'top', 'Al', 'L12')
# 703: ('Ta', 'bridge', 'Ta_Ta|Ta', 'A1')
# 704: ('Cu3Co', 'bridge', 'Cu_Cu|Cu', 'L12')
# 705: ('Cu3Co', 'bridge', 'Cu_Co|Cu', 'L12')
# 706: ('Ta', 'hollow', 'Ta_Ta_Ta|FCC', 'A1')
# 707: ('Cu3Co', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 708: ('Cu3Co', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 709: ('Cu3Co', 'hollow', 'Cu_Cu_Co|HCP', 'L12')
# 710: ('Cu3Co', 'top', 'Cu', 'L12')
# 711: ('Cu3Co', 'top', 'Co', 'L12')
# 712: ('Ta', 'top', 'Ta', 'A1')
# 713: ('Cu2Sn2', 'top', 'Sn', 'L10')
# 714: ('Zr', 'hollow', 'Zr_Zr_Zr|FCC', 'A1')
# 715: ('Zr', 'hollow', 'Zr_Zr_Zr|HCP', 'A1')
# 716: ('Zr', 'top', 'Zr', 'A1')
# 717: ('W', 'top', 'W', 'A1')
# 718: ('Y', 'bridge', 'Y_Y|Y', 'A1')
# 719: ('Y', 'hollow', 'Y_Y_Y|FCC', 'A1')
# 720: ('Y', 'hollow', 'Y_Y_Y|HCP', 'A1')
# 721: ('Y', 'top', 'Y', 'A1')
# 722: ('Tc', 'bridge', 'Tc_Tc|Tc', 'A1')
# 723: ('Tc', 'hollow', 'Tc_Tc_Tc|FCC', 'A1')
# 724: ('Tc', 'hollow', 'Tc_Tc_Tc|HCP', 'A1')
# 725: ('Tc', 'top', 'Tc', 'A1')
# 726: ('Sc', 'bridge', 'Sc_Sc|Sc', 'A1')
# 727: ('Sc', 'hollow', 'Sc_Sc_Sc|FCC', 'A1')
# 728: ('Sc', 'hollow', 'Sc_Sc_Sc|HCP', 'A1')
# 729: ('Sc', 'top', 'Sc', 'A1')
# 730: ('Cu', 'bridge', 'Cu_Cu|Cu', 'A1')
# 731: ('Cu', 'hollow', 'Cu_Cu_Cu|FCC', 'A1')
# 732: ('Cu', 'hollow', 'Cu_Cu_Cu|HCP', 'A1')
# 733: ('Cu', 'top', 'Cu', 'A1')
# 734: ('Mn', 'top', 'Mn', 'A1')
# 735: ('Ru3Bi', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 736: ('Ru3Bi', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 737: ('Ga3Bi', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 738: ('Au3Ag', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 739: ('Au3Ag', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 740: ('Pt3Au', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 741: ('Pt3Au', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 742: ('Al3Au', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 743: ('Al3Au', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 744: ('Au3Fe', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 745: ('Au3Fe', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 746: ('Cu3Ir', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 747: ('Cu3Ir', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 748: ('Ag3Ga', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 749: ('Ag3Ga', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 750: ('Os3Ga', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 751: ('Os3Ga', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 752: ('Co3Ru', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 753: ('Co3Ru', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 754: ('Co3Ru', 'hollow', 'Co_Co_Ru|FCC', 'L12')
# 755: ('Co3Ru', 'hollow', 'Co_Co_Ru|HCP', 'L12')
# 756: ('Al3Au', 'top', 'Au', 'L12')
# 757: ('Au3Ag', 'top', 'Au', 'L12')
# 758: ('Au3Ag', 'top', 'Ag', 'L12')
# 759: ('Pt3Au', 'top', 'Pt', 'L12')
# 760: ('Pt3Au', 'top', 'Au', 'L12')
# 761: ('Au3Fe', 'top', 'Au', 'L12')
# 762: ('Au3Fe', 'top', 'Fe', 'L12')
# 763: ('Cu3Ir', 'bridge', 'Cu_Cu|Cu', 'L12')
# 764: ('Cu3Ir', 'top', 'Cu', 'L12')
# 765: ('Cu3Ir', 'top', 'Ir', 'L12')
# 766: ('Ag3Ga', 'bridge', 'Ag_Ag|Ag', 'L12')
# 767: ('Ag3Ga', 'top', 'Ag', 'L12')
# 768: ('Ag3Ga', 'bridge', 'Ag_Ag|Ga', 'L12')
# 769: ('Ag3Ga', 'top', 'Ga', 'L12')
# 770: ('Sn3Fe', 'top', 'Fe', 'L12')
# 771: ('Os3Ga', 'bridge', 'Os_Os|Os', 'L12')
# 772: ('Os3Ga', 'top', 'Os', 'L12')
# 773: ('Co3Ru', 'bridge', 'Co_Ru|Co', 'L12')
# 774: ('Co3Ru', 'top', 'Co', 'L12')
# 775: ('Co3Ru', 'top', 'Ru', 'L12')
# 776: ('Ni2Co2', 'hollow', 'Co_Ni_Ni|FCC', 'L10')
# 777: ('Ni2Co2', 'top', 'Ni', 'L10')
# 778: ('Ni2Co2', 'hollow', 'Co_Ni_Ni|HCP', 'L10')
# 779: ('Co3Pd', 'bridge', 'Co_Co|Co', 'L12')
# 780: ('Co3Pd', 'bridge', 'Co_Co|Pd', 'L12')
# 781: ('Co3Pd', 'bridge', 'Co_Pd|Co', 'L12')
# 782: ('Co3Pd', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 783: ('Co3Pd', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 784: ('Co3Pd', 'hollow', 'Co_Co_Pd|FCC', 'L12')
# 785: ('Co3Pd', 'top', 'Co', 'L12')
# 786: ('Co2Pd2', 'bridge', 'Co_Co|Pd', 'L10')
# 787: ('Co3Pd', 'top', 'Pd', 'L12')
# 788: ('Co2Pd2', 'hollow', 'Co_Co_Pd|FCC', 'L10')
# 789: ('Co2Pd2', 'top', 'Co', 'L10')
# 790: ('Co2Pd2', 'top', 'Pd', 'L10')
# 791: ('Co3Au', 'bridge', 'Co_Au|Co', 'L12')
# 792: ('Co3Au', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 793: ('Co3Au', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 794: ('Co3Au', 'top', 'Co', 'L12')
# 795: ('Co3Fe', 'bridge', 'Co_Co|Co', 'L12')
# 796: ('Co3Au', 'top', 'Au', 'L12')
# 797: ('Co3Fe', 'bridge', 'Co_Co|Fe', 'L12')
# 798: ('Co2Au2', 'bridge', 'Au_Au|Co', 'L10')
# 799: ('Co3Pt', 'bridge', 'Co_Co|Pt', 'L12')
# 800: ('Co3Fe', 'bridge', 'Co_Fe|Co', 'L12')
# 801: ('Co2Au2', 'top', 'Au', 'L10')
# 802: ('Co3Pt', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 803: ('Co3Fe', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 804: ('Co3Fe', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 805: ('Co3Pt', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 806: ('Co3Pt', 'top', 'Co', 'L12')
# 807: ('Co3Pt', 'top', 'Pt', 'L12')
# 808: ('Ni3Os', 'hollow', 'Ni_Ni_Ni|FCC', 'L12')
# 809: ('Co3Fe', 'hollow', 'Co_Co_Fe|FCC', 'L12')
# 810: ('Ni3Os', 'hollow', 'Ni_Ni_Os|HCP', 'L12')
# 811: ('Co3Fe', 'hollow', 'Co_Co_Fe|HCP', 'L12')
# 812: ('Co3Fe', 'top', 'Co', 'L12')
# 813: ('Co3Fe', 'top', 'Fe', 'L12')
# 814: ('Ni3Os', 'top', 'Ni', 'L12')
# 815: ('Ni3Os', 'top', 'Os', 'L12')
# 816: ('Ag3Sn', 'bridge', 'Ag_Ag|Ag', 'L12')
# 817: ('Ag3Sn', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 818: ('Ag3Sn', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 819: ('Ag3Sn', 'top', 'Ag', 'L12')
# 820: ('Ag2Cu2', 'bridge', 'Ag_Ag|Cu', 'L10')
# 821: ('Au2Ag2', 'bridge', 'Au_Au|Ag', 'L10')
# 822: ('Ag2Cu2', 'bridge', 'Cu_Cu|Ag', 'L10')
# 823: ('Au2Ag2', 'top', 'Ag', 'L10')
# 824: ('Au2Ag2', 'top', 'Au', 'L10')
# 825: ('Ag2Cu2', 'top', 'Ag', 'L10')
# 826: ('Ag2Cu2', 'top', 'Cu', 'L10')
# 827: ('Ni3Co', 'bridge', 'Ni_Ni|Ni', 'L12')
# 828: ('Ni3Co', 'bridge', 'Ni_Co|Ni', 'L12')
# 829: ('Co2Pt2', 'bridge', 'Co_Co|Pt', 'L10')
# 830: ('Ni3Co', 'hollow', 'Ni_Ni_Ni|FCC', 'L12')
# 831: ('Ag2Sn2', 'top', 'Ag', 'L10')
# 832: ('Ni3Co', 'hollow', 'Ni_Ni_Ni|HCP', 'L12')
# 833: ('Co2Pt2', 'top', 'Co', 'L10')
# 834: ('Co2Pt2', 'top', 'Pt', 'L10')
# 835: ('Ni3Co', 'hollow', 'Ni_Ni_Co|FCC', 'L12')
# 836: ('Ni3Co', 'top', 'Co', 'L12')
# 837: ('Ag3Bi', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 838: ('Ag3Bi', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 839: ('Ag3Bi', 'top', 'Ag', 'L12')
# 840: ('Ag2Bi2', 'top', 'Ag', 'L10')
# 841: ('Ag2Bi2', 'top', 'Bi', 'L10')
# 842: ('Co3Ir', 'bridge', 'Co_Co|Co', 'L12')
# 843: ('Co3Ir', 'bridge', 'Co_Co|Ir', 'L12')
# 844: ('Co3Ir', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 845: ('Co3Ir', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 846: ('Fe3Ir', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 847: ('Co3Ir', 'top', 'Co', 'L12')
# 848: ('Fe3Ir', 'hollow', 'Fe_Fe_Fe|HCP', 'L12')
# 849: ('Co3Ir', 'top', 'Ir', 'L12')
# 850: ('Fe2Pt2', 'hollow', 'Fe_Pt_Pt|HCP', 'L10')
# 851: ('Fe2Pd2', 'bridge', 'Pd_Pd|Fe', 'L10')
# 852: ('Fe2Pt2', 'top', 'Fe', 'L10')
# 853: ('Fe2Pd2', 'hollow', 'Fe_Pd_Pd|FCC', 'L10')
# 854: ('Ag2Al2', 'top', 'Al', 'L10')
# 855: ('Co3Os', 'bridge', 'Co_Co|Co', 'L12')
# 856: ('Fe2Pt2', 'top', 'Pt', 'L10')
# 857: ('Fe2Pd2', 'top', 'Fe', 'L10')
# 858: ('Fe2Pd2', 'top', 'Pd', 'L10')
# 859: ('Fe2Au2', 'bridge', 'Au_Au|Fe', 'L10')
# 860: ('Fe2Au2', 'top', 'Au', 'L10')
# 861: ('Ag3Al', 'bridge', 'Ag_Ag|Ag', 'L12')
# 862: ('Co3Os', 'bridge', 'Co_Co|Os', 'L12')
# 863: ('Fe2Au2', 'top', 'Fe', 'L10')
# 864: ('Fe3Au', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 865: ('Fe3Au', 'hollow', 'Fe_Fe_Fe|HCP', 'L12')
# 866: ('Ag3Al', 'bridge', 'Ag_Ag|Al', 'L12')
# 867: ('Co3Os', 'bridge', 'Co_Os|Co', 'L12')
# 868: ('Co3Os', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 869: ('Co3Os', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 870: ('Ag3Al', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 871: ('Co3Os', 'hollow', 'Co_Co_Os|FCC', 'L12')
# 872: ('Co3Os', 'hollow', 'Co_Co_Os|HCP', 'L12')
# 873: ('Ag3Al', 'top', 'Ag', 'L12')
# 874: ('Co3Os', 'top', 'Os', 'L12')
# 875: ('Ag3Al', 'top', 'Al', 'L12')
# 876: ('Pt3Os', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 877: ('Pt3Ru', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 878: ('Pt3Rh', 'top', 'Pt', 'L12')
# 879: ('Pt3Os', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 880: ('Pt3Ru', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 881: ('Pt3Rh', 'top', 'Rh', 'L12')
# 882: ('Pt3Os', 'top', 'Pt', 'L12')
# 883: ('Pt3Ru', 'top', 'Pt', 'L12')
# 884: ('Pt3Os', 'top', 'Os', 'L12')
# 885: ('Pt3Ru', 'top', 'Ru', 'L12')
# 886: ('Pt3Pd', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 887: ('Pt3Pd', 'top', 'Pt', 'L12')
# 888: ('Pt3Rh', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 889: ('Pt3Pd', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 890: ('Pt3Pd', 'top', 'Pd', 'L12')
# 891: ('Pt3Ir', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 892: ('Pt3Rh', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 893: ('Pt3Ir', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 894: ('Pt3Ir', 'top', 'Pt', 'L12')
# 895: ('Pt3Ir', 'top', 'Ir', 'L12')
# 896: ('Pt2Pd2', 'top', 'Pt', 'L10')
# 897: ('Co3Ni', 'bridge', 'Co_Co|Ni', 'L12')
# 898: ('Co3Ni', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 899: ('Co3Ni', 'hollow', 'Co_Co_Ni|FCC', 'L12')
# 900: ('Co3Ni', 'hollow', 'Co_Co_Ni|HCP', 'L12')
# 901: ('Co3Ni', 'top', 'Co', 'L12')
# 902: ('Pt2Pd2', 'top', 'Pd', 'L10')
# 903: ('Pd2Au2', 'top', 'Au', 'L10')
# 904: ('Pd2Au2', 'top', 'Pd', 'L10')
# 905: ('Co3Ni', 'top', 'Ni', 'L12')
# 906: ('Pd3Au', 'bridge', 'Pd_Au|Pd', 'L12')
# 907: ('Pd3Au', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 908: ('Pd3Au', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 909: ('Pd3Os', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 910: ('Pd3Au', 'top', 'Pd', 'L12')
# 911: ('Pd3Os', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 912: ('Pd3Au', 'top', 'Au', 'L12')
# 913: ('Pd3Os', 'top', 'Pd', 'L12')
# 914: ('Ag2Ga2', 'top', 'Ag', 'L10')
# 915: ('Pd3Os', 'top', 'Os', 'L12')
# 916: ('Ni2Co2', 'bridge', 'Co_Co|Ni', 'L10')
# 917: ('Ni2Co2', 'bridge', 'Co_Ni|Co', 'L10')
# 918: ('Ni2Co2', 'bridge', 'Co_Ni|Ni', 'L10')
# 919: ('Ni2Co2', 'bridge', 'Ni_Ni|Co', 'L10')
# 920: ('Ni2Co2', 'hollow', 'Co_Co_Ni|FCC', 'L10')
# 921: ('Pd3Ni', 'top', 'Pd', 'L12')
# 922: ('Pd3Ni', 'top', 'Ni', 'L12')
# 923: ('Pd3Pt', 'top', 'Pd', 'L12')
# 924: ('Pd3Ir', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 925: ('Pd3Ir', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 926: ('Pd3Ir', 'top', 'Pd', 'L12')
# 927: ('Pd3Ir', 'top', 'Ir', 'L12')
# 928: ('Co3Rh', 'bridge', 'Co_Co|Co', 'L12')
# 929: ('Au3Ir', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 930: ('Co3Rh', 'bridge', 'Co_Rh|Co', 'L12')
# 931: ('Au3Os', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 932: ('Au3Ir', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 933: ('Au3Os', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 934: ('Au3Ru', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 935: ('Au3Ir', 'top', 'Au', 'L12')
# 936: ('Au3Os', 'top', 'Au', 'L12')
# 937: ('Au3Ru', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 938: ('Au3Ir', 'top', 'Ir', 'L12')
# 939: ('Au3Rh', 'top', 'Au', 'L12')
# 940: ('Au3Os', 'top', 'Os', 'L12')
# 941: ('Au3Ru', 'top', 'Au', 'L12')
# 942: ('Au3Rh', 'top', 'Rh', 'L12')
# 943: ('Au3Ru', 'top', 'Ru', 'L12')
# 944: ('Co3Rh', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 945: ('Co3Rh', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 946: ('Co3Rh', 'hollow', 'Co_Co_Rh|FCC', 'L12')
# 947: ('Co3Rh', 'hollow', 'Co_Co_Rh|HCP', 'L12')
# 948: ('Co3Rh', 'top', 'Co', 'L12')
# 949: ('Au3Pt', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 950: ('Co3Rh', 'top', 'Rh', 'L12')
# 951: ('Au3Pt', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 952: ('Au3Pd', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 953: ('Au3Pt', 'top', 'Au', 'L12')
# 954: ('Au3Pd', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 955: ('Au3Pt', 'top', 'Pt', 'L12')
# 956: ('Au3Pd', 'top', 'Au', 'L12')
# 957: ('Au3Pd', 'top', 'Pd', 'L12')
# 958: ('Ag3Ir', 'bridge', 'Ag_Ag|Ag', 'L12')
# 959: ('Ag3Os', 'bridge', 'Ag_Ag|Ag', 'L12')
# 960: ('Ag3Ir', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 961: ('Ag3Os', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 962: ('Ag3Ir', 'top', 'Ir', 'L12')
# 963: ('Ag3Rh', 'bridge', 'Ag_Ag|Ag', 'L12')
# 964: ('Ag3Os', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 965: ('Ag3Rh', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 966: ('Ag3Os', 'top', 'Os', 'L12')
# 967: ('Ag3Rh', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 968: ('Ag3Rh', 'top', 'Ag', 'L12')
# 969: ('Ag3Rh', 'top', 'Rh', 'L12')
# 970: ('Ag3Co', 'bridge', 'Ag_Ag|Ag', 'L12')
# 971: ('Ag3Co', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 972: ('Ag3Pt', 'bridge', 'Ag_Ag|Ag', 'L12')
# 973: ('Ag3Ni', 'bridge', 'Ag_Ag|Ag', 'L12')
# 974: ('Ag3Co', 'top', 'Ag', 'L12')
# 975: ('Ag3Pt', 'bridge', 'Ag_Ag|Pt', 'L12')
# 976: ('Ag3Ni', 'bridge', 'Ag_Ag|Ni', 'L12')
# 977: ('Ag3Co', 'top', 'Co', 'L12')
# 978: ('Ag3Pt', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 979: ('Ag3Pd', 'bridge', 'Ag_Ag|Ag', 'L12')
# 980: ('Ag3Ni', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 981: ('Ag3Pt', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 982: ('Ag3Pd', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 983: ('Ag3Ni', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 984: ('Ag3Pt', 'top', 'Pt', 'L12')
# 985: ('Ag3Pd', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 986: ('Ag3Au', 'bridge', 'Ag_Ag|Ag', 'L12')
# 987: ('Ag3Ni', 'top', 'Ag', 'L12')
# 988: ('Ag3Pd', 'top', 'Ag', 'L12')
# 989: ('Ag3Au', 'bridge', 'Ag_Ag|Au', 'L12')
# 990: ('Ag3Ni', 'top', 'Ni', 'L12')
# 991: ('Ag3Pd', 'top', 'Pd', 'L12')
# 992: ('Ag3Au', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 993: ('Ag3Au', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 994: ('Ag3Au', 'top', 'Ag', 'L12')
# 995: ('Ag3Au', 'top', 'Au', 'L12')
# 996: ('Cu3Ru', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 997: ('Cu3Ru', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 998: ('Cu3Os', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 999: ('Cu3Ru', 'hollow', 'Cu_Cu_Ru|HCP', 'L12')
# 1000: ('Cu3Os', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1001: ('Cu3Ru', 'top', 'Ru', 'L12')
# 1002: ('Cu3Os', 'top', 'Cu', 'L12')
# 1003: ('Cu3Os', 'top', 'Os', 'L12')
# 1004: ('Cu3Rh', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1005: ('Cu3Rh', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1006: ('Cu3Ag', 'top', 'Ag', 'L12')
# 1007: ('Cu3Rh', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1008: ('Cu3Rh', 'top', 'Cu', 'L12')
# 1009: ('Cu3Ni', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1010: ('Cu3Fe', 'bridge', 'Cu_Fe|Cu', 'L12')
# 1011: ('Cu3Pt', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1012: ('Cu3Ag', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1013: ('Cu3Rh', 'top', 'Rh', 'L12')
# 1014: ('Cu3Ni', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1015: ('Cu3Fe', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1016: ('Cu3Pt', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1017: ('Cu3Ag', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1018: ('Cu3Ag', 'top', 'Cu', 'L12')
# 1019: ('Cu3Ni', 'top', 'Cu', 'L12')
# 1020: ('Cu3Fe', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1021: ('Cu3Pt', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1022: ('Cu3Ni', 'top', 'Ni', 'L12')
# 1023: ('Cu3Fe', 'hollow', 'Cu_Cu_Fe|HCP', 'L12')
# 1024: ('Cu3Pt', 'top', 'Cu', 'L12')
# 1025: ('Cu3Pd', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1026: ('Cu3Fe', 'top', 'Cu', 'L12')
# 1027: ('Cu3Pt', 'top', 'Pt', 'L12')
# 1028: ('Cu3Pd', 'bridge', 'Cu_Pd|Cu', 'L12')
# 1029: ('Cu3Fe', 'top', 'Fe', 'L12')
# 1030: ('Cu3Au', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1031: ('Cu3Pd', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1032: ('Cu3Au', 'bridge', 'Cu_Cu|Au', 'L12')
# 1033: ('Cu3Pd', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1034: ('Al3Bi', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1035: ('Cu3Pd', 'hollow', 'Cu_Cu_Pd|HCP', 'L12')
# 1036: ('Cu3Au', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1037: ('Al3Bi', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1038: ('Cu3Au', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1039: ('Cu3Pd', 'top', 'Cu', 'L12')
# 1040: ('Cu3Au', 'top', 'Cu', 'L12')
# 1041: ('Al3Ga', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1042: ('Cu3Pd', 'top', 'Pd', 'L12')
# 1043: ('Cu3Au', 'top', 'Au', 'L12')
# 1044: ('Al3Ga', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1045: ('Al3Sn', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1046: ('Al3Sn', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1047: ('Al2Ga2', 'top', 'Ga', 'L10')
# 1048: ('Al3Rh', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1049: ('Al3Rh', 'top', 'Rh', 'L12')
# 1050: ('Al3Rh', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1051: ('Al3Ni', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1052: ('Al3Ni', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1053: ('Al3Os', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1054: ('Al3Ru', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1055: ('Al3Ir', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1056: ('Al3Ni', 'top', 'Ni', 'L12')
# 1057: ('Al3Os', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1058: ('Al3Ru', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1059: ('Al3Ir', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1060: ('Al3Os', 'top', 'Os', 'L12')
# 1061: ('Al3Ru', 'top', 'Ru', 'L12')
# 1062: ('Al3Ir', 'top', 'Ir', 'L12')
# 1063: ('Al3Pd', 'top', 'Pd', 'L12')
# 1064: ('Al3Fe', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1065: ('Al3Pd', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1066: ('Al3Fe', 'top', 'Fe', 'L12')
# 1067: ('Al3Pt', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1068: ('Al3Pd', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1069: ('Al3Pt', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1070: ('Al3Pt', 'top', 'Pt', 'L12')
# 1071: ('Al3Ag', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1072: ('Al3Ag', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1073: ('Al3Ag', 'top', 'Ag', 'L12')
# 1074: ('Ga3Os', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1075: ('Ga3Ru', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1076: ('Ga3Ir', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1077: ('Ga3Os', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1078: ('Ga3Ru', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1079: ('Ga3Ir', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1080: ('Ga3Os', 'top', 'Os', 'L12')
# 1081: ('Ga3Ru', 'top', 'Ru', 'L12')
# 1082: ('Ga3Ir', 'top', 'Ir', 'L12')
# 1083: ('Ga3Rh', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1084: ('Ga3Rh', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1085: ('Ga3Rh', 'top', 'Rh', 'L12')
# 1086: ('Al3Cu', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1087: ('Al3Cu', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1088: ('Al3Cu', 'top', 'Cu', 'L12')
# 1089: ('Ga3Ni', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1090: ('Ga3Ni', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1091: ('Ga3Pt', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1092: ('Ga3Ag', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1093: ('Ga3Ag', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1094: ('Ga3Ag', 'top', 'Ag', 'L12')
# 1095: ('Ga3Cu', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1096: ('Ga3Cu', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1097: ('Ga3Cu', 'top', 'Cu', 'L12')
# 1098: ('Ga3Al', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 1099: ('Ga3Sn', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1100: ('Ga3Al', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 1101: ('Ga3Sn', 'top', 'Ga', 'L12')
# 1102: ('Ga3Al', 'top', 'Al', 'L12')
# 1103: ('Ga3Sn', 'top', 'Sn', 'L12')
# 1104: ('Ga3Bi', 'top', 'Ga', 'L12')
# 1105: ('Ga3Bi', 'top', 'Bi', 'L12')
# 1106: ('Ga2Bi2', 'top', 'Bi', 'L10')
# 1107: ('Ga2Bi2', 'top', 'Ga', 'L10')
# 1108: ('Ga2Sn2', 'top', 'Ga', 'L10')
# 1109: ('Ga2Sn2', 'top', 'Sn', 'L10')
# 1110: ('Sn3Ag', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1111: ('Sn3Ag', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1112: ('Sn3Ag', 'top', 'Sn', 'L12')
# 1113: ('Sn3Ag', 'top', 'Ag', 'L12')
# 1114: ('Sn3Al', 'top', 'Al', 'L12')
# 1115: ('Sn3Cu', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1116: ('Sn3Cu', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1117: ('Sn3Cu', 'top', 'Cu', 'L12')
# 1118: ('Sn3Ga', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1119: ('Sn3Ga', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1120: ('Sn3Ga', 'top', 'Sn', 'L12')
# 1121: ('Sn3Bi', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1122: ('Sn3Bi', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1123: ('Sn3Bi', 'top', 'Bi', 'L12')
# 1124: ('Bi3Rh', 'hollow', 'Bi_Bi_Bi|HCP', 'L12')
# 1125: ('Bi3Ru', 'hollow', 'Bi_Bi_Bi|FCC', 'L12')
# 1126: ('Bi3Pt', 'hollow', 'Bi_Bi_Bi|HCP', 'L12')
# 1127: ('Bi3Ru', 'hollow', 'Bi_Bi_Bi|HCP', 'L12')
# 1128: ('Bi3Pt', 'top', 'Pt', 'L12')
# 1129: ('Bi3Ru', 'top', 'Ru', 'L12')
# 1130: ('Bi3Au', 'top', 'Au', 'L12')
# 1131: ('Bi3Cu', 'top', 'Cu', 'L12')
# 1132: ('Bi3Cu', 'top', 'Bi', 'L12')
# 1133: ('Bi3Ga', 'top', 'Ga', 'L12')
# 1134: ('Bi3Ag', 'top', 'Ag', 'L12')
# 1135: ('Bi3Pd', 'hollow', 'Bi_Bi_Bi|FCC', 'L12')
# ...
# 1167: ('Os3Sn', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 1168: ('Pt3Os', 'bridge', 'Pt_Os|Pt', 'L12')
# 1169: ('Ag2Cu2', 'hollow', 'Ag_Ag_Cu|HCP', 'L10')
# 1170: ('Os3Sn', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 1171: ('Ag2Cu2', 'hollow', 'Ag_Cu_Cu|FCC', 'L10')
# 1172: ('Pt3Os', 'top', 'Pt', 'L12')
# 1173: ('Rh3Au', 'top', 'Au', 'L12')
# 1174: ('Ag2Cu2', 'hollow', 'Ag_Cu_Cu|HCP', 'L10')
# 1175: ('Pt3Ga', 'bridge', 'Pt_Pt|Pt', 'L12')
# 1176: ('Pt3Os', 'top', 'Os', 'L12')
# 1177: ('Fe3Ir', 'top', 'Ir', 'L12')
# 1178: ('Pt3Ga', 'bridge', 'Pt_Pt|Ga', 'L12')
# 1179: ('Al3Os', 'bridge', 'Al_Al|Al', 'L12')
# 1180: ('Ni3Au', 'bridge', 'Ni_Ni|Au', 'L12')
# 1181: ('Pt3Ga', 'top', 'Pt', 'L12')
# 1182: ('Al3Os', 'bridge', 'Al_Al|Os', 'L12')
# 1183: ('Pt3Ga', 'top', 'Ga', 'L12')
# 1184: ('Al3Os', 'bridge', 'Al_Os|Al', 'L12')
# 1185: ('Ni3Au', 'top', 'Au', 'L12')
# 1186: ('Al3Os', 'top', 'Os', 'L12')
# 1187: ('Os2Rh2', 'top', 'Os', 'L10')
# 1188: ('Pd3Co', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 1189: ('Pd3Co', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 1190: ('Pd3Co', 'hollow', 'Pd_Pd_Co|FCC', 'L12')
# 1191: ('Pt2Al2', 'bridge', 'Al_Al|Pt', 'L10')
# 1192: ('Pd3Co', 'hollow', 'Pd_Pd_Co|HCP', 'L12')
# 1193: ('Pt2Al2', 'hollow', 'Al_Al_Pt|HCP', 'L10')
# 1194: ('Fe2Pt2', 'bridge', 'Pt_Pt|Fe', 'L10')
# 1195: ('Fe2Pt2', 'hollow', 'Fe_Fe_Pt|FCC', 'L10')
# 1196: ('Os2Cu2', 'bridge', 'Os_Os|Cu', 'L10')
# 1197: ('Fe2Pt2', 'top', 'Fe', 'L10')
# 1198: ('Pt2Al2', 'top', 'Al', 'L10')
# 1199: ('Ir3Rh', 'bridge', 'Ir_Ir|Ir', 'L12')
# 1200: ('Fe2Pt2', 'bridge', 'Fe_Fe|Pt', 'L10')
# 1201: ('Pd3Ir', 'bridge', 'Pd_Ir|Pd', 'L12')
# 1202: ('Pd3Ir', 'top', 'Ir', 'L12')
# 1203: ('Ir3Rh', 'bridge', 'Ir_Ir|Rh', 'L12')
# 1204: ('Ir3Rh', 'bridge', 'Ir_Rh|Ir', 'L12')
# 1205: ('Ir3Rh', 'top', 'Rh', 'L12')
# 1206: ('Fe2Cu2', 'bridge', 'Cu_Cu|Fe', 'L10')
# 1207: ('Pd3Ir', 'bridge', 'Pd_Pd|Pd', 'L12')
# 1208: ('Fe2Cu2', 'bridge', 'Fe_Fe|Cu', 'L10')
# 1209: ('Pd3Ir', 'bridge', 'Pd_Pd|Ir', 'L12')
# 1210: ('Ru2Cu2', 'bridge', 'Ru_Ru|Cu', 'L10')
# 1211: ('Fe2Cu2', 'hollow', 'Cu_Cu_Fe|HCP', 'L10')
# 1212: ('Fe2Cu2', 'hollow', 'Cu_Fe_Fe|FCC', 'L10')
# 1213: ('Fe2Cu2', 'hollow', 'Cu_Fe_Fe|HCP', 'L10')
# 1214: ('Ru2Cu2', 'hollow', 'Cu_Cu_Ru|FCC', 'L10')
# 1215: ('Os2Cu2', 'top', 'Os', 'L10')
# 1216: ('Os2Ag2', 'bridge', 'Os_Os|Ag', 'L10')
# 1217: ('Os2Ag2', 'bridge', 'Os_Os|Os', 'L10')
# 1218: ('Fe2Sn2', 'bridge', 'Fe_Fe|Sn', 'L10')
# 1219: ('Fe2Sn2', 'bridge', 'Sn_Sn|Fe', 'L10')
# 1220: ('Fe2Sn2', 'top', 'Fe', 'L10')
# 1221: ('Os2Fe2', 'hollow', 'Fe_Fe_Os|HCP', 'L10')
# 1222: ('Os2Fe2', 'hollow', 'Fe_Os_Os|HCP', 'L10')
# 1223: ('Co2Ga2', 'bridge', 'Ga_Ga|Co', 'L10')
# 1224: ('Co2Ga2', 'top', 'Co', 'L10')
# 1225: ('Pd2Ga2', 'bridge', 'Ga_Ga|Pd', 'L10')
# 1226: ('Pt2Cu2', 'bridge', 'Cu_Cu|Pt', 'L10')
# 1227: ('Ru2Pt2', 'bridge', 'Pt_Pt|Ru', 'L10')
# 1228: ('Ga2Sn2', 'bridge', 'Ga_Ga|Sn', 'L10')
# 1229: ('Pt2Cu2', 'bridge', 'Pt_Pt|Cu', 'L10')
# 1230: ('Ru2Pt2', 'bridge', 'Pt_Ru|Pt', 'L10')
# 1231: ('Ga2Sn2', 'bridge', 'Ga_Sn|Ga', 'L10')
# 1232: ('Pt2Cu2', 'hollow', 'Cu_Cu_Pt|FCC', 'L10')
# 1233: ('Ru2Pt2', 'bridge', 'Ru_Ru|Pt', 'L10')
# 1234: ('Ga2Sn2', 'bridge', 'Sn_Sn|Ga', 'L10')
# 1235: ('Pt2Cu2', 'hollow', 'Cu_Pt_Pt|HCP', 'L10')
# 1236: ('Ru2Pt2', 'hollow', 'Pt_Pt_Ru|FCC', 'L10')
# 1237: ('Ga2Sn2', 'hollow', 'Ga_Ga_Sn|HCP', 'L10')
# 1238: ('Pd2Ga2', 'top', 'Ga', 'L10')
# 1239: ('Ru2Pt2', 'hollow', 'Pt_Ru_Ru|FCC', 'L10')
# 1240: ('Ga2Sn2', 'hollow', 'Ga_Sn_Sn|FCC', 'L10')
# 1241: ('Ru2Pt2', 'hollow', 'Pt_Ru_Ru|HCP', 'L10')
# 1242: ('Pt2Cu2', 'top', 'Pt', 'L10')
# 1243: ('Ru2Pt2', 'top', 'Ru', 'L10')
# 1244: ('Ni2Fe2', 'bridge', 'Fe_Ni|Ni', 'L10')
# 1245: ('Ni2Fe2', 'top', 'Ni', 'L10')
# 1246: ('Ni2Fe2', 'bridge', 'Ni_Ni|Fe', 'L10')
# 1247: ('Ni2Fe2', 'hollow', 'Fe_Fe_Ni|FCC', 'L10')
# 1248: ('Ni2Fe2', 'hollow', 'Fe_Fe_Ni|HCP', 'L10')
# 1249: ('Ni2Fe2', 'hollow', 'Fe_Ni_Ni|FCC', 'L10')
# 1250: ('Co2Cu2', 'bridge', 'Co_Co|Cu', 'L10')
# 1251: ('Au2Cu2', 'hollow', 'Au_Au_Cu|FCC', 'L10')
# 1252: ('Co2Cu2', 'hollow', 'Co_Co_Cu|FCC', 'L10')
# 1253: ('Au2Cu2', 'hollow', 'Au_Au_Cu|HCP', 'L10')
# 1254: ('Co2Cu2', 'hollow', 'Co_Co_Cu|HCP', 'L10')
# 1255: ('Co2Cu2', 'hollow', 'Co_Cu_Cu|HCP', 'L10')
# 1256: ('Co2Cu2', 'top', 'Co', 'L10')
# 1257: ('Ir2Ag2', 'bridge', 'Ir_Ir|Ag', 'L10')
# 1258: ('Cu2Al2', 'bridge', 'Al_Al|Cu', 'L10')
# 1259: ('Ir2Ag2', 'hollow', 'Ag_Ag_Ir|FCC', 'L10')
# 1260: ('Cu2Al2', 'hollow', 'Al_Al_Cu|FCC', 'L10')
# 1261: ('Ir2Ag2', 'top', 'Ir', 'L10')
# 1262: ('Fe2Ag2', 'bridge', 'Fe_Fe|Ag', 'L10')
# 1263: ('Fe2Ag2', 'bridge', 'Fe_Fe|Fe', 'L10')
# 1264: ('Fe2Ag2', 'hollow', 'Ag_Ag_Fe|FCC', 'L10')
# 1265: ('Co2Pt2', 'bridge', 'Co_Co|Pt', 'L10')
# 1266: ('Fe2Pd2', 'bridge', 'Fe_Fe|Pd', 'L10')
# 1267: ('Co2Pt2', 'bridge', 'Co_Pt|Pt', 'L10')
# 1268: ('Fe2Pd2', 'hollow', 'Fe_Fe_Pd|HCP', 'L10')
# 1269: ('Fe2Ag2', 'top', 'Fe', 'L10')
# 1270: ('Co2Pt2', 'hollow', 'Co_Co_Pt|FCC', 'L10')
# 1271: ('Fe2Pd2', 'hollow', 'Fe_Pd_Pd|FCC', 'L10')
# 1272: ('Co2Pt2', 'hollow', 'Co_Pt_Pt|HCP', 'L10')
# 1273: ('Fe2Pd2', 'hollow', 'Fe_Pd_Pd|HCP', 'L10')
# 1274: ('Co2Pt2', 'top', 'Co', 'L10')
# 1275: ('Rh2Co2', 'bridge', 'Co_Co|Rh', 'L10')
# 1276: ('Rh2Co2', 'hollow', 'Co_Co_Rh|FCC', 'L10')
# 1277: ('Rh2Co2', 'hollow', 'Co_Co_Rh|HCP', 'L10')
# 1278: ('Rh2Co2', 'bridge', 'Co_Rh|Co', 'L10')
# 1279: ('Rh2Co2', 'hollow', 'Co_Rh_Rh|HCP', 'L10')
# 1280: ('Rh2Co2', 'bridge', 'Co_Rh|Rh', 'L10')
# 1281: ('Rh2Co2', 'top', 'Co', 'L10')
# 1282: ('Rh2Co2', 'bridge', 'Rh_Rh|Co', 'L10')
# 1283: ('Bi3Ag', 'top', 'Ag', 'L12')
# 1284: ('Au3Bi', 'bridge', 'Au_Au|Au', 'L12')
# 1285: ('Bi3Au', 'top', 'Au', 'L12')
# 1286: ('Pt2Bi2', 'bridge', 'Pt_Pt|Bi', 'L10')
# 1287: ('Pt3Bi', 'bridge', 'Pt_Pt|Pt', 'L12')
# 1288: ('Au3Bi', 'bridge', 'Au_Au|Bi', 'L12')
# 1289: ('Ru3Rh', 'bridge', 'Ru_Ru|Rh', 'L12')
# 1290: ('Rh3Pd', 'bridge', 'Rh_Rh|Rh', 'L12')
# 1291: ('Pt3Bi', 'bridge', 'Pt_Pt|Bi', 'L12')
# 1292: ('Au3Bi', 'bridge', 'Au_Bi|Au', 'L12')
# 1293: ('Ru3Rh', 'bridge', 'Ru_Rh|Ru', 'L12')
# 1294: ('Rh3Pd', 'bridge', 'Rh_Rh|Pd', 'L12')
# 1295: ('Pd3Pt', 'bridge', 'Pd_Pd|Pd', 'L12')
# 1296: ('Pt3Bi', 'top', 'Bi', 'L12')
# 1297: ('Au3Bi', 'top', 'Bi', 'L12')
# 1298: ('Ru3Rh', 'top', 'Rh', 'L12')
# 1299: ('Pt2Bi2', 'top', 'Pt', 'L10')
# 1300: ('Ru3Ag', 'top', 'Ag', 'L12')
# 1301: ('Rh3Pd', 'top', 'Rh', 'L12')
# 1302: ('Pd3Ru', 'bridge', 'Pd_Ru|Pd', 'L12')
# 1303: ('Pd3Pt', 'bridge', 'Pd_Pd|Pt', 'L12')
# 1304: ('Ag3Au', 'bridge', 'Ag_Ag|Ag', 'L12')
# 1305: ('Ru3Au', 'bridge', 'Ru_Ru|Au', 'L12')
# 1306: ('Pt3Ru', 'bridge', 'Pt_Pt|Pt', 'L12')
# 1307: ('Pd3Ag', 'bridge', 'Pd_Pd|Pd', 'L12')
# 1308: ('Rh3Pd', 'top', 'Pd', 'L12')
# 1309: ('Pd3Ru', 'top', 'Ru', 'L12')
# 1310: ('Pd3Pt', 'top', 'Pt', 'L12')
# 1311: ('Ag3Pd', 'bridge', 'Ag_Ag|Ag', 'L12')
# 1312: ('Ag3Au', 'bridge', 'Ag_Ag|Au', 'L12')
# 1313: ('Ag3Bi', 'bridge', 'Ag_Ag|Ag', 'L12')
# 1314: ('Au3Rh', 'bridge', 'Au_Rh|Au', 'L12')
# 1315: ('Cu3Ru', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1316: ('Ru3Au', 'top', 'Au', 'L12')
# 1317: ('Pt3Ru', 'bridge', 'Pt_Pt|Ru', 'L12')
# 1318: ('Pd3Ag', 'bridge', 'Pd_Pd|Ag', 'L12')
# 1319: ('Pd3Bi', 'bridge', 'Pd_Pd|Pd', 'L12')
# 1320: ('Bi3Rh', 'top', 'Rh', 'L12')
# 1321: ('Ag3Pd', 'bridge', 'Ag_Pd|Ag', 'L12')
# 1322: ('Ag3Au', 'bridge', 'Ag_Au|Ag', 'L12')
# 1323: ('Ag3Bi', 'bridge', 'Ag_Ag|Bi', 'L12')
# 1324: ('Au3Rh', 'top', 'Au', 'L12')
# 1325: ('Cu3Ru', 'bridge', 'Cu_Ru|Cu', 'L12')
# 1326: ('Pt3Ru', 'bridge', 'Pt_Ru|Pt', 'L12')
# 1327: ('Pd3Ag', 'top', 'Ag', 'L12')
# 1328: ('Pd3Bi', 'bridge', 'Pd_Pd|Bi', 'L12')
# 1329: ('Au3Pt', 'bridge', 'Au_Au|Au', 'L12')
# 1330: ('Ag3Pd', 'top', 'Pd', 'L12')
# 1331: ('Ag3Au', 'top', 'Au', 'L12')
# 1332: ('Ag3Bi', 'bridge', 'Ag_Bi|Ag', 'L12')
# 1333: ('Au3Rh', 'top', 'Rh', 'L12')
# 1334: ('Cu3Ru', 'top', 'Ru', 'L12')
# 1335: ('Pt3Ru', 'top', 'Pt', 'L12')
# 1336: ('Pd3Bi', 'top', 'Bi', 'L12')
# 1337: ('Bi3Pd', 'top', 'Pd', 'L12')
# 1338: ('Au3Pt', 'top', 'Au', 'L12')
# 1339: ('Ag3Bi', 'top', 'Bi', 'L12')
# 1340: ('Pt3Ru', 'top', 'Ru', 'L12')
# 1341: ('Cu3Au', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1342: ('Au3Pt', 'top', 'Pt', 'L12')
# 1343: ('Cu3Au', 'bridge', 'Cu_Cu|Au', 'L12')
# 1344: ('Cu3Au', 'top', 'Au', 'L12')
# 1345: ('Co3Cu', 'bridge', 'Co_Co|Co', 'L12')
# 1346: ('Bi3Pt', 'bridge', 'Bi_Bi|Bi', 'L12')
# 1347: ('Co3Cu', 'bridge', 'Co_Co|Cu', 'L12')
# 1348: ('Co3Cu', 'top', 'Cu', 'L12')
# 1349: ('Bi3Ru', 'top', 'Ru', 'L12')
# 1350: ('Bi3Pt', 'top', 'Bi', 'L12')
# 1351: ('Ru3Fe', 'bridge', 'Ru_Ru|Fe', 'L12')
# 1352: ('Ru3Pt', 'bridge', 'Ru_Ru|Pt', 'L12')
# 1353: ('Bi3Pt', 'top', 'Pt', 'L12')
# 1354: ('Ru3Fe', 'top', 'Fe', 'L12')
# 1355: ('Ru3Pt', 'top', 'Ru', 'L12')
# 1356: ('Pd3Rh', 'bridge', 'Pd_Pd|Pd', 'L12')
# 1357: ('Ru3Pt', 'top', 'Pt', 'L12')
# 1358: ('Pd3Rh', 'bridge', 'Pd_Pd|Rh', 'L12')
# 1359: ('Pd3Cu', 'bridge', 'Pd_Pd|Pd', 'L12')
# 1360: ('Co3Pd', 'bridge', 'Co_Co|Co', 'L12')
# 1361: ('Pd3Rh', 'bridge', 'Pd_Rh|Pd', 'L12')
# 1362: ('Pd3Cu', 'bridge', 'Pd_Pd|Cu', 'L12')
# 1363: ('Ir3Au', 'bridge', 'Ir_Ir|Ir', 'L12')
# 1364: ('Co3Pd', 'bridge', 'Co_Co|Pd', 'L12')
# 1365: ('Pd3Rh', 'top', 'Rh', 'L12')
# 1366: ('Pd3Cu', 'top', 'Cu', 'L12')
# 1367: ('Al3Pd', 'bridge', 'Al_Al|Al', 'L12')
# 1368: ('Ir3Au', 'bridge', 'Ir_Ir|Au', 'L12')
# 1369: ('Co3Pd', 'bridge', 'Co_Pd|Co', 'L12')
# 1370: ('Al3Pd', 'bridge', 'Al_Al|Pd', 'L12')
# 1371: ('Co3Pd', 'top', 'Pd', 'L12')
# 1372: ('Cu3Ni', 'bridge', 'Cu_Ni|Cu', 'L12')
# 1373: ('Al3Pd', 'top', 'Pd', 'L12')
# 1374: ('Ir3Au', 'top', 'Au', 'L12')
# 1375: ('Cu3Ni', 'top', 'Ni', 'L12')
# 1376: ('Au3Os', 'top', 'Os', 'L12')
# 1377: ('Al3Ga', 'bridge', 'Al_Al|Al', 'L12')
# 1378: ('Ir3Fe', 'bridge', 'Ir_Ir|Ir', 'L12')
# 1379: ('Ir3Fe', 'top', 'Ir', 'L12')
# 1380: ('Al3Ga', 'bridge', 'Al_Al|Ga', 'L12')
# 1381: ('Ir3Fe', 'bridge', 'Ir_Ir|Fe', 'L12')
# 1382: ('Ir3Fe', 'top', 'Fe', 'L12')
# 1383: ('Al3Ga', 'top', 'Al', 'L12')
# 1384: ('Al3Ga', 'top', 'Ga', 'L12')
# 1385: ('Fe3Sn', 'top', 'Sn', 'L12')
# 1386: ('Ir2Pd2', 'bridge', 'Ir_Ir|Pd', 'L10')
# 1387: ('Ir2Pd2', 'bridge', 'Ir_Pd|Ir', 'L10')
# 1388: ('Ir2Pd2', 'bridge', 'Ir_Pd|Pd', 'L10')
# 1389: ('Ir2Pd2', 'hollow', 'Ir_Ir_Pd|FCC', 'L10')
# 1390: ('Ir2Pd2', 'top', 'Ir', 'L10')
# 1391: ('Rh2Pt2', 'bridge', 'Pt_Pt|Rh', 'L10')
# 1392: ('Rh2Pt2', 'bridge', 'Pt_Rh|Pt', 'L10')
# 1393: ('Rh2Pt2', 'bridge', 'Pt_Rh|Rh', 'L10')
# 1394: ('Rh2Pt2', 'bridge', 'Rh_Rh|Pt', 'L10')
# 1395: ('Rh2Pt2', 'hollow', 'Pt_Pt_Rh|HCP', 'L10')
# 1396: ('Rh2Pt2', 'hollow', 'Pt_Rh_Rh|HCP', 'L10')
# 1397: ('Rh2Pt2', 'top', 'Pt', 'L10')
# 1398: ('Rh2Pt2', 'top', 'Rh', 'L10')
# 1399: ('Ru2Ag2', 'bridge', 'Ru_Ru|Ag', 'L10')
# 1400: ('Ru2Ag2', 'hollow', 'Ag_Ag_Ru|FCC', 'L10')
# 1401: ('Sn3Au', 'bridge', 'Sn_Sn|Sn', 'L12')
# 1402: ('Sn3Au', 'top', 'Au', 'L12')
# 1403: ('Ag3Al', 'bridge', 'Ag_Ag|Ag', 'L12')
# 1404: ('Ag3Al', 'bridge', 'Ag_Ag|Al', 'L12')
# 1405: ('Ag3Al', 'top', 'Ag', 'L12')
# 1406: ('Ag3Al', 'top', 'Al', 'L12')
# 1407: ('Al3Rh', 'bridge', 'Al_Al|Al', 'L12')
# 1408: ('Al3Rh', 'bridge', 'Al_Al|Rh', 'L12')
# 1409: ('Al3Rh', 'top', 'Rh', 'L12')
# 1410: ('Al3Fe', 'bridge', 'Al_Al|Al', 'L12')
# 1411: ('Al3Fe', 'bridge', 'Al_Al|Fe', 'L12')
# 1412: ('Al3Fe', 'bridge', 'Al_Fe|Al', 'L12')
# 1413: ('Al3Pt', 'bridge', 'Al_Al|Al', 'L12')
# 1414: ('Al3Fe', 'top', 'Fe', 'L12')
# 1415: ('Al3Pt', 'bridge', 'Al_Al|Pt', 'L12')
# 1416: ('Al3Pt', 'top', 'Pt', 'L12')
# 1417: ('Au3Ir', 'top', 'Au', 'L12')
# 1418: ('Ga3Fe', 'top', 'Fe', 'L12')
# 1419: ('Au3Ir', 'bridge', 'Au_Au|Au', 'L12')
# 1420: ('Au3Ir', 'top', 'Ir', 'L12')
# 1421: ('Pt3Ni', 'bridge', 'Pt_Pt|Pt', 'L12')
# 1422: ('Pt3Ni', 'bridge', 'Pt_Pt|Ni', 'L12')
# 1423: ('Ag3Os', 'top', 'Os', 'L12')
# 1424: ('Sn3Al', 'top', 'Al', 'L12')
# 1425: ('Pt3Ni', 'top', 'Ni', 'L12')
# 1426: ('Ag3Os', 'bridge', 'Ag_Ag|Ag', 'L12')
# 1427: ('Al3Sn', 'bridge', 'Al_Al|Al', 'L12')
# 1428: ('Al3Sn', 'bridge', 'Al_Al|Sn', 'L12')
# 1429: ('Al3Sn', 'top', 'Al', 'L12')
# 1430: ('Cu3Sn', 'top', 'Sn', 'L12')
# 1431: ('Cu3Sn', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1432: ('Cu3Sn', 'bridge', 'Cu_Cu|Sn', 'L12')
# 1433: ('Rh3Os', 'bridge', 'Rh_Rh|Os', 'L12')
# 1434: ('Rh3Os', 'bridge', 'Rh_Os|Rh', 'L12')
# 1435: ('Rh3Os', 'top', 'Os', 'L12')
# 1436: ('Ru3Os', 'top', 'Os', 'L12')
# 1437: ('Ru3Sn', 'bridge', 'Ru_Ru|Ru', 'L12')
# 1438: ('Ru3Sn', 'top', 'Sn', 'L12')
# 1439: ('Ir3Ag', 'bridge', 'Ir_Ir|Ir', 'L12')
# 1440: ('Ir3Ag', 'bridge', 'Ir_Ir|Ag', 'L12')
# 1441: ('Ir3Ag', 'top', 'Ir', 'L12')
# 1442: ('Ir3Ag', 'top', 'Ag', 'L12')
# 1443: ('Co3Fe', 'bridge', 'Co_Co|Co', 'L12')
# 1444: ('Co3Au', 'bridge', 'Co_Co|Co', 'L12')
# 1445: ('Co3Au', 'bridge', 'Co_Co|Au', 'L12')
# 1446: ('Co3Au', 'top', 'Au', 'L12')
# 1447: ('Co3Fe', 'bridge', 'Co_Fe|Co', 'L12')
# 1448: ('Ag3Cu', 'top', 'Cu', 'L12')
# 1449: ('Os3Ir', 'bridge', 'Os_Os|Ir', 'L12')
# 1450: ('Os3Ir', 'bridge', 'Os_Ir|Os', 'L12')
# 1451: ('Os3Ir', 'top', 'Os', 'L12')
# 1452: ('Os3Ir', 'top', 'Ir', 'L12')
# 1453: ('Rh3Ir', 'bridge', 'Rh_Rh|Rh', 'L12')
# 1454: ('Rh3Ir', 'bridge', 'Rh_Rh|Ir', 'L12')
# 1455: ('Rh3Ir', 'bridge', 'Rh_Ir|Rh', 'L12')
# 1456: ('Rh3Ir', 'top', 'Ir', 'L12')
# 1457: ('Co3Rh', 'bridge', 'Co_Co|Co', 'L12')
# 1458: ('Co3Rh', 'bridge', 'Co_Co|Rh', 'L12')
# 1459: ('Co3Rh', 'bridge', 'Co_Rh|Co', 'L12')
# 1460: ('Co3Rh', 'top', 'Rh', 'L12')
# 1461: ('Pt3Rh', 'bridge', 'Pt_Pt|Pt', 'L12')
# 1462: ('Pt3Fe', 'bridge', 'Pt_Pt|Fe', 'L12')
# 1463: ('Pt3Rh', 'bridge', 'Pt_Pt|Rh', 'L12')
# 1464: ('Pt3Fe', 'bridge', 'Pt_Fe|Pt', 'L12')
# 1465: ('Pt3Rh', 'top', 'Pt', 'L12')
# 1466: ('Pt3Fe', 'top', 'Pt', 'L12')
# 1467: ('Pt3Rh', 'top', 'Rh', 'L12')
# 1468: ('Pt3Fe', 'top', 'Fe', 'L12')
# 1469: ('Pt3Fe', 'bridge', 'Pt_Pt|Pt', 'L12')
# 1470: ('Pd3Ni', 'top', 'Ni', 'L12')
# 1471: ('Pd3Co', 'top', 'Co', 'L12')
# 1472: ('Pd3Ni', 'bridge', 'Pd_Pd|Ni', 'L12')
# 1473: ('Pd3Ni', 'bridge', 'Pd_Ni|Pd', 'L12')
# 1474: ('Pd3Fe', 'bridge', 'Pd_Pd|Fe', 'L12')
# 1475: ('Pd3Fe', 'bridge', 'Pd_Fe|Pd', 'L12')
# 1476: ('Pd3Fe', 'top', 'Fe', 'L12')
# 1477: ('Pd3Os', 'bridge', 'Pd_Pd|Os', 'L12')
# 1478: ('Pd3Co', 'bridge', 'Pd_Co|Pd', 'L12')
# 1479: ('Pd3Os', 'bridge', 'Pd_Os|Pd', 'L12')
# 1480: ('Pd3Os', 'top', 'Os', 'L12')
# 1481: ('Au3Ru', 'top', 'Au', 'L12')
# 1482: ('Au3Ru', 'top', 'Ru', 'L12')
# 1483: ('Ag3Ru', 'top', 'Ag', 'L12')
# 1484: ('Ag3Ru', 'top', 'Ru', 'L12')
# 1485: ('Ag3Fe', 'top', 'Fe', 'L12')
# 1486: ('Cu3Rh', 'top', 'Rh', 'L12')
# 1487: ('Cu3Pd', 'top', 'Pd', 'L12')
# 1488: ('Cu3Pd', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1489: ('Cu3Pd', 'bridge', 'Cu_Cu|Pd', 'L12')
# 1490: ('Cu3Pd', 'bridge', 'Cu_Pd|Cu', 'L12')
# 1491: ('Cu3Ag', 'top', 'Ag', 'L12')
# 1492: ('Cu3Ag', 'bridge', 'Cu_Cu|Cu', 'L12')
# 1493: ('Cu3Ag', 'bridge', 'Cu_Cu|Ag', 'L12')
# 1494: ('Al3Bi', 'bridge', 'Al_Al|Bi', 'L12')
# 1495: ('Al3Bi', 'top', 'Bi', 'L12')
# 1496: ('Cu3Os', 'top', 'Os', 'L12')
# 1497: ('Cu3Rh', 'bridge', 'Cu_Rh|Cu', 'L12')
# 1498: ('Al3Ni', 'bridge', 'Al_Al|Al', 'L12')
# 1499: ('Al3Ru', 'bridge', 'Al_Al|Al', 'L12')
# 1500: ('Al3Ni', 'bridge', 'Al_Al|Ni', 'L12')
# 1501: ('Al3Ru', 'bridge', 'Al_Al|Ru', 'L12')
# 1502: ('Al3Ru', 'bridge', 'Al_Ru|Al', 'L12')
# 1503: ('Al3Ni', 'top', 'Ni', 'L12')
# 1504: ('Al3Ir', 'bridge', 'Al_Al|Al', 'L12')
# 1505: ('Al3Ir', 'bridge', 'Al_Al|Ir', 'L12')
# 1506: ('Al3Ru', 'top', 'Ru', 'L12')
# 1507: ('Al3Ir', 'top', 'Ir', 'L12')
# 1508: ('Al3Ag', 'bridge', 'Al_Al|Ag', 'L12')
# 1509: ('Al3Ag', 'top', 'Ag', 'L12')
# 1510: ('Ga3Rh', 'bridge', 'Ga_Ga|Rh', 'L12')
# 1511: ('Ga3Pd', 'bridge', 'Ga_Ga|Ga', 'L12')
# 1512: ('Ga3Ni', 'bridge', 'Ga_Ga|Ga', 'L12')
# 1513: ('Ga3Pd', 'bridge', 'Ga_Ga|Pd', 'L12')
# 1514: ('Ga3Ni', 'top', 'Ni', 'L12')
# 1515: ('Ga3Cu', 'bridge', 'Ga_Ga|Cu', 'L12')
# 1516: ('Ga3Cu', 'top', 'Cu', 'L12')
# 1517: ('Ga3Sn', 'bridge', 'Ga_Ga|Ga', 'L12')
# 1518: ('Ga3Sn', 'bridge', 'Ga_Ga|Sn', 'L12')
# 1519: ('Ga3Sn', 'bridge', 'Ga_Sn|Ga', 'L12')
# 1520: ('Ga3Sn', 'top', 'Ga', 'L12')
# 1521: ('Ga3Sn', 'top', 'Sn', 'L12')
# 1522: ('Ga3Bi', 'top', 'Ga', 'L12')
# 1523: ('Ga3Bi', 'top', 'Bi', 'L12')
# 1524: ('Sn3Ni', 'top', 'Ni', 'L12')
# 1525: ('Sn3Pd', 'top', 'Pd', 'L12')
# 1526: ('Sn3Ir', 'top', 'Ir', 'L12')
# 1527: ('Sn3Ag', 'bridge', 'Sn_Sn|Sn', 'L12')
# 1528: ('Sn3Ag', 'bridge', 'Sn_Sn|Ag', 'L12')
# 1529: ('Sn3Ag', 'top', 'Ag', 'L12')
# 1530: ('Sn3Bi', 'top', 'Bi', 'L12')
# 1531: ('Bi3Ir', 'top', 'Ir', 'L12')
# 1532: ('Bi3Os', 'top', 'Os', 'L12')
# 1533: ('Bi3Al', 'bridge', 'Bi_Bi|Bi', 'L12')
# 1534: ('Bi3Al', 'top', 'Bi', 'L12')
# 1535: ('Bi3Al', 'top', 'Al', 'L12')
# 1536: ('Sn3Ga', 'bridge', 'Sn_Sn|Sn', 'L12')
# 1537: ('Sn3Ga', 'bridge', 'Sn_Sn|Ga', 'L12')
# 1538: ('Sn3Ga', 'top', 'Ga', 'L12')
# 1539: ('Fe', 'hollow', 'Fe_Fe_Fe|FCC', 'A1')
# 1540: ('Bi3Ga', 'top', 'Ga', 'L12')
# 1541: ('Bi3Sn', 'bridge', 'Bi_Bi|Sn', 'L12')
# 1542: ('Bi3Sn', 'top', 'Sn', 'L12')
