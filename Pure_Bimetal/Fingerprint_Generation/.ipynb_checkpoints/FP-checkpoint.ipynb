# %%
import numpy as np
from ase.io import read
from ase.db import connect
from collections import Counter
from catkit.pawprint import Fingerprinter
import sys
from ase.build import bulk
from catkit.gen.surface import SlabGenerator
from ase import Atoms
import pkg_resources
import json
from ase.data import atomic_numbers
import pickle

# %%
parameters_list_nonlocal = []

parameters_list_nonlocal += [['atomic_number',
                              'atomic_radius',
                              'dband_center_slab',
                              'dband_width_slab',
                              'dband_skewness_slab',
                              'dband_kurtosis_slab',
                              'dipole_polarizability',
                              'electron_affinity',
                              'heat_of_formation',
                              'specific_heat']]
parameters_list_nonlocal += [parameters_list_nonlocal[-1]]

parameters_list_nonlocal += [['atomic_number',
                              'atomic_radius',
                              'dband_center_slab',
                              'dband_width_slab',
                              'dipole_polarizability',
                              'electron_affinity',
                              'heat_of_formation',
                              'specific_heat',
                              'en_allen']]

# %%
def get_slab(symbol):
    data = np.load('bulk_data.npy')[()]

    try:
        a = data[symbol]['a']
        c = data[symbol]['c']
    except KeyError:
        if '2' in symbol:
            m1, m2, _ = symbol.split('2')
            try:
                a = data[m1 + '2' + m2 + '2']['a']
                c = data[m1 + '2' + m2 + '2']['c']
            except KeyError:
                a = data[m2 + '2' + m1 + '2']['a']
                c = data[m2 + '2' + m1 + '2']['c']

    if '2' in symbol:
        m1, m2, _ = symbol.split('2')
        name = m1 + '2' + m2 + '2'
        b=Atoms(name,
                scaled_positions=[(0, 0, 0),
                                  (0.5, 0.5, 0),
                                  (0.5, 0, 0.5),
                                  (0, 0.5, 0.5)],
                cell=[a, a, c],
                pbc=True)
        b.set_pbc((1,1,1))
    elif '3' in symbol:
        m1, m2 = symbol.split('3')
        b = bulk(m1, cubic=True, crystalstructure='fcc', a=a, c=c)
        b[3].symbol = m2
    else:
        b = bulk(symbol, cubic=True, crystalstructure='fcc', a=a, c=c)

    gen = SlabGenerator(b,
            miller_index=(1, 1, 1),
            vacuum=10,
            layers=3,
            fixed=2,
            layer_type='trim',
            standardize_bulk=False,
            primitive=False)


    return gen.get_slab(size=(1, 1), iterm=-1)

# %%
path = pkg_resources.resource_filename('catkit', 'data/properties.json')
with open(path, 'r') as f:
    properties_data = json.load(f)

# %%
def get_ads_fp(A, B):
    with open('pure_data.pkl', 'rb') as f:
        pure_data = pickle.load(f)
    pure_data = pure_data[B]
    parameters = ['atomic_number',
                  'atomic_radius',
                  'dband_center_slab',
                  'dband_width_slab',
                  'dband_skewness_slab',
                  'dband_kurtosis_slab',
                  'dipole_polarizability',
                  'electron_affinity',
                  'heat_of_formation',
                  'specific_heat']
    
    if A[3] == "L12":
        a, b = A[0].split('3')
        num = [atomic_numbers[a], atomic_numbers[b]]
        pure_d = [pure_data[a], pure_data[b]]
    if A[3] == "L10":  
        a, b, _ = A[0].split('2')
        num = [atomic_numbers[a], atomic_numbers[b]]
        pure_d = [pure_data[a], pure_data[b]]
    atoms_parameters = np.zeros((len(parameters), len(num)))
    for i, k in enumerate(parameters):
        atoms_parameters[i] = np.asarray(properties_data[k])[num]
    
    if A[3] == 'L12':
        if A[1] == 'top':
            if A[2] == a:
                JD0U = pure_d[0][1]
                JD0S = JD0U
                JD1U = 4 * pure_d[0][1] + 2 * pure_d[1][1]
                JD1S = JD1U/6
                JD2U = 10 * pure_d[0][1] + 2 * pure_d[1][1]
                JD2S = JD2U/12
                AD0U = atoms_parameters[:, 0].reshape(-1)
                AD0S = atoms_parameters[:, 0].reshape(-1)
                AD1U = 4 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/6
                AD2U = 10 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/12
                SSU = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                SSS = SSU/3
            if A[2] == b:
                JD0U = pure_d[1][1]
                JD0S = JD0U
                JD1U = 6 * pure_d[0][1]
                JD1S = JD1U/6
                JD2U = 6 * pure_d[0][1] + 6 * pure_d[1][1]
                JD2S = JD2U/12
                AD0U = atoms_parameters[:, 1].reshape(-1)
                AD0S = atoms_parameters[:, 1].reshape(-1)
                AD1U = 6 * atoms_parameters[:, 0].reshape(-1) 
                AD1S = AD1U/6
                AD2U = 6 * atoms_parameters[:, 0].reshape(-1) + 6 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/12
                SSU = 3 * atoms_parameters[:, 0].reshape(-1) 
                SSS = atoms_parameters[:, 0].reshape(-1)
        if A[1] == 'bridge':
            m, o = A[2].split('|')
            m, n = m.split('_')
            if m == n:
                JD0U = 2 * pure_d[0][2]
                JD0S = JD0U/2
                JD1U = 5 * pure_d[0][2] + 3 * pure_d[1][2]
                JD1S = JD1U/8
                JD2U = 12 * pure_d[0][2] + 2 * pure_d[1][2]
                JD2S = JD2U/14
                AD0U = 2 * atoms_parameters[:, 0].reshape(-1)
                AD0S = AD0U/2
                AD1U = 5 * atoms_parameters[:, 0].reshape(-1) + 3 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/8
                AD2U = 12 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/14
                if o == a:
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
                else:
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = atoms_parameters[:, 1].reshape(-1)
            else:
                JD0U = pure_d[0][2] + pure_d[1][2]
                JD0S = JD0U/2
                JD1U = 7 * pure_d[0][2] + pure_d[1][2]
                JD1S = JD1U/8
                JD2U = 9 * pure_d[0][2] + 5 * pure_d[1][2]
                JD2S = JD2U/14
                AD0U = atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/2
                AD1U = 7 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/8
                AD2U = 9 * atoms_parameters[:, 0].reshape(-1) + 5 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/14
                SSU = atoms_parameters[:, 0].reshape(-1)
                SSS = SSU
        if A[1] == 'hollow':
            if Counter(A[2].split('|')[0].split('_'))[a] == 3:
                AD0U = 3 * atoms_parameters[:, 0].reshape(-1)
                AD0S = AD0U/3
                AD1U = 6 * atoms_parameters[:, 0].reshape(-1) + 3 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/9
                AD2U = 12 * atoms_parameters[:, 0].reshape(-1) + 3 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/15
                if 'FCC' in A[2]:
                    SSU = 3 * atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU/3
                    JD0U = 3 * pure_d[0][3]
                    JD0S = JD0U/3
                    JD1U = 6 * pure_d[0][3] + 3 * pure_d[1][3]
                    JD1S = JD1U/9
                    JD2U = 12 * pure_d[0][3] + 3 * pure_d[1][3]
                    JD2S = JD2U/15
                else:
                    SSU =  atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU
                    JD0U = 3 * pure_d[0][4]
                    JD0S = JD0U/3
                    JD1U = 6 * pure_d[0][4] + 3 * pure_d[1][4]
                    JD1S = JD1U/9
                    JD2U = 12 * pure_d[0][4] + 3 * pure_d[1][4]
                    JD2S = JD2U/15
            else:
                AD0U = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/3
                AD1U = 7 * atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/9
                AD2U = 11 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/15  
                if 'FCC' in A[2]:
                    SSU = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU/3
                    JD0U = 2 * pure_d[0][3] + pure_d[1][3]
                    JD0S = JD0U/3
                    JD1U = 7 * pure_d[0][3] + 2 * pure_d[1][3]
                    JD1S = JD1U/9
                    JD2U = 11 * pure_d[0][3] + 4 * pure_d[1][3]
                    JD2S = JD2U/15
                else:
                    SSU =  atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
                    JD0U = 2 * pure_d[0][4] + pure_d[1][4]
                    JD0S = JD0U/3
                    JD1U = 7 * pure_d[0][4] + 2 * pure_d[1][4]
                    JD1S = JD1U/9
                    JD2U = 11 * pure_d[0][4] + 4 * pure_d[1][4]
                    JD2S = JD2U/15
    if A[3] == 'L10':
        if A[1] == 'top':
            if A[2] == a:
                JD0U = pure_d[0][1] 
                JD0S = JD0U
                JD1U = 2 * pure_d[0][1] + 4 * pure_d[1][1]
                JD1S = JD1U/6
                JD2U = 8 * pure_d[0][1] + 4 * pure_d[1][1]
                JD2S = JD2U/12
                AD0U = atoms_parameters[:, 0].reshape(-1) 
                AD0S = AD0U
                AD1U = 2 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/6
                AD2U = 8 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/12
                SSU = atoms_parameters[:, 0].reshape(-1) + 2 * atoms_parameters[:, 1].reshape(-1)
                SSS = SSU/3
            else:
                JD0U = pure_d[1][1] 
                JD0S = JD0U
                JD1U = 2 * pure_d[1][1] + 4 * pure_d[0][1]
                JD1S = JD1U/6
                JD2U = 8 * pure_d[1][1] + 4 * pure_d[0][1]
                JD2S = JD2U/12
                AD0U = atoms_parameters[:, 1].reshape(-1) 
                AD0S = AD0U
                AD1U = 2 * atoms_parameters[:, 1].reshape(-1) + 4 * atoms_parameters[:, 0].reshape(-1)
                AD1S = AD1U/6
                AD2U = 8 * atoms_parameters[:, 1].reshape(-1) + 4 * atoms_parameters[:, 0].reshape(-1)
                AD2S = AD2U/12
                SSU = atoms_parameters[:, 1].reshape(-1) + 2 * atoms_parameters[:, 0].reshape(-1)
                SSS = SSU/3
        if A[1] == 'bridge':
            m, o = A[2].split('|')
            m, n = m.split('_')
            if m == n:
                if m == a:
                    JD0U = 2 * pure_d[0][2] 
                    JD0S = JD0U/2
                    JD1U = 2 * pure_d[0][2] + 6 * pure_d[1][2]
                    JD1S = JD1U/8
                    JD2U = 10 * pure_d[0][2] + 4 * pure_d[1][2]
                    JD2S = JD2U/14
                    AD0U = 2 * atoms_parameters[:, 0].reshape(-1) 
                    AD0S = AD0U/2
                    AD1U = 2 * atoms_parameters[:, 0].reshape(-1) + 6 * atoms_parameters[:, 1].reshape(-1)
                    AD1S = AD1U/8
                    AD2U = 10 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                    AD2S = AD2U/14
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU
                else:
                    JD0U = 2 * pure_d[1][2] 
                    JD0S = JD0U/2
                    JD1U = 2 * pure_d[1][2] + 6 * pure_d[0][2]
                    JD1S = JD1U/8
                    JD2U = 10 * pure_d[1][2] + 4 * pure_d[0][2]
                    JD2S = JD2U/14
                    AD0U = 2 * atoms_parameters[:, 1].reshape(-1) 
                    AD0S = AD0U/2
                    AD1U = 2 * atoms_parameters[:, 1].reshape(-1) + 6 * atoms_parameters[:, 0].reshape(-1)
                    AD1S = AD1U/8
                    AD2U = 10 * atoms_parameters[:, 1].reshape(-1) + 4 * atoms_parameters[:, 0].reshape(-1)
                    AD2S = AD2U/14
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
            else:
                JD0U = pure_d[0][2] + pure_d[1][2] 
                JD0S = JD0U/2
                JD1U = 4 * pure_d[0][2] + 4 * pure_d[1][2]
                JD1S = JD1U/8
                JD2U = 7 * pure_d[0][2] + 7 * pure_d[1][2]
                JD2S = JD2U/14
                AD0U = atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/2
                AD1U = 4 * atoms_parameters[:, 0].reshape(-1) + 4 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/8
                AD2U = 7 * atoms_parameters[:, 0].reshape(-1) + 7 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/14
                if o == a:
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
                else:
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU
        if A[1] == 'hollow':
            if A[2].split('|')[0].split('_').count(a) == 2:
                AD0U = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                AD0S = AD0U/3
                AD1U = 4 * atoms_parameters[:, 0].reshape(-1) + 5 * atoms_parameters[:, 1].reshape(-1)
                AD1S = AD1U/9
                AD2U = 8 * atoms_parameters[:, 0].reshape(-1) + 7 * atoms_parameters[:, 1].reshape(-1)
                AD2S = AD2U/15
                if 'FCC' in A[2]:
                    JD0U = 2 * pure_d[0][3] + pure_d[1][3] 
                    JD0S = JD0U/3
                    JD1U = 4 * pure_d[0][3] + 5 * pure_d[1][3]
                    JD1S = JD1U/9
                    JD2U = 8 * pure_d[0][3] + 7 * pure_d[1][3]
                    JD2S = JD2U/15
                    SSU = 2 * atoms_parameters[:, 0].reshape(-1) + atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU/3
                else:
                    JD0U = 2 * pure_d[0][4] + pure_d[1][4] 
                    JD0S = JD0U/3
                    JD1U = 4 * pure_d[0][4] + 5 * pure_d[1][4]
                    JD1S = JD1U/9
                    JD2U = 8 * pure_d[0][4] + 7 * pure_d[1][4]
                    JD2S = JD2U/15
                    SSU = atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU
                    
            else:
                AD0U = 2 * atoms_parameters[:, 1].reshape(-1) + atoms_parameters[:, 0].reshape(-1)
                AD0S = AD0U/3
                AD1U = 4 * atoms_parameters[:, 1].reshape(-1) + 5 * atoms_parameters[:, 0].reshape(-1)
                AD1S = AD1U/9
                AD2U = 8 * atoms_parameters[:, 1].reshape(-1) + 7 * atoms_parameters[:, 0].reshape(-1)
                AD2S = AD2U/15
                if 'FCC' in A[2]:
                    JD0U = 2 * pure_d[1][3] + pure_d[0][3] 
                    JD0S = JD0U/3
                    JD1U = 4 * pure_d[1][3] + 5 * pure_d[0][3]
                    JD1S = JD1U/9
                    JD2U = 8 * pure_d[1][3] + 7 * pure_d[0][3]
                    JD2S = JD2U/15
                    SSU = 2 * atoms_parameters[:, 1].reshape(-1) + atoms_parameters[:, 0].reshape(-1)
                    SSS = SSU/3
                else:
                    JD0U = 2 * pure_d[1][4] + pure_d[0][4] 
                    JD0S = JD0U/3
                    JD1U = 4 * pure_d[1][4] + 5 * pure_d[0][4]
                    JD1S = JD1U/9
                    JD2U = 8 * pure_d[1][4] + 7 * pure_d[0][4]
                    JD2S = JD2U/15
                    SSU = atoms_parameters[:, 1].reshape(-1)
                    SSS = SSU                  
    
    return JD0U, JD0S, JD1U, JD1S, JD2U, JD2S, AD0U, AD1U, AD2U, SSU, AD0S, AD1S, AD2S, SSS

# %%
with open('pure_data.pkl', 'rb') as f:
    pure_data = pickle.load(f)

adsorbates = ['C', 'O', 'N', 'S', 'H']
'''data_format = [metadata, Jac_d0_unscaled, Jac_d0_scaled, Jac_d1_unscaled, Jac_d1_scaled,
                  Jac_d2_unscaled, Jac_d2_scled, slab_d0, slab_d1, bimetal_fp, 
                  ads_d0_unscaled, ads_d1_unscaled, ads_d2_unscaled, SS_unscaled,
                  ads_d0_scaled, ads_d1_scaled, ads_d2_scaled, SS_scaled,
                  energy, energy_A]'''
for ads in adsorbates:
    print('Working on adsorbates: {}'.format(ads))
    data = []
    db =connect('{}_atoms.db'.format(ads))
    cnt = 0
    for i in db.select():
        if len(i.toatoms()) != 12:
            continue
        if i.sb_symbol == 'A1':
            continue
        cnt += 1
        if i.sb_symbol == 'L12':
            a, b = i.symbol.split('3')
        if i.sb_symbol == 'L10':
            a, b, _ = i.symbol.split('2')
        #if pure metal a and b data for the site exists then proceed otherwise break
        PD_a = pure_data[ads][a]
        PD_b = pure_data[ads][b]
        scorrespond = {'top': 1, 'bridge': 2, 'FCC': 3, 'HCP': 4}
        if i.site in ['top', 'bridge']:
            site = i.site
        else:
            site = i.site_type.split('|')[1]
        if PD_a[scorrespond[site]] == None or PD_b[scorrespond[site]] == None:
            continue
        slab = get_slab(i.symbol)
        metadata = tuple([i.symbol, i.site, i.site_type, i.sb_symbol])
        print('{}: {}'.format(cnt, metadata))
        energy = i.reaction_energy
        fp_slab = Fingerprinter(slab)
        slab_d0 = fp_slab.get_fp(parameters_list_nonlocal[0],
                                 ['periodic_convolution'])
        slab_d1 = fp_slab.get_fp(parameters_list_nonlocal[1],
                                 [['periodic_convolution', {'d': 1}]])
        bimetal_fp = fp_slab.get_fp(parameters_list_nonlocal[2],
                                 ['bimetal_fp'])
        
        Jac_d0_unscaled, Jac_d0_scaled, Jac_d1_unscaled, Jac_d1_scaled, Jac_d2_unscaled, \
        Jac_d2_scaled, ads_d0_unscaled, ads_d1_unscaled, ads_d2_unscaled, subsurface_unscaled,\
        ads_d0_scaled, ads_d1_scaled, ads_d2_scaled, subsurface_scaled = get_ads_fp(metadata, ads)
        

        temp = [metadata, Jac_d0_unscaled, Jac_d0_scaled, Jac_d1_unscaled, Jac_d1_scaled, 
                Jac_d2_unscaled, Jac_d2_scaled, slab_d0, slab_d1, bimetal_fp, ads_d0_unscaled, 
                ads_d1_unscaled, ads_d2_unscaled, subsurface_unscaled, ads_d0_scaled, 
                ads_d1_scaled, ads_d2_scaled, subsurface_scaled, energy]

        data +=[temp]                
    np.save('{}_data.npy'.format(ads), data)
# Out:
# Working on adsorbates: C
# /Users/osmanmamun/Suncat_Code_Base/CatKit/catkit/gen/surface.py:106: UserWarning: Not using a standardized bulk will result in an arbitrary Miller index. To get ensure you are using the correct miller index, use standardize_bulk=True
#   ("Not using a standardized bulk will result in an arbitrary "
# /Users/osmanmamun/Suncat_Code_Base/CatKit/catkit/gratoms.py:325: UserWarning: Edge conservation not currently supported with pbc. Remove pbc or edges first.
#   ("Edge conservation not currently supported with "
# 1: ('Pd2Ag2', 'hollow', 'Ag_Ag_Pd|FCC', 'L10')
# 2: ('Re2Ga2', 'hollow', 'Ga_Re_Re|FCC', 'L10')
# 3: ('Ta2Ag2', 'hollow', 'Ag_Ag_Ta|HCP', 'L10')
# 4: ('Pd2Au2', 'hollow', 'Au_Pd_Pd|HCP', 'L10')
# 6: ('Pd2Ag2', 'hollow', 'Ag_Ag_Pd|HCP', 'L10')
# 7: ('Ta2Ag2', 'hollow', 'Ag_Ta_Ta|FCC', 'L10')
# 8: ('Pd2Au2', 'hollow', 'Au_Au_Pd|FCC', 'L10')
# 9: ('Mo2Ir2', 'hollow', 'Ir_Ir_Mo|HCP', 'L10')
# 11: ('Ta2Ag2', 'hollow', 'Ag_Ta_Ta|HCP', 'L10')
# 15: ('Zr2Ru2', 'hollow', 'Ru_Zr_Zr|FCC', 'L10')
# 16: ('Mo2Ir2', 'hollow', 'Ir_Mo_Mo|FCC', 'L10')
# 17: ('Zr2Ta2', 'hollow', 'Ta_Ta_Zr|FCC', 'L10')
# 19: ('Ta2Ga2', 'hollow', 'Ga_Ga_Ta|FCC', 'L10')
# 20: ('Zr2Ta2', 'hollow', 'Ta_Ta_Zr|HCP', 'L10')
# 22: ('Ta2Ga2', 'hollow', 'Ga_Ga_Ta|HCP', 'L10')
# 24: ('Nb3Cr', 'top', 'Cr', 'L12')
# 25: ('Zr2Ta2', 'hollow', 'Ta_Zr_Zr|FCC', 'L10')
# 27: ('Ta2Ga2', 'hollow', 'Ga_Ta_Ta|FCC', 'L10')
# 29: ('Ti2V2', 'hollow', 'Ti_Ti_V|FCC', 'L10')
# 30: ('Zr2Ta2', 'hollow', 'Ta_Zr_Zr|HCP', 'L10')
# 31: ('Ta2Ga2', 'hollow', 'Ga_Ta_Ta|HCP', 'L10')
# 33: ('Ti2V2', 'hollow', 'Ti_Ti_V|HCP', 'L10')
# 34: ('Zr2Hf2', 'hollow', 'Hf_Hf_Zr|FCC', 'L10')
# 36: ('Ti2V2', 'hollow', 'Ti_V_V|FCC', 'L10')
# 37: ('Zr2Hf2', 'hollow', 'Hf_Hf_Zr|HCP', 'L10')
# 38: ('Ta2W2', 'hollow', 'Ta_Ta_W|FCC', 'L10')
# 39: ('Zr2Ti2', 'hollow', 'Ti_Zr_Zr|FCC', 'L10')
# 41: ('Hf2Cr2', 'hollow', 'Cr_Hf_Hf|FCC', 'L10')
# 42: ('Mo2Pd2', 'hollow', 'Mo_Mo_Pd|FCC', 'L10')
# 43: ('Mo2Pd2', 'hollow', 'Mo_Pd_Pd|FCC', 'L10')
# 44: ('Mo2Pd2', 'hollow', 'Mo_Mo_Pd|HCP', 'L10')
# 45: ('Mo2Pd2', 'hollow', 'Mo_Pd_Pd|HCP', 'L10')
# 46: ('V2Cr2', 'hollow', 'Cr_Cr_V|FCC', 'L10')
# 47: ('Ti2V2', 'hollow', 'Ti_V_V|HCP', 'L10')
# 48: ('Zr2Hf2', 'hollow', 'Hf_Zr_Zr|FCC', 'L10')
# 49: ('Ta2W2', 'hollow', 'Ta_Ta_W|HCP', 'L10')
# 50: ('V2Cr2', 'hollow', 'Cr_Cr_V|HCP', 'L10')
# 51: ('Zr2Hf2', 'hollow', 'Hf_Zr_Zr|HCP', 'L10')
# 52: ('Ta2W2', 'hollow', 'Ta_W_W|FCC', 'L10')
# 54: ('Sc2Cu2', 'hollow', 'Cu_Sc_Sc|FCC', 'L10')
# 55: ('V2Cr2', 'hollow', 'Cr_V_V|FCC', 'L10')
# 56: ('Ta2W2', 'hollow', 'Ta_W_W|HCP', 'L10')
# 57: ('Zr2Ti2', 'hollow', 'Ti_Zr_Zr|HCP', 'L10')
# 60: ('V2Cr2', 'hollow', 'Cr_V_V|HCP', 'L10')
# 61: ('Mo2W2', 'hollow', 'Mo_Mo_W|FCC', 'L10')
# 62: ('Zr2Cd2', 'hollow', 'Cd_Cd_Zr|FCC', 'L10')
# 64: ('Mo2W2', 'hollow', 'Mo_Mo_W|HCP', 'L10')
# 65: ('Zr2Cd2', 'hollow', 'Cd_Cd_Zr|HCP', 'L10')
# 66: ('Mo2W2', 'hollow', 'Mo_W_W|FCC', 'L10')
# 68: ('Zr2Cd2', 'hollow', 'Cd_Zr_Zr|FCC', 'L10')
# 69: ('Cr3Sn', 'top', 'Sn', 'L12')
# 70: ('Mo2W2', 'hollow', 'Mo_W_W|HCP', 'L10')
# 71: ('Cu2In2', 'hollow', 'Cu_Cu_In|HCP', 'L10')
# 72: ('Zr2Cd2', 'hollow', 'Cd_Zr_Zr|HCP', 'L10')
# 73: ('Os2Co2', 'hollow', 'Co_Co_Os|FCC', 'L10')
# 74: ('Cu2In2', 'hollow', 'Cu_In_In|FCC', 'L10')
# 76: ('Cu2In2', 'hollow', 'Cu_In_In|HCP', 'L10')
# 77: ('Os2Co2', 'hollow', 'Co_Co_Os|HCP', 'L10')
# 78: ('Os2Co2', 'hollow', 'Co_Os_Os|FCC', 'L10')
# 79: ('Pt2Sn2', 'hollow', 'Pt_Pt_Sn|HCP', 'L10')
# 80: ('Mo2Rh2', 'hollow', 'Mo_Mo_Rh|FCC', 'L10')
# 81: ('Mo2Rh2', 'hollow', 'Mo_Rh_Rh|HCP', 'L10')
# 83: ('Tc2Ag2', 'hollow', 'Ag_Tc_Tc|FCC', 'L10')
# 85: ('Pd2Al2', 'top', 'Al', 'L10')
# 86: ('Y2Sc2', 'hollow', 'Sc_Sc_Y|HCP', 'L10')
# 87: ('Mo2Rh2', 'hollow', 'Mo_Mo_Rh|HCP', 'L10')
# 88: ('Pd2Al2', 'top', 'Pd', 'L10')
# 89: ('Os2Co2', 'hollow', 'Co_Os_Os|HCP', 'L10')
# 91: ('Y2Sc2', 'hollow', 'Sc_Y_Y|FCC', 'L10')
# 92: ('Mo2Rh2', 'hollow', 'Mo_Rh_Rh|FCC', 'L10')
# 93: ('W2Ru2', 'hollow', 'Ru_Ru_W|FCC', 'L10')
# 94: ('W2Ru2', 'hollow', 'Ru_W_W|HCP', 'L10')
# 95: ('Os2Co2', 'top', 'Os', 'L10')
# 96: ('Y2Sc2', 'hollow', 'Sc_Y_Y|HCP', 'L10')
# 97: ('Cr2W2', 'top', 'Cr', 'L10')
# 98: ('W2Ru2', 'hollow', 'Ru_Ru_W|HCP', 'L10')
# 99: ('Sc2Nb2', 'hollow', 'Nb_Nb_Sc|FCC', 'L10')
# 100: ('Sc2Nb2', 'hollow', 'Nb_Sc_Sc|FCC', 'L10')
# 101: ('Cr2W2', 'top', 'W', 'L10')
# 102: ('W2Ru2', 'hollow', 'Ru_W_W|FCC', 'L10')
# 103: ('Tl2Pb2', 'hollow', 'Pb_Tl_Tl|FCC', 'L10')
# 105: ('Tl2Pb2', 'hollow', 'Pb_Tl_Tl|HCP', 'L10')
# 106: ('Sc2Nb2', 'hollow', 'Nb_Sc_Sc|HCP', 'L10')
# 107: ('Cr3Nb', 'top', 'Nb', 'L12')
# 108: ('V2Sn2', 'hollow', 'Sn_Sn_V|HCP', 'L10')
# 109: ('Cr3Ti', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 110: ('Cr3Ti', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 111: ('Cr3Nb', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 114: ('Cr2Fe2', 'hollow', 'Cr_Cr_Fe|FCC', 'L10')
# 119: ('Cr3Pd', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 120: ('Cr3Pd', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 122: ('Cr3Au', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 123: ('Cr2Au2', 'hollow', 'Au_Au_Cr|FCC', 'L10')
# 124: ('Cr2Au2', 'hollow', 'Au_Au_Cr|HCP', 'L10')
# 125: ('Cr3Ag', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 126: ('Cr3Hf', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 127: ('Cr3Cu', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 128: ('Cr3Cu', 'hollow', 'Cr_Cr_Cu|FCC', 'L12')
# 129: ('Cr3Al', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 130: ('Cr3Al', 'top', 'Al', 'L12')
# 131: ('Cr3Ga', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 132: ('Cr2Ga2', 'hollow', 'Cr_Cr_Ga|HCP', 'L10')
# 133: ('Cr3Tl', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 138: ('Cr3In', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 139: ('Mo3Zr', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 140: ('Mo3Hf', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 141: ('Mo3Zr', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 143: ('Mo3Ti', 'hollow', 'Mo_Mo_Ti|HCP', 'L12')
# 144: ('Mo3Ta', 'hollow', 'Mo_Mo_Ta|FCC', 'L12')
# 145: ('Mo3V', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 146: ('Mo3W', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 147: ('Mo3V', 'hollow', 'Mo_Mo_V|HCP', 'L12')
# 148: ('Mo3W', 'hollow', 'Mo_Mo_W|HCP', 'L12')
# 149: ('Mo3Re', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 150: ('Mo3Tc', 'hollow', 'Mo_Mo_Tc|FCC', 'L12')
# 151: ('Mo3Os', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 152: ('Mo3Os', 'hollow', 'Mo_Mo_Os|HCP', 'L12')
# 153: ('Mo3Re', 'hollow', 'Mo_Mo_Re|HCP', 'L12')
# 154: ('Mo3Tc', 'hollow', 'Mo_Mo_Tc|HCP', 'L12')
# 156: ('Mo3Ir', 'hollow', 'Mo_Mo_Ir|HCP', 'L12')
# 157: ('Mo2Ir2', 'hollow', 'Ir_Mo_Mo|HCP', 'L10')
# 158: ('Mo3Rh', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 159: ('Mo3Rh', 'hollow', 'Mo_Mo_Rh|HCP', 'L12')
# 161: ('Mo3Rh', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 162: ('Mo3Rh', 'top', 'Rh', 'L12')
# 163: ('Mo3Fe', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 169: ('Mo3Pt', 'hollow', 'Mo_Mo_Pt|HCP', 'L12')
# 171: ('Mo3Pd', 'top', 'Mo', 'L12')
# 172: ('Mo3Pd', 'top', 'Pd', 'L12')
# 174: ('Mo3Au', 'top', 'Mo', 'L12')
# 175: ('Mo3Ag', 'top', 'Ag', 'L12')
# 176: ('Mo3Au', 'top', 'Au', 'L12')
# 177: ('Mo3Cu', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 178: ('Mo3Cu', 'hollow', 'Mo_Mo_Cu|HCP', 'L12')
# 179: ('Mo3Zn', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 181: ('Mo3In', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 184: ('Mo3Sn', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 187: ('W3La', 'hollow', 'W_W_W|HCP', 'L12')
# 188: ('Mo2Sn2', 'hollow', 'Mo_Mo_Sn|FCC', 'L10')
# 189: ('W3Ta', 'hollow', 'W_W_Ta|HCP', 'L12')
# 190: ('W3Cr', 'hollow', 'W_W_W|FCC', 'L12')
# 191: ('W3Cr', 'hollow', 'W_W_W|HCP', 'L12')
# 193: ('W3Tc', 'hollow', 'W_W_Tc|FCC', 'L12')
# 194: ('W3Tc', 'top', 'Tc', 'L12')
# 195: ('W3Tc', 'hollow', 'W_W_Tc|HCP', 'L12')
# 196: ('W3Os', 'hollow', 'W_W_Os|FCC', 'L12')
# 197: ('W3Os', 'top', 'Os', 'L12')
# 198: ('W2Os2', 'hollow', 'Os_Os_W|HCP', 'L10')
# 199: ('W3Os', 'hollow', 'W_W_Os|HCP', 'L12')
# 201: ('W2Os2', 'hollow', 'Os_W_W|FCC', 'L10')
# 202: ('W2Os2', 'hollow', 'Os_Os_W|FCC', 'L10')
# 203: ('W2Os2', 'hollow', 'Os_W_W|HCP', 'L10')
# 204: ('W3Ir', 'hollow', 'W_W_Ir|HCP', 'L12')
# 205: ('W3Ir', 'hollow', 'W_W_W|FCC', 'L12')
# 206: ('W3Rh', 'hollow', 'W_W_W|HCP', 'L12')
# 207: ('W3Rh', 'top', 'Rh', 'L12')
# 210: ('W3Fe', 'hollow', 'W_W_W|FCC', 'L12')
# 212: ('W3Pt', 'hollow', 'W_W_W|FCC', 'L12')
# 213: ('W3Pt', 'hollow', 'W_W_Pt|HCP', 'L12')
# 214: ('W3Fe', 'hollow', 'W_W_Fe|FCC', 'L12')
# 216: ('W3Pt', 'hollow', 'W_W_W|HCP', 'L12')
# 217: ('W3Pt', 'top', 'Pt', 'L12')
# 218: ('W2Pt2', 'hollow', 'Pt_Pt_W|HCP', 'L10')
# 219: ('W3Pd', 'hollow', 'W_W_Pd|HCP', 'L12')
# 221: ('W2Pt2', 'hollow', 'Pt_Pt_W|FCC', 'L10')
# 222: ('W2Pt2', 'hollow', 'Pt_W_W|FCC', 'L10')
# 223: ('W2Pt2', 'hollow', 'Pt_W_W|HCP', 'L10')
# 224: ('W3Pd', 'hollow', 'W_W_W|FCC', 'L12')
# 225: ('W3Cu', 'hollow', 'W_W_W|FCC', 'L12')
# 226: ('W3Cu', 'hollow', 'W_W_Cu|HCP', 'L12')
# 228: ('W3Zn', 'hollow', 'W_W_W|FCC', 'L12')
# 229: ('W3Cd', 'hollow', 'W_W_W|FCC', 'L12')
# 232: ('W3Cd', 'hollow', 'W_W_W|HCP', 'L12')
# 234: ('W2Al2', 'hollow', 'Al_Al_W|FCC', 'L10')
# 235: ('W2Al2', 'hollow', 'Al_Al_W|HCP', 'L10')
# 236: ('W2Al2', 'hollow', 'Al_W_W|FCC', 'L10')
# 237: ('W3Ga', 'hollow', 'W_W_W|FCC', 'L12')
# 238: ('W2Ga2', 'hollow', 'Ga_Ga_W|FCC', 'L10')
# 239: ('W2Al2', 'hollow', 'Al_W_W|HCP', 'L10')
# 240: ('W3Ga', 'hollow', 'W_W_W|HCP', 'L12')
# 241: ('W2Ga2', 'hollow', 'Ga_Ga_W|HCP', 'L10')
# 242: ('W3In', 'hollow', 'W_W_W|FCC', 'L12')
# 243: ('W3In', 'hollow', 'W_W_W|HCP', 'L12')
# 244: ('W3Tl', 'top', 'Tl', 'L12')
# 245: ('W3Pb', 'hollow', 'W_W_W|HCP', 'L12')
# 247: ('Re3Nb', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 249: ('Re3Os', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 250: ('Re2Os2', 'hollow', 'Os_Os_Re|HCP', 'L10')
# 251: ('Re2Os2', 'hollow', 'Os_Re_Re|HCP', 'L10')
# 252: ('Re3Os', 'hollow', 'Re_Re_Os|HCP', 'L12')
# 254: ('Re3Ir', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 255: ('Re3Ir', 'hollow', 'Re_Re_Ir|HCP', 'L12')
# 257: ('Re3Ir', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 258: ('Re3Ir', 'top', 'Re', 'L12')
# 260: ('Re3Ir', 'top', 'Ir', 'L12')
# 262: ('Re3Fe', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 265: ('Re3Pt', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 267: ('Re3Pt', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 268: ('Re3Pt', 'hollow', 'Re_Re_Pt|HCP', 'L12')
# 273: ('Re3Al', 'hollow', 'Re_Re_Al|HCP', 'L12')
# 274: ('Re3Al', 'top', 'Al', 'L12')
# 275: ('Re2Al2', 'hollow', 'Al_Al_Re|FCC', 'L10')
# 277: ('Re3Al', 'top', 'Re', 'L12')
# 278: ('Re2Al2', 'hollow', 'Al_Al_Re|HCP', 'L10')
# 279: ('Re2Al2', 'hollow', 'Al_Re_Re|FCC', 'L10')
# 280: ('Re2Al2', 'hollow', 'Al_Re_Re|HCP', 'L10')
# 282: ('Re3Ga', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 283: ('Re3In', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 284: ('Tc3Zr', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 285: ('Tc3V', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 286: ('Tc3W', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 287: ('Tc3W', 'hollow', 'Tc_Tc_W|HCP', 'L12')
# 288: ('Tc3Os', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 289: ('Re3In', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 290: ('Tc3V', 'hollow', 'Tc_Tc_V|HCP', 'L12')
# 291: ('Tc3Os', 'hollow', 'Tc_Tc_Os|FCC', 'L12')
# 292: ('Tc3Zr', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 293: ('Tc3Os', 'hollow', 'Tc_Tc_Os|HCP', 'L12')
# 295: ('Tc3Y', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 296: ('Tc3Ru', 'top', 'Tc', 'L12')
# 299: ('Tc3Re', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 300: ('Ru2Ag2', 'hollow', 'Ag_Ru_Ru|FCC', 'L10')
# 301: ('Tc3Ru', 'top', 'Ru', 'L12')
# 302: ('Tc3Re', 'hollow', 'Tc_Tc_Re|HCP', 'L12')
# 303: ('Tc3Cr', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 305: ('Re3Sn', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 306: ('Re3Sn', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 307: ('Tc3La', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 308: ('Tc3Hf', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 309: ('Tc3Cr', 'hollow', 'Tc_Tc_Cr|HCP', 'L12')
# 310: ('Tc3La', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 311: ('Tc3Hf', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 312: ('Tc2Os2', 'hollow', 'Os_Tc_Tc|HCP', 'L10')
# 313: ('Tc3Rh', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 314: ('Tc3Rh', 'top', 'Rh', 'L12')
# 317: ('Tc3Cd', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 318: ('Tc3Ga', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 319: ('Tc3Tl', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 320: ('Os3Sc', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 321: ('Tc3Rh', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 323: ('Tc3Cd', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 324: ('Tc3Rh', 'hollow', 'Tc_Tc_Rh|HCP', 'L12')
# 326: ('Tc3Rh', 'top', 'Tc', 'L12')
# 328: ('Ru3Ga', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 329: ('Ru3Ga', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 330: ('Ru3Pb', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 331: ('Ru3Pb', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 332: ('Os3La', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 334: ('Ru3Sn', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 335: ('Ru3Sn', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 336: ('Os3La', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 339: ('Tc3Cu', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 341: ('Tc3Cu', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 342: ('Tc3Pb', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 345: ('Tc3Pb', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 347: ('Tc3Fe', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 353: ('Os3Hf', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 354: ('Tc3Pt', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 356: ('Tc3Pt', 'hollow', 'Tc_Tc_Pt|HCP', 'L12')
# 357: ('Tc3Al', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 358: ('Os3Cr', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 359: ('Tc3Al', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 360: ('Os3Cr', 'hollow', 'Os_Os_Cr|HCP', 'L12')
# 361: ('Os3Re', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 362: ('Os3Re', 'hollow', 'Os_Os_Re|HCP', 'L12')
# 363: ('Os3Tc', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 364: ('Os3Tc', 'hollow', 'Os_Os_Tc|HCP', 'L12')
# 366: ('Os3Ti', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 369: ('Os3Ti', 'hollow', 'Os_Os_Ti|HCP', 'L12')
# 370: ('Tc2Cu2', 'hollow', 'Cu_Cu_Tc|FCC', 'L10')
# 371: ('Tc2Cu2', 'hollow', 'Cu_Cu_Tc|HCP', 'L10')
# 372: ('Ru3Al', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 373: ('Tc2Cu2', 'hollow', 'Cu_Tc_Tc|FCC', 'L10')
# 374: ('Tc2Cu2', 'hollow', 'Cu_Tc_Tc|HCP', 'L10')
# 375: ('Ru3Al', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 376: ('Os3Ta', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 381: ('Ru3In', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 384: ('Ru3In', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 386: ('Tc3Zn', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 388: ('Os3Co', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 390: ('Os3Co', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 391: ('Os3Ru', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 392: ('Os3Ru', 'hollow', 'Os_Os_Ru|HCP', 'L12')
# 395: ('Os3Rh', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 398: ('Os3Rh', 'hollow', 'Os_Os_Rh|HCP', 'L12')
# 403: ('Os3Ag', 'top', 'Ag', 'L12')
# 404: ('Ir3Pt', 'top', 'Ir', 'L12')
# 405: ('Ir3Pt', 'top', 'Pt', 'L12')
# 406: ('Os2Ag2', 'hollow', 'Ag_Ag_Os|FCC', 'L10')
# 409: ('Ir3Hf', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 410: ('Ir2Pt2', 'hollow', 'Ir_Ir_Pt|HCP', 'L10')
# 412: ('Ir3Fe', 'hollow', 'Ir_Ir_Fe|FCC', 'L12')
# 413: ('Os3Cu', 'top', 'Os', 'L12')
# 415: ('Ru3Tl', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 417: ('Os3Cu', 'top', 'Cu', 'L12')
# 422: ('Ir3Cr', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 423: ('Ir3Cr', 'hollow', 'Ir_Ir_Cr|HCP', 'L12')
# 425: ('Ru3Mo', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 426: ('Ru3Tc', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 427: ('Ru3Mo', 'hollow', 'Ru_Ru_Mo|HCP', 'L12')
# 428: ('Ru3Tc', 'hollow', 'Ru_Ru_Tc|HCP', 'L12')
# 430: ('Ru3Cr', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 432: ('Os3Tl', 'top', 'Tl', 'L12')
# 440: ('Ir3Pd', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 441: ('Ir3Pd', 'hollow', 'Ir_Ir_Pd|HCP', 'L12')
# 442: ('Os3Pd', 'top', 'Os', 'L12')
# 443: ('Os3Pd', 'top', 'Pd', 'L12')
# 445: ('Ir3Pd', 'top', 'Ir', 'L12')
# 446: ('Ir3Pd', 'top', 'Pd', 'L12')
# 447: ('Os3Al', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 449: ('Ir3Cu', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 450: ('Os3Al', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 451: ('Ir3Cu', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 452: ('Os3Al', 'top', 'Os', 'L12')
# 453: ('Os3Al', 'top', 'Al', 'L12')
# 454: ('Ir3Cd', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 457: ('Ir3Cd', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 459: ('Os2Sn2', 'top', 'Sn', 'L10')
# 461: ('Os3Sn', 'top', 'Os', 'L12')
# 462: ('Ir3Al', 'top', 'Al', 'L12')
# 463: ('Ir3Ru', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 464: ('Ir3Ru', 'hollow', 'Ir_Ir_Ru|HCP', 'L12')
# 465: ('Ru3Os', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 466: ('Ru3Os', 'hollow', 'Ru_Ru_Os|FCC', 'L12')
# 468: ('Ru3Os', 'hollow', 'Ru_Ru_Os|HCP', 'L12')
# 470: ('Ru3Co', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 471: ('Ru3Co', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 472: ('Ru3La', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 474: ('Rh3Sc', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 475: ('Rh3Sc', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 476: ('Rh3Zr', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 478: ('Rh3Hf', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 481: ('Rh3Ti', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 482: ('Rh3Ta', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 483: ('Rh3Cr', 'hollow', 'Rh_Rh_Cr|HCP', 'L12')
# 484: ('Rh3Mo', 'hollow', 'Rh_Rh_Mo|HCP', 'L12')
# 485: ('Rh3Ta', 'hollow', 'Rh_Rh_Ta|HCP', 'L12')
# 489: ('Rh3Tc', 'hollow', 'Rh_Rh_Tc|FCC', 'L12')
# 490: ('Rh3Tc', 'hollow', 'Rh_Rh_Tc|HCP', 'L12')
# 491: ('Rh3Ru', 'top', 'Rh', 'L12')
# 493: ('Ru3Sc', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 495: ('Ir3Ga', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 497: ('Ir3Ga', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 499: ('Ru3Sc', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 500: ('Rh3Ir', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 508: ('Ru2Fe2', 'hollow', 'Fe_Fe_Ru|FCC', 'L10')
# 510: ('Ru3Zr', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 511: ('Rh3Fe', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 513: ('Rh2Pd2', 'hollow', 'Pd_Rh_Rh|FCC', 'L10')
# 516: ('Ru3Hf', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 517: ('Rh3Sn', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 519: ('Rh3Sn', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 529: ('Ru3Ti', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 531: ('Ru3Ti', 'hollow', 'Ru_Ru_Ti|HCP', 'L12')
# 541: ('Rh3Al', 'top', 'Al', 'L12')
# 558: ('Ru3Ta', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 560: ('Rh3Zn', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 568: ('Co3Cd', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 570: ('Co3Cd', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 576: ('Rh3Ga', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 577: ('Rh3Ga', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 578: ('Co3In', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 579: ('Co3In', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 582: ('Pt2Ag2', 'hollow', 'Ag_Pt_Pt|FCC', 'L10')
# 583: ('Ru2Ag2', 'top', 'Ru', 'L10')
# 584: ('Zr2Ag2', 'hollow', 'Ag_Zr_Zr|FCC', 'L10')
# 585: ('Zr2Ag2', 'hollow', 'Ag_Zr_Zr|HCP', 'L10')
# 586: ('Cu2Al2', 'hollow', 'Al_Al_Cu|FCC', 'L10')
# 587: ('Ag3Co', 'top', 'Ag', 'L12')
# 588: ('Ag3Co', 'top', 'Co', 'L12')
# 589: ('Ag3Nb', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 590: ('Ir3Ag', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 591: ('Ir3Ag', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 592: ('Rh3In', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 593: ('Rh3Tl', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 596: ('Rh3Pb', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 597: ('Rh3Pb', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 598: ('Pd2Ag2', 'top', 'Ag', 'L10')
# 599: ('Au3Pb', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 600: ('Au3Pb', 'hollow', 'Au_Au_Pb|FCC', 'L12')
# 602: ('Co2Au2', 'top', 'Co', 'L10')
# 603: ('Ir2Au2', 'hollow', 'Au_Au_Ir|FCC', 'L10')
# 604: ('Nb2Au2', 'hollow', 'Au_Nb_Nb|HCP', 'L10')
# 605: ('Pd2Au2', 'hollow', 'Au_Au_Pd|HCP', 'L10')
# 607: ('Pt2Au2', 'hollow', 'Au_Au_Pt|FCC', 'L10')
# 608: ('Pt2Au2', 'hollow', 'Au_Au_Pt|HCP', 'L10')
# 609: ('Pt2Au2', 'hollow', 'Au_Pt_Pt|FCC', 'L10')
# 610: ('Pt2Au2', 'hollow', 'Au_Pt_Pt|HCP', 'L10')
# 613: ('Au3Ir', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 614: ('Au2Zn2', 'hollow', 'Au_Au_Zn|FCC', 'L10')
# 615: ('Au2Tl2', 'hollow', 'Au_Au_Tl|FCC', 'L10')
# 617: ('Co2Pd2', 'top', 'Pd', 'L10')
# 619: ('Co2Pt2', 'hollow', 'Co_Co_Pt|HCP', 'L10')
# 620: ('Cd3Ga', 'hollow', 'Cd_Cd_Ga|HCP', 'L12')
# 621: ('Co2Pt2', 'top', 'Pt', 'L10')
# 622: ('Cd3Pb', 'hollow', 'Cd_Cd_Cd|HCP', 'L12')
# 624: ('Cd3Sn', 'hollow', 'Cd_Cd_Sn|FCC', 'L12')
# 625: ('Co2Sn2', 'hollow', 'Co_Sn_Sn|FCC', 'L10')
# 626: ('Cr3Cd', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 627: ('Cr3Rh', 'hollow', 'Cr_Cr_Rh|FCC', 'L12')
# 628: ('Cr3Ru', 'hollow', 'Cr_Cr_Ru|FCC', 'L12')
# 631: ('Cu3Ga', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 632: ('Cu3Ga', 'hollow', 'Cu_Cu_Ga|FCC', 'L12')
# 633: ('Cu3Pt', 'top', 'Pt', 'L12')
# 634: ('Cu3Sn', 'hollow', 'Cu_Cu_Sn|FCC', 'L12')
# 635: ('Cu3Sn', 'hollow', 'Cu_Cu_Sn|HCP', 'L12')
# 636: ('Cu2Sn2', 'hollow', 'Cu_Sn_Sn|FCC', 'L10')
# 638: ('Cd2Pb2', 'hollow', 'Cd_Pb_Pb|HCP', 'L10')
# 639: ('Cu3Al', 'hollow', 'Cu_Cu_Al|HCP', 'L12')
# 641: ('Pt2Cu2', 'top', 'Pt', 'L10')
# 642: ('Fe3Al', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 645: ('Fe3Cd', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 649: ('Fe3Sn', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 651: ('Fe3Tl', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 652: ('Fe3Zn', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 654: ('Ru2Fe2', 'hollow', 'Fe_Ru_Ru|FCC', 'L10')
# 656: ('W2Fe2', 'hollow', 'Fe_W_W|FCC', 'L10')
# 657: ('Ga3Ta', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 658: ('Ga3Tc', 'hollow', 'Ga_Ga_Tc|FCC', 'L12')
# 660: ('Fe3Cu', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 661: ('Fe3Ga', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 664: ('Ga3Tc', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 665: ('Ga3Ti', 'hollow', 'Ga_Ga_Ga|HCP', 'L12')
# 666: ('Co3Ag', 'top', 'Ag', 'L12')
# 667: ('Fe3Pb', 'hollow', 'Fe_Fe_Fe|FCC', 'L12')
# 668: ('Ga3Tl', 'hollow', 'Ga_Ga_Ga|FCC', 'L12')
# 669: ('Cd2Ga2', 'hollow', 'Cd_Cd_Ga|HCP', 'L10')
# 670: ('Cu2Ga2', 'hollow', 'Cu_Cu_Ga|HCP', 'L10')
# 671: ('Hf3Ir', 'hollow', 'Hf_Hf_Ir|HCP', 'L12')
# 672: ('Hf3Pd', 'hollow', 'Hf_Hf_Pd|FCC', 'L12')
# 673: ('Hf3Pd', 'hollow', 'Hf_Hf_Pd|HCP', 'L12')
# 677: ('In3Tc', 'hollow', 'In_In_Tc|HCP', 'L12')
# 678: ('Co3Au', 'top', 'Co', 'L12')
# 683: ('In3Ti', 'hollow', 'In_In_Ti|HCP', 'L12')
# 692: ('Co3Au', 'top', 'Au', 'L12')
# 693: ('La2Sn2', 'hollow', 'La_La_Sn|FCC', 'L10')
# 695: ('Nb3Pt', 'hollow', 'Nb_Nb_Pt|FCC', 'L12')
# 696: ('Sc2Nb2', 'hollow', 'Nb_Nb_Sc|HCP', 'L10')
# 697: ('Nb2Sn2', 'hollow', 'Nb_Nb_Sn|HCP', 'L10')
# 700: ('Tc2Os2', 'hollow', 'Os_Os_Tc|FCC', 'L10')
# 701: ('Os2Zn2', 'hollow', 'Os_Zn_Zn|FCC', 'L10')
# 702: ('Pb3Tl', 'hollow', 'Pb_Pb_Tl|FCC', 'L12')
# 705: ('Pd3Al', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 707: ('Pd3Al', 'hollow', 'Pd_Pd_Al|FCC', 'L12')
# 708: ('Pd3Cd', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 709: ('Pd3Ga', 'hollow', 'Pd_Pd_Ga|FCC', 'L12')
# 712: ('Pd3In', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 713: ('Pd3Pb', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 714: ('Pd3Rh', 'top', 'Rh', 'L12')
# 715: ('Pd3Sn', 'hollow', 'Pd_Pd_Sn|FCC', 'L12')
# 716: ('Pd3Tl', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 719: ('Pt2Pd2', 'top', 'Pt', 'L10')
# 722: ('Pt3Al', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 724: ('Pd3Sn', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 726: ('Pt3Al', 'hollow', 'Pt_Pt_Al|FCC', 'L12')
# 727: ('Pt3Al', 'top', 'Al', 'L12')
# 729: ('Pt3Cu', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 730: ('Pt3Ga', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 731: ('Pt3Ga', 'hollow', 'Pt_Pt_Ga|FCC', 'L12')
# 733: ('Pt3Re', 'top', 'Pt', 'L12')
# 734: ('Pt3Sn', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 735: ('Pt3Sn', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 736: ('Pt3Zn', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 738: ('Rh2Pt2', 'hollow', 'Pt_Pt_Rh|FCC', 'L10')
# 739: ('Rh2Pt2', 'hollow', 'Pt_Rh_Rh|FCC', 'L10')
# 742: ('Re2Zn2', 'hollow', 'Re_Zn_Zn|FCC', 'L10')
# 745: ('Ta3Sc', 'hollow', 'Ta_Ta_Sc|FCC', 'L12')
# 746: ('Ta3Sc', 'hollow', 'Ta_Ta_Sc|HCP', 'L12')
# 747: ('Ti3Cu', 'hollow', 'Ti_Ti_Cu|HCP', 'L12')
# 748: ('W2Fe2', 'hollow', 'Fe_Fe_W|FCC', 'L10')
# 750: ('Y3Tl', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 752: ('Zn3Cr', 'hollow', 'Zn_Zn_Cr|FCC', 'L12')
# 755: ('Zr3Ga', 'hollow', 'Zr_Zr_Ga|FCC', 'L12')
# 757: ('Ti3V', 'hollow', 'Ti_Ti_V|HCP', 'L12')
# 760: ('Tl3Sn', 'hollow', 'Tl_Tl_Sn|FCC', 'L12')
# 762: ('Co3Cu', 'top', 'Cu', 'L12')
# 763: ('Co3Pd', 'top', 'Pd', 'L12')
# 764: ('Co3Rh', 'top', 'Rh', 'L12')
# 765: ('Co3Sn', 'top', 'Sn', 'L12')
# 766: ('Cd2Tl2', 'hollow', 'Cd_Tl_Tl|FCC', 'L10')
# 768: ('Nb2Fe2', 'hollow', 'Fe_Nb_Nb|FCC', 'L10')
# 769: ('Cr2Co2', 'hollow', 'Co_Co_Cr|FCC', 'L10')
# 770: ('Cr2Co2', 'hollow', 'Co_Cr_Cr|FCC', 'L10')
# 771: ('Cr2Co2', 'hollow', 'Co_Cr_Cr|HCP', 'L10')
# 779: ('Mo3Co', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 780: ('Nb3Co', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 787: ('Sn3Co', 'hollow', 'Sn_Sn_Co|FCC', 'L12')
# 788: ('Tc3Co', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 789: ('Tc3Co', 'hollow', 'Tc_Tc_Co|HCP', 'L12')
# 790: ('Ti3Co', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 794: ('Ti3Co', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 796: ('V3Co', 'hollow', 'V_V_V|HCP', 'L12')
# 797: ('Al3Co', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 800: ('W3Co', 'hollow', 'W_W_W|FCC', 'L12')
# 801: ('Zr3Co', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 802: ('Ti2Fe2', 'hollow', 'Fe_Ti_Ti|FCC', 'L10')
# 803: ('Al3Co', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 805: ('Zr3Co', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 807: ('Al3Co', 'top', 'Co', 'L12')
# 808: ('V2Fe2', 'hollow', 'Fe_V_V|FCC', 'L10')
# 809: ('Au3Co', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 810: ('Hf3Co', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 811: ('Au3Co', 'hollow', 'Au_Au_Co|FCC', 'L12')
# 812: ('In3Co', 'hollow', 'In_In_In|HCP', 'L12')
# 813: ('Au3Co', 'hollow', 'Au_Au_Co|HCP', 'L12')
# 816: ('Ir3Co', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 817: ('Cd3Co', 'hollow', 'Cd_Cd_Cd|FCC', 'L12')
# 818: ('Ir3Co', 'hollow', 'Ir_Ir_Co|FCC', 'L12')
# 819: ('Cd3Co', 'hollow', 'Cd_Cd_Cd|HCP', 'L12')
# 820: ('Ir3Co', 'top', 'Ir', 'L12')
# 821: ('Mo2Co2', 'hollow', 'Co_Mo_Mo|FCC', 'L10')
# 822: ('Ir3Co', 'top', 'Co', 'L12')
# 823: ('Mo2Co2', 'hollow', 'Co_Mo_Mo|HCP', 'L10')
# 824: ('Cu3Co', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 825: ('Cu3Co', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 826: ('Cu3Co', 'hollow', 'Cu_Cu_Co|FCC', 'L12')
# 827: ('Cu3Co', 'hollow', 'Cu_Cu_Co|HCP', 'L12')
# 828: ('Cu3Co', 'top', 'Co', 'L12')
# 829: ('Ag3Y', 'top', 'Y', 'L12')
# 830: ('La2Zr2', 'hollow', 'La_La_Zr|FCC', 'L10')
# 831: ('La2Zr2', 'hollow', 'La_La_Zr|HCP', 'L10')
# 832: ('Tc3Ir', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 833: ('Tc3Ir', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 834: ('Tc3Ir', 'hollow', 'Tc_Tc_Ir|FCC', 'L12')
# 835: ('Re2Au2', 'hollow', 'Au_Au_Re|FCC', 'L10')
# 836: ('La2Zr2', 'hollow', 'La_Zr_Zr|FCC', 'L10')
# 837: ('Tc3Ir', 'hollow', 'Tc_Tc_Ir|HCP', 'L12')
# 838: ('La2Zr2', 'hollow', 'La_Zr_Zr|HCP', 'L10')
# 840: ('Sc2Ti2', 'hollow', 'Sc_Sc_Ti|FCC', 'L10')
# 841: ('Sc2Ti2', 'hollow', 'Sc_Sc_Ti|HCP', 'L10')
# 842: ('Au2In2', 'hollow', 'Au_Au_In|HCP', 'L10')
# 843: ('Sc2Ti2', 'hollow', 'Sc_Ti_Ti|HCP', 'L10')
# 844: ('Au2In2', 'hollow', 'Au_In_In|FCC', 'L10')
# 845: ('W3V', 'top', 'V', 'L12')
# 846: ('Re2Cu2', 'hollow', 'Cu_Cu_Re|FCC', 'L10')
# 847: ('Re2Cu2', 'hollow', 'Cu_Cu_Re|HCP', 'L10')
# 848: ('Re2Cu2', 'hollow', 'Cu_Re_Re|FCC', 'L10')
# 849: ('Rh2Cu2', 'hollow', 'Cu_Cu_Rh|FCC', 'L10')
# 865: ('Re2Cu2', 'hollow', 'Cu_Re_Re|HCP', 'L10')
# 866: ('Rh2Cu2', 'hollow', 'Cu_Cu_Rh|HCP', 'L10')
# 867: ('In3Pd', 'hollow', 'In_In_In|FCC', 'L12')
# 872: ('In3Pd', 'hollow', 'In_In_In|HCP', 'L12')
# 873: ('In3Pd', 'hollow', 'In_In_Pd|FCC', 'L12')
# 874: ('Re2Cu2', 'top', 'Re', 'L10')
# 875: ('Rh2Cu2', 'hollow', 'Cu_Rh_Rh|FCC', 'L10')
# 876: ('Rh2Cu2', 'hollow', 'Cu_Rh_Rh|HCP', 'L10')
# 877: ('Al2Sn2', 'hollow', 'Al_Al_Sn|HCP', 'L10')
# 878: ('V2Pd2', 'hollow', 'Pd_Pd_V|FCC', 'L10')
# 879: ('Al2Sn2', 'hollow', 'Al_Sn_Sn|FCC', 'L10')
# 880: ('W2Tc2', 'hollow', 'Tc_Tc_W|HCP', 'L10')
# 881: ('Rh2Au2', 'hollow', 'Au_Au_Rh|FCC', 'L10')
# 882: ('Sc2Mo2', 'hollow', 'Mo_Mo_Sc|FCC', 'L10')
# 886: ('Al3Cu', 'top', 'Cu', 'L12')
# 887: ('W2Tc2', 'hollow', 'Tc_W_W|HCP', 'L10')
# 888: ('Rh2Au2', 'hollow', 'Au_Au_Rh|HCP', 'L10')
# 889: ('Sc2Mo2', 'hollow', 'Mo_Mo_Sc|HCP', 'L10')
# 891: ('W2Tc2', 'top', 'Tc', 'L10')
# 892: ('Rh2Au2', 'hollow', 'Au_Rh_Rh|FCC', 'L10')
# 893: ('Sc2Mo2', 'hollow', 'Mo_Sc_Sc|FCC', 'L10')
# 894: ('W2Tc2', 'top', 'W', 'L10')
# 895: ('Rh2Au2', 'hollow', 'Au_Rh_Rh|HCP', 'L10')
# 896: ('Sc2Mo2', 'hollow', 'Mo_Sc_Sc|HCP', 'L10')
# 899: ('Nb2Cr2', 'hollow', 'Cr_Nb_Nb|FCC', 'L10')
# 900: ('Nb2Cr2', 'top', 'Cr', 'L10')
# 902: ('Nb2Cr2', 'top', 'Nb', 'L10')
# 903: ('Pb2Sn2', 'hollow', 'Pb_Pb_Sn|FCC', 'L10')
# 904: ('Cr3Ag', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 905: ('Sc2Co2', 'top', 'Co', 'L10')
# 906: ('Pb2Sn2', 'hollow', 'Pb_Pb_Sn|HCP', 'L10')
# 907: ('V2Pd2', 'hollow', 'Pd_Pd_V|HCP', 'L10')
# 908: ('Pb2Sn2', 'hollow', 'Pb_Sn_Sn|FCC', 'L10')
# 909: ('V2Pd2', 'hollow', 'Pd_V_V|FCC', 'L10')
# 912: ('Pb2Sn2', 'hollow', 'Pb_Sn_Sn|HCP', 'L10')
# 913: ('V2Pd2', 'hollow', 'Pd_V_V|HCP', 'L10')
# 917: ('Zr2Re2', 'hollow', 'Re_Zr_Zr|FCC', 'L10')
# 918: ('Re2Co2', 'hollow', 'Co_Co_Re|FCC', 'L10')
# 919: ('Pd3Tl', 'top', 'Tl', 'L12')
# 920: ('Re2Co2', 'hollow', 'Co_Co_Re|HCP', 'L10')
# 922: ('Re3Ta', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 923: ('Re2Co2', 'hollow', 'Co_Re_Re|HCP', 'L10')
# 924: ('Ag3Zr', 'top', 'Zr', 'L12')
# 925: ('Tc2Sn2', 'top', 'Tc', 'L10')
# 926: ('Hf2Tc2', 'hollow', 'Hf_Hf_Tc|FCC', 'L10')
# 927: ('Re3Ta', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 928: ('Re3Ta', 'hollow', 'Re_Re_Ta|FCC', 'L12')
# 929: ('La2Ta2', 'hollow', 'La_La_Ta|FCC', 'L10')
# 930: ('Re3Ta', 'hollow', 'Re_Re_Ta|HCP', 'L12')
# 931: ('La2Ta2', 'hollow', 'La_Ta_Ta|HCP', 'L10')
# 938: ('Pd2Zn2', 'hollow', 'Pd_Pd_Zn|FCC', 'L10')
# 939: ('W2Zn2', 'hollow', 'W_W_Zn|FCC', 'L10')
# 943: ('W2Zn2', 'hollow', 'W_Zn_Zn|FCC', 'L10')
# 958: ('Re3Zn', 'top', 'Zn', 'L12')
# 964: ('Zr3Zn', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 965: ('Cr3Re', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 966: ('W3Rh', 'hollow', 'W_W_W|FCC', 'L12')
# 967: ('W3Rh', 'hollow', 'W_W_Rh|FCC', 'L12')
# 968: ('Os3Mo', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 969: ('Os3Mo', 'hollow', 'Os_Os_Mo|HCP', 'L12')
# 974: ('Cr3Re', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 975: ('W3Rh', 'hollow', 'W_W_Rh|HCP', 'L12')
# 976: ('Os3Mo', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 977: ('Zr3Zn', 'hollow', 'Zr_Zr_Zn|FCC', 'L12')
# 978: ('Cr3Re', 'hollow', 'Cr_Cr_Re|FCC', 'L12')
# 979: ('Mo3Tl', 'top', 'Mo', 'L12')
# 982: ('Mo3Tl', 'top', 'Tl', 'L12')
# 987: ('Co2Au2', 'hollow', 'Au_Au_Co|FCC', 'L10')
# 989: ('Ta2Os2', 'hollow', 'Os_Os_Ta|HCP', 'L10')
# 990: ('Ta2Os2', 'hollow', 'Os_Ta_Ta|FCC', 'L10')
# 992: ('Ag2Al2', 'hollow', 'Ag_Ag_Al|FCC', 'L10')
# 993: ('Ru2Ir2', 'hollow', 'Ir_Ir_Ru|FCC', 'L10')
# 994: ('Sc3Ru', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 995: ('Ag2Al2', 'hollow', 'Ag_Al_Al|HCP', 'L10')
# 997: ('Ru2Ir2', 'hollow', 'Ir_Ir_Ru|HCP', 'L10')
# 998: ('Zr2Cu2', 'hollow', 'Cu_Zr_Zr|FCC', 'L10')
# 999: ('Sc3Ru', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 1000: ('Ru2Ir2', 'hollow', 'Ir_Ru_Ru|FCC', 'L10')
# 1001: ('Zr2Cu2', 'top', 'Cu', 'L10')
# 1002: ('Sc3Ru', 'hollow', 'Sc_Sc_Ru|FCC', 'L12')
# 1003: ('Ru2Ir2', 'hollow', 'Ir_Ru_Ru|HCP', 'L10')
# 1004: ('Zr2Cu2', 'top', 'Zr', 'L10')
# 1005: ('Sc3Ru', 'hollow', 'Sc_Sc_Ru|HCP', 'L12')
# 1006: ('Co2Zn2', 'hollow', 'Co_Zn_Zn|FCC', 'L10')
# 1007: ('Os3Cd', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 1010: ('Os3Cd', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 1012: ('Nb2In2', 'hollow', 'In_In_Nb|FCC', 'L10')
# 1013: ('Ta2Re2', 'hollow', 'Re_Ta_Ta|HCP', 'L10')
# 1015: ('Rh3Hf', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 1016: ('Nb2In2', 'hollow', 'In_In_Nb|HCP', 'L10')
# 1019: ('Hf3Ta', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 1020: ('Nb2In2', 'hollow', 'In_Nb_Nb|FCC', 'L10')
# 1021: ('Hf3Ta', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 1022: ('Nb2In2', 'hollow', 'In_Nb_Nb|HCP', 'L10')
# 1024: ('Hf3Ta', 'hollow', 'Hf_Hf_Ta|FCC', 'L12')
# 1026: ('Hf3Ta', 'hollow', 'Hf_Hf_Ta|HCP', 'L12')
# 1027: ('Mo2Os2', 'hollow', 'Mo_Mo_Os|FCC', 'L10')
# 1030: ('Mo2Os2', 'hollow', 'Mo_Mo_Os|HCP', 'L10')
# 1032: ('Ti2Re2', 'hollow', 'Re_Ti_Ti|HCP', 'L10')
# 1033: ('Pd3Al', 'top', 'Al', 'L12')
# 1034: ('Mo2Os2', 'hollow', 'Mo_Os_Os|FCC', 'L10')
# 1036: ('Mo2Os2', 'hollow', 'Mo_Os_Os|HCP', 'L10')
# 1039: ('Ir2Pt2', 'hollow', 'Ir_Ir_Pt|FCC', 'L10')
# 1040: ('Ir2Pt2', 'hollow', 'Ir_Pt_Pt|FCC', 'L10')
# 1041: ('W2In2', 'hollow', 'In_In_W|FCC', 'L10')
# 1042: ('In3Tl', 'hollow', 'In_In_In|FCC', 'L12')
# 1043: ('Hf2Al2', 'hollow', 'Al_Hf_Hf|FCC', 'L10')
# 1044: ('Ir2Pt2', 'hollow', 'Ir_Pt_Pt|HCP', 'L10')
# 1045: ('Ir2Co2', 'hollow', 'Co_Co_Ir|FCC', 'L10')
# 1046: ('Ir2Co2', 'top', 'Ir', 'L10')
# 1047: ('In3Tl', 'hollow', 'In_In_In|HCP', 'L12')
# 1048: ('Tc2Au2', 'hollow', 'Au_Tc_Tc|HCP', 'L10')
# 1049: ('Hf2Al2', 'hollow', 'Al_Hf_Hf|HCP', 'L10')
# 1052: ('Ag2Pb2', 'hollow', 'Ag_Pb_Pb|FCC', 'L10')
# 1053: ('Ir2Co2', 'hollow', 'Co_Co_Ir|HCP', 'L10')
# 1054: ('Ir2Pt2', 'top', 'Ir', 'L10')
# 1055: ('Ir2Co2', 'hollow', 'Co_Ir_Ir|FCC', 'L10')
# 1056: ('Al3Ti', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1057: ('Ir2Pt2', 'top', 'Pt', 'L10')
# 1058: ('Ir2Fe2', 'hollow', 'Fe_Fe_Ir|FCC', 'L10')
# 1059: ('Ir2Co2', 'hollow', 'Co_Ir_Ir|HCP', 'L10')
# 1060: ('Al3Ti', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1063: ('Al3Ti', 'hollow', 'Al_Al_Ti|FCC', 'L12')
# 1064: ('Ir2Fe2', 'hollow', 'Fe_Ir_Ir|FCC', 'L10')
# 1065: ('Zr2Tc2', 'hollow', 'Tc_Zr_Zr|FCC', 'L10')
# 1066: ('Al3Ti', 'hollow', 'Al_Al_Ti|HCP', 'L12')
# 1068: ('Au2Tl2', 'hollow', 'Au_Au_Tl|HCP', 'L10')
# 1072: ('Pd3Au', 'top', 'Au', 'L12')
# 1074: ('In3Nb', 'hollow', 'In_In_In|FCC', 'L12')
# 1075: ('Y3Pd', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 1076: ('Mo3Ag', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 1077: ('In3Nb', 'hollow', 'In_In_In|HCP', 'L12')
# 1078: ('Y3Pd', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1079: ('Mo3Ag', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 1080: ('In3Nb', 'hollow', 'In_In_Nb|FCC', 'L12')
# 1081: ('In3Nb', 'hollow', 'In_In_Nb|HCP', 'L12')
# 1082: ('Au3Ta', 'hollow', 'Au_Au_Ta|FCC', 'L12')
# 1083: ('Rh3Ir', 'hollow', 'Rh_Rh_Ir|HCP', 'L12')
# 1084: ('Rh3Cd', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 1085: ('La3In', 'hollow', 'La_La_La|HCP', 'L12')
# 1086: ('Os3In', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 1087: ('Rh3Cd', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 1088: ('La3In', 'hollow', 'La_La_In|FCC', 'L12')
# 1089: ('Cr2Zn2', 'hollow', 'Cr_Zn_Zn|FCC', 'L10')
# 1090: ('La3In', 'hollow', 'La_La_In|HCP', 'L12')
# 1092: ('Os3In', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 1093: ('V2W2', 'hollow', 'V_V_W|FCC', 'L10')
# 1094: ('V2W2', 'hollow', 'V_V_W|HCP', 'L10')
# 1095: ('Tl3Pt', 'hollow', 'Tl_Tl_Tl|FCC', 'L12')
# 1096: ('Ag3Al', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 1097: ('Ir3Hf', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 1098: ('Tl3Al', 'hollow', 'Tl_Tl_Tl|FCC', 'L12')
# 1099: ('W3Au', 'hollow', 'W_W_W|FCC', 'L12')
# 1100: ('Tl3Pt', 'hollow', 'Tl_Tl_Tl|HCP', 'L12')
# 1101: ('Ag3Al', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 1102: ('Tl3Al', 'hollow', 'Tl_Tl_Tl|HCP', 'L12')
# 1103: ('W3Au', 'hollow', 'W_W_W|HCP', 'L12')
# 1104: ('Tl3Pt', 'hollow', 'Tl_Tl_Pt|FCC', 'L12')
# 1105: ('Ag3Al', 'hollow', 'Ag_Ag_Al|FCC', 'L12')
# 1107: ('V2W2', 'hollow', 'V_W_W|FCC', 'L10')
# 1108: ('W3Au', 'hollow', 'W_W_Au|FCC', 'L12')
# 1109: ('Tl3Pt', 'hollow', 'Tl_Tl_Pt|HCP', 'L12')
# 1110: ('Ag3Al', 'hollow', 'Ag_Ag_Al|HCP', 'L12')
# 1111: ('V2W2', 'hollow', 'V_W_W|HCP', 'L10')
# 1112: ('Al3Rh', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1114: ('Tc3Ru', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 1115: ('Y3Rh', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1116: ('Y3Tc', 'hollow', 'Y_Y_Tc|HCP', 'L12')
# 1117: ('Al3Zn', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1118: ('Tc3Ru', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 1119: ('Y3Tc', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 1121: ('Tc3Ru', 'hollow', 'Tc_Tc_Ru|FCC', 'L12')
# 1122: ('Y3Tc', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1123: ('Tc3Ru', 'hollow', 'Tc_Tc_Ru|HCP', 'L12')
# 1124: ('Zn3Zr', 'hollow', 'Zn_Zn_Zn|FCC', 'L12')
# 1126: ('Hf3Os', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 1127: ('Pt3Ru', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 1128: ('Co3Pd', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 1129: ('La3Ga', 'hollow', 'La_La_La|FCC', 'L12')
# 1130: ('Pt3Ru', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 1131: ('Co3Pd', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 1133: ('Ag3La', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 1134: ('Pt3Ru', 'hollow', 'Pt_Pt_Ru|FCC', 'L12')
# 1135: ('Cd2Ga2', 'hollow', 'Cd_Ga_Ga|HCP', 'L10')
# 1136: ('Ag3La', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 1137: ('Pt3Ru', 'hollow', 'Pt_Pt_Ru|HCP', 'L12')
# 1138: ('Tc3Au', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 1139: ('Ag3La', 'hollow', 'Ag_Ag_La|HCP', 'L12')
# 1140: ('Tc3Au', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 1141: ('Cr3Zn', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 1142: ('W3Re', 'hollow', 'W_W_W|FCC', 'L12')
# 1143: ('Rh3Os', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 1144: ('Rh3Os', 'hollow', 'Rh_Rh_Os|FCC', 'L12')
# 1147: ('W3Re', 'hollow', 'W_W_W|HCP', 'L12')
# 1148: ('Rh3Os', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 1149: ('Rh3Os', 'hollow', 'Rh_Rh_Os|HCP', 'L12')
# 1150: ('Zn3Ga', 'hollow', 'Zn_Zn_Ga|FCC', 'L12')
# 1151: ('W3Re', 'hollow', 'W_W_Re|FCC', 'L12')
# 1153: ('La3Ru', 'hollow', 'La_La_La|FCC', 'L12')
# 1154: ('Cu3Zr', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1155: ('W3Re', 'hollow', 'W_W_Re|HCP', 'L12')
# 1156: ('La3Ru', 'hollow', 'La_La_La|HCP', 'L12')
# 1157: ('Cu3Zr', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1158: ('Ru3Au', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 1159: ('Mo3Tc', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 1160: ('V3Rh', 'hollow', 'V_V_V|FCC', 'L12')
# 1161: ('V3Rh', 'hollow', 'V_V_Rh|HCP', 'L12')
# 1162: ('Ru3Au', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 1163: ('V3Rh', 'hollow', 'V_V_V|HCP', 'L12')
# 1164: ('Cr3Os', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 1165: ('Os3Pd', 'hollow', 'Os_Os_Os|FCC', 'L12')
# 1166: ('Rh3Y', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 1168: ('Y3Sn', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1169: ('Os3Pd', 'hollow', 'Os_Os_Os|HCP', 'L12')
# 1170: ('Rh3Y', 'hollow', 'Rh_Rh_Rh|HCP', 'L12')
# 1172: ('W3La', 'hollow', 'W_W_W|FCC', 'L12')
# 1173: ('Zn3Ru', 'hollow', 'Zn_Zn_Zn|FCC', 'L12')
# 1174: ('Au3Rh', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 1175: ('Os3Ta', 'hollow', 'Os_Os_Ta|HCP', 'L12')
# 1176: ('La3Cu', 'hollow', 'La_La_La|FCC', 'L12')
# 1177: ('Au3Rh', 'hollow', 'Au_Au_Au|HCP', 'L12')
# 1178: ('Sn3Ga', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1181: ('La3Cu', 'hollow', 'La_La_La|HCP', 'L12')
# 1182: ('Ir3Ta', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 1183: ('Au3Rh', 'hollow', 'Au_Au_Rh|FCC', 'L12')
# 1185: ('Mo2Ag2', 'hollow', 'Ag_Ag_Mo|FCC', 'L10')
# 1186: ('Ir3Ta', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 1187: ('Au3Rh', 'hollow', 'Au_Au_Rh|HCP', 'L12')
# 1188: ('Zr3Ti', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 1189: ('Pt3Al', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 1190: ('V3Pb', 'hollow', 'V_V_V|FCC', 'L12')
# 1191: ('Pt3Rh', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 1192: ('Ir3Au', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 1193: ('Ir3Ta', 'hollow', 'Ir_Ir_Ta|HCP', 'L12')
# 1194: ('Zr3Ti', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 1195: ('Pt3Rh', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 1196: ('Ir3Au', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 1197: ('W3Pd', 'hollow', 'W_W_W|HCP', 'L12')
# 1198: ('Zr3Ti', 'hollow', 'Zr_Zr_Ti|FCC', 'L12')
# 1199: ('Pt3Rh', 'hollow', 'Pt_Pt_Rh|FCC', 'L12')
# 1200: ('Zr3Ti', 'hollow', 'Zr_Zr_Ti|HCP', 'L12')
# 1201: ('Pt3Rh', 'hollow', 'Pt_Pt_Rh|HCP', 'L12')
# 1202: ('Mo2Ag2', 'hollow', 'Ag_Ag_Mo|HCP', 'L10')
# 1203: ('Cr3W', 'hollow', 'Cr_Cr_Cr|FCC', 'L12')
# 1204: ('Mo2Ag2', 'hollow', 'Ag_Mo_Mo|FCC', 'L10')
# 1205: ('Mo2Ag2', 'hollow', 'Ag_Mo_Mo|HCP', 'L10')
# 1206: ('La3Nb', 'top', 'Nb', 'L12')
# 1207: ('Y3Tl', 'hollow', 'Y_Y_Tl|HCP', 'L12')
# 1208: ('Ag3Zn', 'hollow', 'Ag_Ag_Ag|FCC', 'L12')
# 1210: ('Rh3Zr', 'hollow', 'Rh_Rh_Rh|FCC', 'L12')
# 1211: ('Hf3V', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 1213: ('W3Pt', 'hollow', 'W_W_Pt|FCC', 'L12')
# 1215: ('Tc3Nb', 'hollow', 'Tc_Tc_Tc|FCC', 'L12')
# 1216: ('Tc3Nb', 'hollow', 'Tc_Tc_Tc|HCP', 'L12')
# 1218: ('Tc3Nb', 'hollow', 'Tc_Tc_Nb|FCC', 'L12')
# 1219: ('Al3Mo', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1221: ('Tc3Nb', 'hollow', 'Tc_Tc_Nb|HCP', 'L12')
# 1223: ('Ti3Pt', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 1224: ('Tl3Ga', 'hollow', 'Tl_Tl_Tl|FCC', 'L12')
# 1225: ('Hf2Re2', 'hollow', 'Hf_Hf_Re|FCC', 'L10')
# 1226: ('Ir2Ga2', 'hollow', 'Ga_Ga_Ir|HCP', 'L10')
# 1227: ('Ti3Pt', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 1228: ('Tl3Ga', 'hollow', 'Tl_Tl_Tl|HCP', 'L12')
# 1229: ('Hf2Re2', 'top', 'Hf', 'L10')
# 1230: ('Ti3Pt', 'hollow', 'Ti_Ti_Pt|FCC', 'L12')
# 1231: ('Zn3Pt', 'hollow', 'Zn_Zn_Zn|FCC', 'L12')
# 1232: ('Hf2Re2', 'top', 'Re', 'L10')
# 1234: ('Mo2Au2', 'hollow', 'Au_Au_Mo|FCC', 'L10')
# 1235: ('Ti3Pt', 'hollow', 'Ti_Ti_Pt|HCP', 'L12')
# 1237: ('La2Cu2', 'hollow', 'Cu_La_La|FCC', 'L10')
# 1238: ('Mo2Au2', 'hollow', 'Au_Au_Mo|HCP', 'L10')
# 1239: ('Cu3Ru', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1240: ('Zn3Pt', 'hollow', 'Zn_Zn_Pt|FCC', 'L12')
# 1241: ('La2Cu2', 'top', 'La', 'L10')
# 1242: ('Mo2Au2', 'hollow', 'Au_Mo_Mo|FCC', 'L10')
# 1243: ('Cu3Ru', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1244: ('Mo2Au2', 'hollow', 'Au_Mo_Mo|HCP', 'L10')
# 1245: ('Zr2Sn2', 'hollow', 'Sn_Sn_Zr|FCC', 'L10')
# 1246: ('Zr2Sn2', 'hollow', 'Sn_Zr_Zr|HCP', 'L10')
# 1247: ('Cu3Ru', 'hollow', 'Cu_Cu_Ru|FCC', 'L12')
# 1248: ('La3Cd', 'hollow', 'La_La_La|FCC', 'L12')
# 1249: ('Ta3Al', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 1250: ('Ru3Ag', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 1251: ('Cu3Ru', 'hollow', 'Cu_Cu_Ru|HCP', 'L12')
# 1252: ('La3Cd', 'hollow', 'La_La_La|HCP', 'L12')
# 1253: ('Ta3Al', 'hollow', 'Ta_Ta_Al|FCC', 'L12')
# 1254: ('Ru3Ag', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 1255: ('Ag3V', 'hollow', 'Ag_Ag_Ag|HCP', 'L12')
# 1256: ('Zr2Sn2', 'hollow', 'Sn_Sn_Zr|HCP', 'L10')
# 1257: ('Zr2Sn2', 'hollow', 'Sn_Zr_Zr|FCC', 'L10')
# 1258: ('Zn3Y', 'hollow', 'Zn_Zn_Zn|FCC', 'L12')
# 1260: ('Co3Re', 'hollow', 'Co_Co_Co|FCC', 'L12')
# 1261: ('Ta3Al', 'hollow', 'Ta_Ta_Ta|FCC', 'L12')
# 1263: ('Co3Re', 'hollow', 'Co_Co_Co|HCP', 'L12')
# 1264: ('Mo2Re2', 'hollow', 'Mo_Mo_Re|FCC', 'L10')
# 1265: ('Al3W', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1266: ('Zn3Y', 'hollow', 'Zn_Zn_Y|FCC', 'L12')
# 1267: ('Co3Re', 'hollow', 'Co_Co_Re|FCC', 'L12')
# 1268: ('Al2Ga2', 'hollow', 'Al_Al_Ga|FCC', 'L10')
# 1269: ('Al3W', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1270: ('Co3Re', 'hollow', 'Co_Co_Re|HCP', 'L12')
# 1271: ('Al2Ga2', 'hollow', 'Al_Al_Ga|HCP', 'L10')
# 1272: ('Al3W', 'hollow', 'Al_Al_W|FCC', 'L12')
# 1273: ('Al2Ga2', 'hollow', 'Al_Ga_Ga|FCC', 'L10')
# 1274: ('W3Pb', 'hollow', 'W_W_W|FCC', 'L12')
# 1275: ('Al3W', 'hollow', 'Al_Al_W|HCP', 'L12')
# 1276: ('Al2Ga2', 'hollow', 'Al_Ga_Ga|HCP', 'L10')
# 1277: ('Mo2Re2', 'hollow', 'Mo_Mo_Re|HCP', 'L10')
# 1278: ('Mo2Re2', 'hollow', 'Mo_Re_Re|FCC', 'L10')
# 1279: ('In3Zn', 'hollow', 'In_In_In|FCC', 'L12')
# 1280: ('Cr3Tc', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 1281: ('Mo2Re2', 'hollow', 'Mo_Re_Re|HCP', 'L10')
# 1283: ('Pd3Zr', 'top', 'Zr', 'L12')
# 1284: ('Cr2Tc2', 'hollow', 'Cr_Tc_Tc|HCP', 'L10')
# 1286: ('V2Ga2', 'hollow', 'Ga_Ga_V|FCC', 'L10')
# 1287: ('Cr2Tc2', 'top', 'Cr', 'L10')
# 1288: ('Zr2Pb2', 'hollow', 'Pb_Pb_Zr|FCC', 'L10')
# 1289: ('V2Ga2', 'hollow', 'Ga_Ga_V|HCP', 'L10')
# 1290: ('Cr2Tc2', 'top', 'Tc', 'L10')
# 1291: ('Zr2Pb2', 'hollow', 'Pb_Pb_Zr|HCP', 'L10')
# 1292: ('V2Ga2', 'hollow', 'Ga_V_V|FCC', 'L10')
# 1293: ('Sc2Pb2', 'hollow', 'Pb_Pb_Sc|FCC', 'L10')
# 1294: ('Zr2Pb2', 'hollow', 'Pb_Zr_Zr|FCC', 'L10')
# 1295: ('V2Ga2', 'hollow', 'Ga_V_V|HCP', 'L10')
# 1296: ('Sc2Pb2', 'hollow', 'Pb_Sc_Sc|FCC', 'L10')
# 1297: ('Zr2Pb2', 'hollow', 'Pb_Zr_Zr|HCP', 'L10')
# 1298: ('Sc2Pb2', 'hollow', 'Pb_Sc_Sc|HCP', 'L10')
# 1299: ('Cu2Ga2', 'hollow', 'Cu_Ga_Ga|FCC', 'L10')
# 1301: ('Mo3Nb', 'top', 'Nb', 'L12')
# 1302: ('Cu2Ga2', 'hollow', 'Cu_Ga_Ga|HCP', 'L10')
# 1303: ('Zr2Tc2', 'top', 'Tc', 'L10')
# 1305: ('Zr3Mo', 'hollow', 'Zr_Zr_Mo|FCC', 'L12')
# 1306: ('Tc3W', 'hollow', 'Tc_Tc_W|FCC', 'L12')
# 1307: ('Y3Cd', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1308: ('Ti3Ta', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 1309: ('Ru3Rh', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 1310: ('Ti3V', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 1311: ('Au3Ir', 'hollow', 'Au_Au_Au|FCC', 'L12')
# 1313: ('Ti3Ta', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 1314: ('Ru3Rh', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 1315: ('Ti3V', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 1316: ('Au3Ir', 'hollow', 'Au_Au_Ir|FCC', 'L12')
# 1317: ('La3Ga', 'hollow', 'La_La_La|HCP', 'L12')
# 1318: ('Ti3Ta', 'hollow', 'Ti_Ti_Ta|FCC', 'L12')
# 1319: ('Ru3Rh', 'hollow', 'Ru_Ru_Rh|FCC', 'L12')
# 1320: ('Ti3V', 'hollow', 'Ti_Ti_V|FCC', 'L12')
# 1321: ('Au3Ir', 'hollow', 'Au_Au_Ir|HCP', 'L12')
# 1322: ('Ti3Ta', 'hollow', 'Ti_Ti_Ta|HCP', 'L12')
# 1323: ('Ru3Rh', 'hollow', 'Ru_Ru_Rh|HCP', 'L12')
# 1324: ('Zn3Pb', 'hollow', 'Zn_Zn_Zn|FCC', 'L12')
# 1327: ('Pd3Y', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 1328: ('Pb3Rh', 'hollow', 'Pb_Pb_Pb|FCC', 'L12')
# 1329: ('Pd3Y', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 1330: ('Pb3Rh', 'hollow', 'Pb_Pb_Pb|HCP', 'L12')
# 1331: ('Cu3Au', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1332: ('Sn3La', 'hollow', 'Sn_Sn_La|FCC', 'L12')
# 1333: ('Pt3Pb', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 1334: ('Nb3Ga', 'hollow', 'Nb_Nb_Ga|FCC', 'L12')
# 1335: ('La3Re', 'hollow', 'La_La_La|FCC', 'L12')
# 1336: ('Zr3Ga', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 1337: ('La3Re', 'hollow', 'La_La_La|HCP', 'L12')
# 1338: ('Zr3Ga', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 1339: ('Cu3Au', 'hollow', 'Cu_Cu_Cu|HCP', 'L12')
# 1340: ('Zr3Ga', 'hollow', 'Zr_Zr_Ga|HCP', 'L12')
# 1341: ('Cu3Au', 'hollow', 'Cu_Cu_Au|FCC', 'L12')
# 1342: ('La3Au', 'hollow', 'La_La_La|FCC', 'L12')
# 1343: ('Sn3Ag', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1344: ('Hf3Tl', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 1345: ('La3Au', 'hollow', 'La_La_La|HCP', 'L12')
# 1346: ('Sn3Ag', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1347: ('Hf3Tl', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 1348: ('Cu3Au', 'hollow', 'Cu_Cu_Au|HCP', 'L12')
# 1349: ('Sn3Ag', 'hollow', 'Sn_Sn_Ag|FCC', 'L12')
# 1350: ('Hf3Tl', 'hollow', 'Hf_Hf_Tl|FCC', 'L12')
# 1353: ('Hf3Tl', 'hollow', 'Hf_Hf_Tl|HCP', 'L12')
# 1354: ('Ta3Au', 'hollow', 'Ta_Ta_Ta|FCC', 'L12')
# 1355: ('Mo3Pb', 'hollow', 'Mo_Mo_Mo|FCC', 'L12')
# 1356: ('Sn3Zr', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1357: ('Ta3Au', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 1358: ('Mo3Pb', 'hollow', 'Mo_Mo_Mo|HCP', 'L12')
# 1359: ('Sn3Zr', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1360: ('Ta3Au', 'hollow', 'Ta_Ta_Au|FCC', 'L12')
# 1361: ('Sn3Zr', 'hollow', 'Sn_Sn_Zr|FCC', 'L12')
# 1362: ('Mo3Au', 'hollow', 'Mo_Mo_Au|HCP', 'L12')
# 1363: ('Cr2Fe2', 'hollow', 'Cr_Fe_Fe|FCC', 'L10')
# 1364: ('Zr2Os2', 'hollow', 'Os_Zr_Zr|FCC', 'L10')
# 1365: ('Sn3Zr', 'hollow', 'Sn_Sn_Zr|HCP', 'L12')
# 1367: ('Zr2Os2', 'top', 'Os', 'L10')
# 1368: ('Zr3Cd', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 1369: ('Ti3Sn', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 1370: ('Y3Au', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1371: ('Pd3Cd', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 1372: ('Zr3Cd', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 1373: ('Zr3Cd', 'hollow', 'Zr_Zr_Cd|FCC', 'L12')
# 1374: ('V3Zn', 'hollow', 'V_V_V|FCC', 'L12')
# 1375: ('La3Sc', 'hollow', 'La_La_La|HCP', 'L12')
# 1376: ('Zr3Rh', 'hollow', 'Zr_Zr_Rh|HCP', 'L12')
# 1377: ('Y3Nb', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1378: ('Pt3Ir', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 1379: ('Al3Re', 'hollow', 'Al_Al_Al|FCC', 'L12')
# 1380: ('Zr3Cd', 'hollow', 'Zr_Zr_Cd|HCP', 'L12')
# 1382: ('La3Sc', 'hollow', 'La_La_Sc|FCC', 'L12')
# 1383: ('Y3Nb', 'hollow', 'Y_Y_Nb|HCP', 'L12')
# 1384: ('Pt3Ir', 'hollow', 'Pt_Pt_Pt|HCP', 'L12')
# 1385: ('Al3Re', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1386: ('V3Zn', 'hollow', 'V_V_Zn|FCC', 'L12')
# 1387: ('La3Sc', 'hollow', 'La_La_Sc|HCP', 'L12')
# 1388: ('Pt3Ir', 'hollow', 'Pt_Pt_Ir|FCC', 'L12')
# 1389: ('Al3Re', 'hollow', 'Al_Al_Re|FCC', 'L12')
# 1390: ('Pt3Ir', 'hollow', 'Pt_Pt_Ir|HCP', 'L12')
# 1391: ('Re2Ir2', 'hollow', 'Ir_Ir_Re|FCC', 'L10')
# 1392: ('La2Au2', 'hollow', 'Au_La_La|FCC', 'L10')
# 1393: ('Re3Cr', 'top', 'Re', 'L12')
# 1394: ('Al3Re', 'hollow', 'Al_Al_Re|HCP', 'L12')
# 1395: ('Re2Ir2', 'hollow', 'Ir_Ir_Re|HCP', 'L10')
# 1396: ('Zr2Os2', 'top', 'Zr', 'L10')
# 1397: ('Re2Ir2', 'hollow', 'Ir_Re_Re|FCC', 'L10')
# 1398: ('Re3Cr', 'top', 'Cr', 'L12')
# 1399: ('Re2Ir2', 'hollow', 'Ir_Re_Re|HCP', 'L10')
# 1400: ('In3Cd', 'hollow', 'In_In_In|FCC', 'L12')
# 1402: ('Y3W', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 1403: ('In3Cd', 'hollow', 'In_In_In|HCP', 'L12')
# 1404: ('V2Os2', 'hollow', 'Os_V_V|HCP', 'L10')
# 1405: ('In3Cd', 'hollow', 'In_In_Cd|HCP', 'L12')
# 1406: ('Y2Ta2', 'hollow', 'Ta_Ta_Y|FCC', 'L10')
# 1407: ('Tc2Fe2', 'hollow', 'Fe_Fe_Tc|FCC', 'L10')
# 1408: ('Y2Ta2', 'hollow', 'Ta_Y_Y|FCC', 'L10')
# 1409: ('Ir3Tc', 'hollow', 'Ir_Ir_Ir|FCC', 'L12')
# 1410: ('Y2Ta2', 'hollow', 'Ta_Y_Y|HCP', 'L10')
# 1411: ('Ir3Tc', 'hollow', 'Ir_Ir_Ir|HCP', 'L12')
# 1413: ('Ir3Tc', 'hollow', 'Ir_Ir_Tc|FCC', 'L12')
# 1414: ('La2Pd2', 'hollow', 'La_La_Pd|FCC', 'L10')
# 1415: ('Ta2Pd2', 'hollow', 'Pd_Pd_Ta|FCC', 'L10')
# 1416: ('Ir3Tc', 'hollow', 'Ir_Ir_Tc|HCP', 'L12')
# 1417: ('La2Pd2', 'top', 'La', 'L10')
# 1418: ('Ta2Pd2', 'hollow', 'Pd_Pd_Ta|HCP', 'L10')
# 1419: ('Ta2Pd2', 'hollow', 'Pd_Ta_Ta|FCC', 'L10')
# 1420: ('Ru3Re', 'hollow', 'Ru_Ru_Ru|FCC', 'L12')
# 1421: ('Re3Tc', 'hollow', 'Re_Re_Re|FCC', 'L12')
# 1422: ('Pt3Ga', 'hollow', 'Pt_Pt_Pt|FCC', 'L12')
# 1423: ('Al3Os', 'hollow', 'Al_Al_Al|HCP', 'L12')
# 1424: ('Ru3La', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 1425: ('Ru3Re', 'hollow', 'Ru_Ru_Ru|HCP', 'L12')
# 1426: ('Re3Tc', 'hollow', 'Re_Re_Re|HCP', 'L12')
# 1427: ('Sn3Al', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1428: ('Pd3Hf', 'hollow', 'Pd_Pd_Pd|FCC', 'L12')
# 1429: ('Ru3Re', 'hollow', 'Ru_Ru_Re|FCC', 'L12')
# 1430: ('Re3Tc', 'hollow', 'Re_Re_Tc|FCC', 'L12')
# 1431: ('Sn3Al', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1432: ('Ga2Pb2', 'hollow', 'Ga_Ga_Pb|FCC', 'L10')
# 1433: ('Pd3Hf', 'hollow', 'Pd_Pd_Pd|HCP', 'L12')
# 1434: ('Ru3Re', 'hollow', 'Ru_Ru_Re|HCP', 'L12')
# 1435: ('Re3Tc', 'hollow', 'Re_Re_Tc|HCP', 'L12')
# 1436: ('Sc3Tc', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 1437: ('V3Tl', 'hollow', 'V_V_V|FCC', 'L12')
# 1438: ('Nb3Tl', 'hollow', 'Nb_Nb_Nb|FCC', 'L12')
# 1439: ('Pd3Hf', 'hollow', 'Pd_Pd_Hf|FCC', 'L12')
# 1440: ('V3Zr', 'hollow', 'V_V_V|FCC', 'L12')
# 1441: ('Cu3Zn', 'hollow', 'Cu_Cu_Cu|FCC', 'L12')
# 1442: ('Nb3Tl', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 1443: ('Ga2Pb2', 'hollow', 'Ga_Pb_Pb|HCP', 'L10')
# 1444: ('Pd3Hf', 'hollow', 'Pd_Pd_Hf|HCP', 'L12')
# 1445: ('V3Zr', 'hollow', 'V_V_V|HCP', 'L12')
# 1447: ('Cu3Zn', 'hollow', 'Cu_Cu_Zn|FCC', 'L12')
# 1449: ('Nb2Au2', 'hollow', 'Au_Au_Nb|FCC', 'L10')
# 1450: ('Sn3Hf', 'hollow', 'Sn_Sn_Sn|FCC', 'L12')
# 1451: ('Sn3Hf', 'hollow', 'Sn_Sn_Sn|HCP', 'L12')
# 1453: ('Sn3Hf', 'hollow', 'Sn_Sn_Hf|FCC', 'L12')
# 1454: ('Zn3Ir', 'hollow', 'Zn_Zn_Ir|FCC', 'L12')
# 1455: ('Pb3Ag', 'hollow', 'Pb_Pb_Pb|HCP', 'L12')
# 1456: ('Sn3Hf', 'hollow', 'Sn_Sn_Hf|HCP', 'L12')
# 1457: ('V3Cd', 'hollow', 'V_V_V|FCC', 'L12')
# 1459: ('Ti2Ga2', 'hollow', 'Ga_Ga_Ti|FCC', 'L10')
# 1461: ('V3Cd', 'hollow', 'V_V_V|HCP', 'L12')
# 1462: ('Ti2Ga2', 'hollow', 'Ga_Ga_Ti|HCP', 'L10')
# ...
# 5811: ('Cr3Ir', 'hollow', 'Cr_Cr_Cr|HCP', 'L12')
# 5812: ('Hf3Cr', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 5813: ('Cr3Ir', 'hollow', 'Cr_Cr_Ir|FCC', 'L12')
# 5814: ('Hf3Cr', 'hollow', 'Hf_Hf_Cr|HCP', 'L12')
# 5822: ('Sc3Y', 'hollow', 'Sc_Sc_Y|FCC', 'L12')
# 5825: ('Sc3Y', 'hollow', 'Sc_Sc_Y|HCP', 'L12')
# 5827: ('Sc3Hf', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5828: ('Zr3Y', 'hollow', 'Zr_Zr_Y|FCC', 'L12')
# 5831: ('Sc3Zr', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5832: ('Sc3Hf', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5833: ('Zr3Y', 'hollow', 'Zr_Zr_Y|HCP', 'L12')
# 5834: ('Zr3Sc', 'hollow', 'Zr_Zr_Sc|HCP', 'L12')
# 5835: ('Y3Zr', 'hollow', 'Y_Y_Zr|FCC', 'L12')
# 5840: ('Y2Ta2', 'hollow', 'Ta_Ta_Y|FCC', 'L10')
# 5841: ('Sc3Hf', 'hollow', 'Sc_Sc_Hf|FCC', 'L12')
# 5842: ('Y3Sc', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5845: ('Y3Sc', 'hollow', 'Y_Y_Sc|FCC', 'L12')
# 5846: ('Y3Zr', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5848: ('Y3Cr', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5851: ('Y3V', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5852: ('Y3Mo', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5853: ('Y3Os', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5854: ('Y3V', 'hollow', 'Y_Y_V|FCC', 'L12')
# 5855: ('Y3Mo', 'hollow', 'Y_Y_Mo|HCP', 'L12')
# 5856: ('Y3W', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5857: ('Y3W', 'hollow', 'Y_Y_W|HCP', 'L12')
# 5862: ('Y2Ir2', 'top', 'Y', 'L10')
# 5864: ('Y3Au', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5865: ('Y3Ag', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5866: ('Y3Zn', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5867: ('Y3Au', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5869: ('Y3Ag', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5870: ('Y3Cu', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5872: ('Y3Zn', 'hollow', 'Y_Y_Zn|FCC', 'L12')
# 5873: ('Y3Cd', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5874: ('Y3Cu', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5876: ('Y3Al', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5877: ('Y3Al', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5878: ('Y3Al', 'hollow', 'Y_Y_Al|FCC', 'L12')
# 5879: ('La3Ti', 'top', 'Ti', 'L12')
# 5881: ('Y3In', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5882: ('Y3Sn', 'hollow', 'Y_Y_Y|FCC', 'L12')
# 5887: ('La3Tc', 'top', 'Tc', 'L12')
# 5888: ('Y3Ga', 'hollow', 'Y_Y_Y|HCP', 'L12')
# 5889: ('La3Mo', 'hollow', 'La_La_La|FCC', 'L12')
# 5891: ('La3Re', 'top', 'Re', 'L12')
# 5892: ('Y3Ga', 'top', 'Ga', 'L12')
# 5894: ('La3Ru', 'top', 'Ru', 'L12')
# 5898: ('La3Pd', 'top', 'Pd', 'L12')
# 5899: ('La3Ag', 'bridge', 'La_Ag|La', 'L12')
# 5900: ('La2Ag2', 'bridge', 'Ag_Ag|La', 'L10')
# 5901: ('La2Pt2', 'bridge', 'Pt_Pt|La', 'L10')
# 5902: ('La3Zn', 'bridge', 'La_Zn|La', 'L12')
# 5903: ('La3Fe', 'hollow', 'La_La_La|FCC', 'L12')
# 5904: ('La2Zn2', 'bridge', 'Zn_Zn|La', 'L10')
# 5905: ('La2Zn2', 'hollow', 'La_La_Zn|FCC', 'L10')
# 5906: ('La3Au', 'top', 'Au', 'L12')
# 5907: ('La3Cd', 'bridge', 'La_Cd|La', 'L12')
# 5908: ('La3Cd', 'hollow', 'La_La_La|FCC', 'L12')
# 5909: ('La3Cd', 'top', 'Cd', 'L12')
# 5911: ('La2Al2', 'hollow', 'Al_La_La|FCC', 'L10')
# 5912: ('La3In', 'hollow', 'La_La_In|FCC', 'L12')
# 5913: ('La2In2', 'bridge', 'La_La|In', 'L10')
# 5914: ('La3Pb', 'bridge', 'La_La|La', 'L12')
# 5917: ('La3Tl', 'hollow', 'La_La_La|FCC', 'L12')
# 5919: ('Sc3Ti', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5920: ('Sc2Ti2', 'hollow', 'Sc_Sc_Ti|HCP', 'L10')
# 5921: ('Sc2Nb2', 'hollow', 'Nb_Sc_Sc|FCC', 'L10')
# 5922: ('La3Al', 'top', 'Al', 'L12')
# 5924: ('Sc3Ti', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5926: ('Sc3Nb', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5927: ('Sc3Ti', 'hollow', 'Sc_Sc_Ti|FCC', 'L12')
# 5928: ('Sc3Ta', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5929: ('Sc3Nb', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5931: ('Sc3Ta', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5932: ('Sc2Ta2', 'hollow', 'Sc_Sc_Ta|FCC', 'L10')
# 5933: ('Sc3V', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5934: ('Sc2Ta2', 'hollow', 'Sc_Sc_Ta|HCP', 'L10')
# 5935: ('Sc3V', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5936: ('La2Cd2', 'top', 'La', 'L10')
# 5937: ('Sc2Ta2', 'hollow', 'Sc_Ta_Ta|FCC', 'L10')
# 5938: ('Sc2Ta2', 'hollow', 'Sc_Ta_Ta|HCP', 'L10')
# 5944: ('Sc3Rh', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5945: ('Sc3Cr', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5946: ('Sc3Ir', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5947: ('Sc3Cr', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5948: ('Sc3Tc', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5949: ('Sc3Ir', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5950: ('Sc3Cr', 'hollow', 'Sc_Sc_Cr|HCP', 'L12')
# 5951: ('Sc3W', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5952: ('Sc3Tc', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5953: ('Sc3Os', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5954: ('Sc3W', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5955: ('Sc3Tc', 'hollow', 'Sc_Sc_Tc|HCP', 'L12')
# 5956: ('Sc3Os', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5957: ('Sc3W', 'hollow', 'Sc_Sc_W|HCP', 'L12')
# 5959: ('Sc3Pd', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5961: ('Sc3Fe', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5962: ('Sc3Pt', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5963: ('Sc3Pd', 'hollow', 'Sc_Sc_Pd|FCC', 'L12')
# 5964: ('Sc3Cu', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5965: ('Sc3Fe', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5966: ('Sc3Pt', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5968: ('Sc3Cd', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5969: ('Sc3Zn', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5970: ('Sc3Cd', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5972: ('Sc3Zn', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5978: ('Zr2Ti2', 'hollow', 'Ti_Ti_Zr|FCC', 'L10')
# 5980: ('Zr3V', 'hollow', 'Zr_Zr_V|HCP', 'L12')
# 5981: ('Sc3Al', 'hollow', 'Sc_Sc_Al|FCC', 'L12')
# 5983: ('Zr2Ti2', 'hollow', 'Ti_Zr_Zr|HCP', 'L10')
# 5984: ('Sc3Tl', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5985: ('Sc3Pb', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5986: ('Zr3Nb', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 5987: ('Zr3V', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 5988: ('Sc2Al2', 'hollow', 'Al_Al_Sc|HCP', 'L10')
# 5989: ('Sc3Ga', 'hollow', 'Sc_Sc_Sc|FCC', 'L12')
# 5991: ('Sc3Tl', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5992: ('Sc3Pb', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5993: ('Zr3Ta', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 5994: ('Zr3Nb', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 5995: ('Zr3V', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 5996: ('Sc3Ga', 'hollow', 'Sc_Sc_Sc|HCP', 'L12')
# 5997: ('Sc2In2', 'hollow', 'In_In_Sc|FCC', 'L10')
# 5998: ('Zr3Ta', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 5999: ('Zr3Nb', 'hollow', 'Zr_Zr_Nb|HCP', 'L12')
# 6000: ('Sc2In2', 'hollow', 'In_In_Sc|HCP', 'L10')
# 6001: ('Zr3Ta', 'hollow', 'Zr_Zr_Ta|HCP', 'L12')
# 6002: ('Zr3Nb', 'top', 'Nb', 'L12')
# 6003: ('Zr3Mo', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6004: ('Zr3Re', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6005: ('Zr3Ru', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6006: ('Zr3Ir', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6007: ('Zr3Rh', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6009: ('Zr3Fe', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6010: ('Zr3Re', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6011: ('Zr3Ir', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6012: ('Zr3Rh', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6013: ('Zr3Fe', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6015: ('Zr3Fe', 'hollow', 'Zr_Zr_Fe|HCP', 'L12')
# 6019: ('Zr2Au2', 'hollow', 'Au_Au_Zr|FCC', 'L10')
# 6022: ('Zr3W', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6023: ('Zr3Ag', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6024: ('Zr2Ag2', 'hollow', 'Ag_Ag_Zr|FCC', 'L10')
# 6026: ('Zr3W', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6029: ('Zr3Au', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6030: ('Zr2Ag2', 'hollow', 'Ag_Ag_Zr|HCP', 'L10')
# 6032: ('Zr3Pt', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6033: ('Zr3Au', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6034: ('Zr2Ag2', 'top', 'Zr', 'L10')
# 6037: ('Zr3Pt', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6038: ('Zr3Cd', 'top', 'Cd', 'L12')
# 6039: ('Zr3Ga', 'top', 'Ga', 'L12')
# 6041: ('Zr3Al', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6042: ('Zr3In', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6043: ('Zr3Tl', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6044: ('Zr3Sn', 'hollow', 'Zr_Zr_Zr|FCC', 'L12')
# 6048: ('Zr3Al', 'hollow', 'Zr_Zr_Al|FCC', 'L12')
# 6050: ('Zr3Tl', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6051: ('Zr3Sn', 'hollow', 'Zr_Zr_Zr|HCP', 'L12')
# 6053: ('Hf3La', 'bridge', 'Hf_Hf|La', 'L12')
# 6054: ('Hf3Mo', 'top', 'Mo', 'L12')
# 6055: ('Zr2Al2', 'hollow', 'Al_Al_Zr|FCC', 'L10')
# 6058: ('Hf3W', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 6059: ('Hf3Re', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 6060: ('Zr2Al2', 'hollow', 'Al_Al_Zr|HCP', 'L10')
# 6061: ('Zr2In2', 'hollow', 'In_In_Zr|FCC', 'L10')
# 6062: ('Hf2Mo2', 'hollow', 'Hf_Hf_Mo|HCP', 'L10')
# 6063: ('Hf3W', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6064: ('Hf3Re', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6066: ('Zr2Al2', 'hollow', 'Al_Zr_Zr|FCC', 'L10')
# 6067: ('Hf2Mo2', 'hollow', 'Hf_Mo_Mo|HCP', 'L10')
# 6068: ('Hf3W', 'hollow', 'Hf_Hf_W|HCP', 'L12')
# 6069: ('Hf3Os', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 6070: ('Hf3Ir', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6071: ('Zr2Al2', 'hollow', 'Al_Zr_Zr|HCP', 'L10')
# 6072: ('Hf3Os', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6073: ('Hf3Rh', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 6074: ('Zr2Al2', 'top', 'Al', 'L10')
# 6075: ('Hf3Ru', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 6076: ('Hf3Rh', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6077: ('Hf3Ru', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6078: ('Hf3Rh', 'hollow', 'Hf_Hf_Rh|FCC', 'L12')
# 6080: ('Hf3Ru', 'top', 'Ru', 'L12')
# 6081: ('Hf3Rh', 'top', 'Rh', 'L12')
# 6082: ('Hf2Pt2', 'bridge', 'Pt_Pt|Hf', 'L10')
# 6083: ('Hf3Pd', 'bridge', 'Hf_Hf|Pd', 'L12')
# 6084: ('Hf2Pd2', 'bridge', 'Pd_Pd|Hf', 'L10')
# 6085: ('Hf2Ag2', 'bridge', 'Ag_Ag|Hf', 'L10')
# 6086: ('Hf3Pt', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6087: ('Hf3Pd', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6088: ('Hf2Au2', 'hollow', 'Au_Hf_Hf|FCC', 'L10')
# 6089: ('Hf3Cu', 'hollow', 'Hf_Hf_Hf|FCC', 'L12')
# 6093: ('Hf2Ga2', 'bridge', 'Ga_Ga|Hf', 'L10')
# 6094: ('Hf2In2', 'bridge', 'In_In|Hf', 'L10')
# 6095: ('Hf3Tl', 'top', 'Tl', 'L12')
# 6097: ('Hf3Pb', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6098: ('Hf3Ga', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6099: ('Hf3Sn', 'top', 'Sn', 'L12')
# 6100: ('Hf3Zn', 'top', 'Zn', 'L12')
# 6102: ('Ti3Sc', 'hollow', 'Ti_Ti_Sc|FCC', 'L12')
# 6104: ('Hf3Cd', 'hollow', 'Hf_Hf_Hf|HCP', 'L12')
# 6105: ('Ti3Y', 'hollow', 'Ti_Ti_Y|HCP', 'L12')
# 6106: ('Ti3V', 'hollow', 'Ti_Ti_V|HCP', 'L12')
# 6107: ('Hf3Cd', 'top', 'Cd', 'L12')
# 6109: ('Ti3Hf', 'hollow', 'Ti_Ti_Hf|FCC', 'L12')
# 6111: ('Ti3Hf', 'hollow', 'Ti_Ti_Hf|HCP', 'L12')
# 6113: ('Ti2Au2', 'hollow', 'Au_Ti_Ti|FCC', 'L10')
# 6116: ('Ti3Zn', 'top', 'Zn', 'L12')
# 6118: ('Ti3Os', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6120: ('Ti2Ag2', 'hollow', 'Ag_Ti_Ti|FCC', 'L10')
# 6122: ('Ti3Cr', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6123: ('Ti2Mo2', 'hollow', 'Mo_Ti_Ti|HCP', 'L10')
# 6124: ('Ti3Os', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6125: ('Ti3Rh', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6128: ('Ti3Pd', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6129: ('Ti3Cr', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6130: ('Ti3W', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6131: ('Ti3Re', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6134: ('Ti3Pd', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6135: ('Ti3Cd', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6136: ('Ti3W', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6137: ('Ti3Re', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6140: ('Ti3Pd', 'hollow', 'Ti_Ti_Pd|FCC', 'L12')
# 6141: ('Ti3Cd', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6142: ('Ti3W', 'hollow', 'Ti_Ti_W|HCP', 'L12')
# 6143: ('Ti3Ag', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6145: ('Ti3Ag', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6146: ('Ti3Cu', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6147: ('Ti3Ru', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6148: ('Ti3Cu', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6149: ('Ti3Ru', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6151: ('Ta3Y', 'hollow', 'Ta_Ta_Y|HCP', 'L12')
# 6153: ('Ti2Tl2', 'top', 'Ti', 'L10')
# 6154: ('Ti3Sn', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6156: ('Ta3Ti', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6159: ('Ta3Mo', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6161: ('Ti3Pb', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6162: ('Ta3Ti', 'hollow', 'Ta_Ta_Ti|HCP', 'L12')
# 6164: ('Ta3Cr', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6165: ('Ta3Mo', 'hollow', 'Ta_Ta_Mo|HCP', 'L12')
# 6167: ('Ti3Al', 'hollow', 'Ti_Ti_Ti|FCC', 'L12')
# 6169: ('Ti3Pb', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6170: ('Ta3Re', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6171: ('Ti3Al', 'hollow', 'Ti_Ti_Ti|HCP', 'L12')
# 6172: ('Ti2In2', 'hollow', 'In_In_Ti|FCC', 'L10')
# 6173: ('Ti3Al', 'hollow', 'Ti_Ti_Al|FCC', 'L12')
# 6175: ('Ta3Zr', 'hollow', 'Ta_Ta_Zr|FCC', 'L12')
# 6176: ('Ta3Zr', 'hollow', 'Ta_Ta_Zr|HCP', 'L12')
# 6177: ('Ta3Nb', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6178: ('Ta3Nb', 'hollow', 'Ta_Ta_Nb|HCP', 'L12')
# 6180: ('Ta3Tc', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6184: ('Ta3Ru', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6185: ('Ta3Ir', 'hollow', 'Ta_Ta_Ta|FCC', 'L12')
# 6188: ('Ta2Tc2', 'hollow', 'Ta_Ta_Tc|HCP', 'L10')
# 6189: ('Ta3Ru', 'hollow', 'Ta_Ta_Ru|HCP', 'L12')
# 6190: ('Ta3Ir', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6192: ('Ta3Fe', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6193: ('Ta2Fe2', 'hollow', 'Fe_Ta_Ta|FCC', 'L10')
# 6195: ('Ta3Zn', 'hollow', 'Ta_Ta_Ta|FCC', 'L12')
# 6196: ('Ta3Rh', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6200: ('Ta3Zn', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6201: ('Ta3Cd', 'hollow', 'Ta_Ta_Ta|FCC', 'L12')
# 6202: ('Ta3Rh', 'hollow', 'Ta_Ta_Rh|HCP', 'L12')
# 6204: ('Ta3Cu', 'hollow', 'Ta_Ta_Ta|FCC', 'L12')
# 6205: ('Ta3Cd', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6206: ('Ta3Cu', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6207: ('Ta2Al2', 'hollow', 'Al_Al_Ta|FCC', 'L10')
# 6208: ('Nb3Y', 'hollow', 'Nb_Nb_Y|HCP', 'L12')
# 6210: ('Ta2Zn2', 'hollow', 'Ta_Zn_Zn|HCP', 'L10')
# 6212: ('Ta3In', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6213: ('Nb3Zr', 'hollow', 'Nb_Nb_Zr|HCP', 'L12')
# 6214: ('Nb3Hf', 'hollow', 'Nb_Nb_Hf|HCP', 'L12')
# 6215: ('Nb3Ti', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6216: ('Nb3V', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6218: ('Ta3Ga', 'hollow', 'Ta_Ta_Ta|FCC', 'L12')
# 6220: ('Nb3Ti', 'hollow', 'Nb_Nb_Ti|HCP', 'L12')
# 6222: ('Nb3V', 'hollow', 'Nb_Nb_V|HCP', 'L12')
# 6223: ('Ta3Ga', 'hollow', 'Ta_Ta_Ta|HCP', 'L12')
# 6224: ('Nb3Ta', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6228: ('Nb2W2', 'hollow', 'Nb_Nb_W|HCP', 'L10')
# 6229: ('Nb3Mo', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6230: ('Nb3W', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6231: ('Nb2W2', 'hollow', 'Nb_W_W|FCC', 'L10')
# 6232: ('Nb3Re', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6233: ('Nb2W2', 'hollow', 'Nb_Nb_W|FCC', 'L10')
# 6234: ('Nb2W2', 'hollow', 'Nb_W_W|HCP', 'L10')
# 6236: ('Nb3Ir', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6238: ('Nb2Ir2', 'hollow', 'Ir_Ir_Nb|FCC', 'L10')
# 6239: ('Nb2Ir2', 'hollow', 'Ir_Nb_Nb|HCP', 'L10')
# 6240: ('Nb3Rh', 'hollow', 'Nb_Nb_Nb|FCC', 'L12')
# 6241: ('Nb3Ir', 'hollow', 'Nb_Nb_Nb|FCC', 'L12')
# 6242: ('Nb3Rh', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6250: ('Nb3Pd', 'top', 'Pd', 'L12')
# 6252: ('Nb3Fe', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6256: ('Nb2Au2', 'hollow', 'Au_Au_Nb|FCC', 'L10')
# 6258: ('Nb3Cu', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6259: ('Nb3Zn', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6260: ('Nb3Ga', 'top', 'Ga', 'L12')
# 6263: ('V3Zr', 'hollow', 'V_V_Zr|HCP', 'L12')
# 6264: ('V3Hf', 'hollow', 'V_V_Hf|HCP', 'L12')
# 6265: ('V3Ti', 'hollow', 'V_V_Ti|HCP', 'L12')
# 6266: ('V3Ta', 'hollow', 'V_V_Ta|HCP', 'L12')
# 6267: ('V3Nb', 'hollow', 'V_V_Nb|HCP', 'L12')
# 6268: ('V3Mo', 'hollow', 'V_V_V|HCP', 'L12')
# 6269: ('Nb3In', 'hollow', 'Nb_Nb_Nb|FCC', 'L12')
# 6271: ('Nb3In', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6276: ('V3W', 'hollow', 'V_V_V|HCP', 'L12')
# 6278: ('V3W', 'top', 'W', 'L12')
# 6281: ('Nb2Tl2', 'top', 'Nb', 'L10')
# 6282: ('Nb3Al', 'top', 'Al', 'L12')
# 6283: ('Nb3Ga', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6284: ('Nb3Sn', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6285: ('V2Zn2', 'hollow', 'V_V_Zn|HCP', 'L10')
# 6286: ('V2Cd2', 'hollow', 'Cd_Cd_V|FCC', 'L10')
# 6290: ('Nb3Cd', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6291: ('V3Tc', 'hollow', 'V_V_V|HCP', 'L12')
# 6292: ('Nb3Pb', 'hollow', 'Nb_Nb_Nb|HCP', 'L12')
# 6293: ('V3Ir', 'hollow', 'V_V_V|FCC', 'L12')
# 6294: ('V3Ir', 'hollow', 'V_V_V|HCP', 'L12')
# 6300: ('V2Au2', 'hollow', 'Au_Au_V|FCC', 'L10')
# 6302: ('V3Os', 'hollow', 'V_V_V|HCP', 'L12')
# 6306: ('V2Cu2', 'hollow', 'Cu_Cu_V|FCC', 'L10')
# 6307: ('V2Cu2', 'hollow', 'Cu_Cu_V|HCP', 'L10')
# 6308: ('V2Cu2', 'hollow', 'Cu_V_V|FCC', 'L10')
# 6309: ('V2Cu2', 'hollow', 'Cu_V_V|HCP', 'L10')
# 6310: ('V2Cu2', 'top', 'V', 'L10')
# 6312: ('V2Cd2', 'hollow', 'Cd_V_V|FCC', 'L10')
# 6314: ('V3Al', 'hollow', 'V_V_V|FCC', 'L12')
# 6316: ('V3In', 'hollow', 'V_V_V|HCP', 'L12')
# 6317: ('V3Tl', 'hollow', 'V_V_V|HCP', 'L12')
# 6318: ('V3Pb', 'hollow', 'V_V_V|HCP', 'L12')
# 6319: ('V3Sn', 'hollow', 'V_V_V|HCP', 'L12')
# 6321: ('V3Ru', 'hollow', 'V_V_V|HCP', 'L12')
# 6322: ('V3Ag', 'hollow', 'V_V_V|FCC', 'L12')
# 6323: ('V2Co2', 'hollow', 'Co_V_V|HCP', 'L10')
# 6325: ('V3Pt', 'hollow', 'V_V_V|FCC', 'L12')
# 6326: ('V3Pt', 'hollow', 'V_V_V|HCP', 'L12')
# 6327: ('V3Pt', 'hollow', 'V_V_Pt|HCP', 'L12')
# 6329: ('V3Pd', 'hollow', 'V_V_V|HCP', 'L12')
